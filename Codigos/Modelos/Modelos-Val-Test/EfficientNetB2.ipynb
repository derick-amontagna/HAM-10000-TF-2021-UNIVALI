# %% [markdown]
# # 1. Comando Iniciais

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## 1.1. Importando Bibliotecas

# %%
# !pip install mlxtend --upgrade --no-deps # Versão do Mlxtend: 0.19.0
# Out:
# Requirement already satisfied: mlxtend in /usr/local/lib/python3.7/dist-packages (0.14.0)
# Collecting mlxtend
#   Downloading mlxtend-0.19.0-py2.py3-none-any.whl (1.3 MB)
#      |████████████████████████████████| 1.3 MB 4.3 MB/s
# Installing collected packages: mlxtend
#   Attempting uninstall: mlxtend
#     Found existing installation: mlxtend 0.14.0
#     Uninstalling mlxtend-0.14.0:
#       Successfully uninstalled mlxtend-0.14.0
# Successfully installed mlxtend-0.19.0

# %%
import numpy as np
import pandas as pd

import matplotlib as mpl
import matplotlib.pyplot as plt


import tensorflow as tf
from tensorflow.keras.layers import Dense, Dropout, Conv2D, Flatten, GlobalAveragePooling2D, Input
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.preprocessing import image_dataset_from_directory
from tensorflow.keras.models import Model
from tensorflow.keras.callbacks import  ModelCheckpoint, EarlyStopping
from tensorflow.keras.metrics import CategoricalAccuracy, AUC, Precision, Recall
from tensorflow import keras

import sklearn
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.preprocessing import OneHotEncoder
from sklearn.metrics import roc_curve, roc_auc_score, precision_recall_curve, precision_score, recall_score

import mlxtend
from mlxtend.plotting import plot_confusion_matrix

import itertools
import os
from os import walk
import re

import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# %%
# Utility Script - Criados dentro do Kaggle Code, devido ao fato que são modulo customizados 
# %cd /content/drive/MyDrive/TCC-Melo/Kaggle/
from lrfinder import *
from cyclicallr import *
# Out:
# /content/drive/MyDrive/TCC-Melo/Kaggle

# %% [markdown]
# ### 1.1.1. Demostrando versões das bibliotecas

# %%
print(f'Versão do Numpy: {np.__version__}')
print(f'Versão do Pandas: {pd.__version__}')
print(f'Versão do Matplotlib: {mpl.__version__}')
print(f'Versão do TensorFlow: {tf.__version__}')
print(f'Versão do Keras: {keras.__version__}')
print(f'Versão do Sklearn: {sklearn.__version__}')
print(f'Versão do Mlxtend: {mlxtend.__version__}')
# Out:
# Versão do Numpy: 1.19.5
# Versão do Pandas: 1.1.5
# Versão do Matplotlib: 3.2.2
# Versão do TensorFlow: 2.6.0
# Versão do Keras: 2.6.0
# Versão do Sklearn: 0.22.2.post1
# Versão do Mlxtend: 0.19.0

# %% [markdown]
# ## 1.2. Verificando Accelerator

# %%
gpu_info = !nvidia-smi
gpu_info = '\n'.join(gpu_info)
if gpu_info.find('failed') >= 0:
  print('Not connected to a GPU')
else:
  print(gpu_info)
# Out:
# Sun Oct 24 23:34:35 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 470.74       Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   32C    P0    26W / 250W |      0MiB / 16280MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
gpus = tf.config.list_physical_devices('GPU')
for gpu in gpus:
    print("Name:", gpu.name, "  Type:", gpu.device_type)
tf.test.is_gpu_available()
# Out:
# Name: /physical_device:GPU:0   Type: GPU
# WARNING:tensorflow:From <ipython-input-7-f99a3e65d632>:4: is_gpu_available (from tensorflow.python.framework.test_util) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.config.list_physical_devices('GPU')` instead.
# True

# %% [markdown]
# ## 1.3. Variaveis Globais

# %%
# Caminho para salvar os melhores modelos do callback checkpoint
save_dir = '/content/drive/MyDrive/TCC-Melo/Kaggle/Modelos_checkPoint_val_test/'
save_dir_plot = '/content/drive/MyDrive/TCC-Melo/Kaggle/Plots_Val_Test/'

save_dir_previsoes_val = '/content/drive/MyDrive/TCC-Melo/Kaggle/previsoes_val/'
save_dir_previsoes_test = '/content/drive/MyDrive/TCC-Melo/Kaggle/previsoes_test/'

train_path = f'/content/drive/MyDrive/TCC-Melo/Dados/ISIC2018_Task3_Training_Input_Modified_Split'    # Imagens em JPG separadas em folders
valid_path = f'/content/drive/MyDrive/TCC-Melo/Dados/ISIC2018_Task3_Validation_Input_Modified_Split'    # Imagens em JPG separadas em folders
test_path = f'/content/drive/MyDrive/TCC-Melo/Dados/ISIC2018_Task3_Test_Input_Modified'    # Imagens em JPG separadas em folders

# Ordem das categorias
classes = ['AKIEC', 'BCC', 'BKL', 'DF', 'MEL', 'NV', 'VASC']
#         [0      , 1    , 2    , 3   , 4    , 5   , 6]

# Tamanho da batch
batch_size = 16

# Dimensão das imagens de entrada
image_size = (448, 448)

# Numero de epochs
## Primeiro Momento:
first_epoch = 30

## Segundo Momento:
second_epoch = first_epoch + 70

# Calculando os passos para o treinamento

train_steps = np.ceil(10015/ batch_size)
val_steps = np.ceil(193 / batch_size)
test_steps = np.ceil(1512 / batch_size)

# Carregando os pesos para as categorias para o treinamento 
weights_train_dict = {0: 15, 1: 10, 2: 5, 3: 42,
                      4: 20, 5: 1, 6: 35}

# %% [markdown]
# ## 1.4. Metricas de avaliação

# %%
metricasEscolhidas = [CategoricalAccuracy(name='acc'), 
                      AUC(name='auc'),
                      Precision(name='precision'), 
                      Recall(name='recall')]

# %% [markdown]
# ## 1.5. Carregando os dados

# %% [markdown]
#  ### 1.5.1. Treinamento

# %%
train_ds = image_dataset_from_directory(train_path,
                                        batch_size=batch_size,
                                        image_size = image_size,
                                        label_mode='categorical',
                                        shuffle=True,
                                        seed=42)
# Out:
# Found 10015 files belonging to 7 classes.

# %%
val_ds = image_dataset_from_directory(valid_path,
                                      batch_size=batch_size,
                                      image_size = image_size,
                                      label_mode='categorical',
                                      shuffle=False,
                                      seed=42)
# Out:
# Found 193 files belonging to 7 classes.

# %%
test_ds = image_dataset_from_directory(test_path,
                                      batch_size = batch_size,
                                      image_size = image_size,
                                      label_mode=None,
                                      shuffle=False,
                                      seed=42)
# Out:
# Found 1512 files belonging to 1 classes.

# %% [markdown]
# #### 1.5.1.1. Alta velocidade de treinamento

# %%
for image_batch, labels_batch in train_ds:
  print(image_batch.shape)
  print(labels_batch.shape)
  break
# Out:
# (16, 448, 448, 3)
# (16, 7)

# %%
AUTOTUNE = tf.data.AUTOTUNE

train_ds = train_ds.prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.prefetch(buffer_size=AUTOTUNE)
test_ds = test_ds.prefetch(buffer_size=AUTOTUNE)

# %% [markdown]
# ## 1.6. Modelo Pré-treinado

# %%
num_model = 12

# %% [markdown]
# ### 1.6.1. Selecionando modelo

# %%
if num_model == 1:
    nomeDoModelo = 'DenseNet121'
    modelo = tf.keras.applications.DenseNet121(weights='imagenet', 
                                               include_top=False, 
                                               input_tensor=Input(shape=image_size+(3,)))
elif num_model == 2:
    nomeDoModelo = 'DenseNet169'
    modelo = tf.keras.applications.DenseNet169(weights='imagenet', 
                                               include_top=False, 
                                               input_tensor=Input(shape=image_size+(3,)))
elif num_model == 3:
    nomeDoModelo = 'DenseNet201'
    modelo = tf.keras.applications.DenseNet201(weights='imagenet', 
                                               include_top=False, 
                                               input_tensor=Input(shape=image_size+(3,)))
elif num_model == 4:
    nomeDoModelo = 'ResNet50V2'
    modelo = tf.keras.applications.ResNet50V2(weights='imagenet', 
                                               include_top=False, 
                                               input_tensor=Input(shape=image_size+(3,)))
elif num_model == 5:
    nomeDoModelo = 'ResNet101V2'
    modelo = tf.keras.applications.ResNet101V2(weights='imagenet', 
                                               include_top=False, 
                                               input_tensor=Input(shape=image_size+(3,)))
elif num_model == 6:
    nomeDoModelo = 'ResNet152V2'
    modelo = tf.keras.applications.ResNet152V2(weights='imagenet', 
                                               include_top=False, 
                                               input_tensor=Input(shape=image_size+(3,)))
elif num_model == 7:
    nomeDoModelo = 'Xception'
    modelo = tf.keras.applications.Xception(weights='imagenet', 
                                               include_top=False, 
                                               input_tensor=Input(shape=image_size+(3,)))
elif num_model == 8:
    nomeDoModelo = 'InceptionV3'
    modelo = tf.keras.applications.InceptionV3(weights='imagenet', 
                                               include_top=False, 
                                               input_tensor=Input(shape=image_size+(3,)))
elif num_model == 9:
    nomeDoModelo = 'InceptionResNetV2'
    modelo = tf.keras.applications.InceptionResNetV2(weights='imagenet', 
                                               include_top=False, 
                                               input_tensor=Input(shape=image_size+(3,)))
elif num_model == 10:
    nomeDoModelo = 'EfficientNetB0'
    modelo = tf.keras.applications.EfficientNetB0(weights='imagenet', 
                                               include_top=False, 
                                               input_tensor=Input(shape=image_size+(3,)))
elif num_model == 11:
    nomeDoModelo = 'EfficientNetB1'
    modelo = tf.keras.applications.EfficientNetB1(weights='imagenet', 
                                               include_top=False, 
                                               input_tensor=Input(shape=image_size+(3,)))
elif num_model == 12:
    nomeDoModelo = 'EfficientNetB2'
    modelo = tf.keras.applications.EfficientNetB2(weights='imagenet', 
                                               include_top=False, 
                                               input_tensor=Input(shape=image_size+(3,)))
    
print(f'O modelo selecionado foi {nomeDoModelo}')
# Out:
# Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb2_notop.h5
# 31793152/31790344 [==============================] - 0s 0us/step
# 31801344/31790344 [==============================] - 0s 0us/step
# O modelo selecionado foi EfficientNetB2

# %% [markdown]
# # 2. Preprocessamento

# %% [markdown]
# ## 2.1. Camada de aumento de dados

# %%
camada_ad = tf.keras.Sequential([
  tf.keras.layers.RandomFlip('horizontal'),
  tf.keras.layers.RandomFlip('vertical'),
  tf.keras.layers.RandomRotation(0.3),
  tf.keras.layers.RandomContrast((0.8, 1.1)),
], name='data_augmentation')

# %% [markdown]
# ## 2.2. Camada de reescalonamento

# %%
if num_model in [1, 2, 3]:
    camada_reescal = tf.keras.applications.densenet.preprocess_input
elif num_model in [4, 5, 6]:
    camada_reescal = tf.keras.applications.resnet_v2.preprocess_input
elif num_model == 7:
    camada_reescal = tf.keras.applications.xception.preprocess_input
elif num_model == 8:
    camada_reescal = tf.keras.applications.inception_v3.preprocess_input
elif num_model == 9:
    camada_reescal = tf.keras.applications.inception_resnet_v2.preprocess_input
elif num_model in [10, 11, 12]:
    camada_reescal = tf.keras.applications.efficientnet.preprocess_input
    
print(f'A camada selecionada foi {camada_reescal}')
# Out:
# A camada selecionada foi <function preprocess_input at 0x7f6da934d7a0>

# %% [markdown]
# # 3. Classificação

# %% [markdown]
# ## 3.1. Criando o modelo: Primeiro Momento

# %%
modelBase = modelo

modelBase.trainable = False # Congelando os pesos do modelo base

inputs = tf.keras.Input(shape=image_size+(3,))
x = camada_ad(inputs)
x = camada_reescal(x)
x = modelBase(x, training=False) # Deixando o modelo em modo enferência por causa das camadas BatchNormalization
x = GlobalAveragePooling2D()(x)
x = Dropout(0.3)(x)
predictions = Dense(7, activation='softmax')(x)
model = tf.keras.Model(inputs, predictions, name=nomeDoModelo)

# %%
model.summary()
# Out:
# Model: "EfficientNetB2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         [(None, 448, 448, 3)]     0
# _________________________________________________________________
# data_augmentation (Sequentia (None, 448, 448, 3)       0
# _________________________________________________________________
# efficientnetb2 (Functional)  (None, 14, 14, 1408)      7768569
# _________________________________________________________________
# global_average_pooling2d (Gl (None, 1408)              0
# _________________________________________________________________
# dropout (Dropout)            (None, 1408)              0
# _________________________________________________________________
# dense (Dense)                (None, 7)                 9863
# =================================================================
# Total params: 7,778,432
# Trainable params: 9,863
# Non-trainable params: 7,768,569
# _________________________________________________________________

# %% [markdown]
# ### 3.1.1. Buscando a taxa de aprendizado: LRFinder 1

# %%
optimizer = tf.keras.optimizers.Adam()
loss_fn = tf.keras.losses.CategoricalCrossentropy()

# %%
lr_find = LrFinder(model, optimizer, loss_fn)
lr_find.range_test(train_ds)
lr_find.plot_lrs(suggestion=True, show_grid=True)
# Out:
# Finding best initial lr over 100 steps
#   0%|          | 0/100 [00:00<?, ?it/s]
# LR Finder is complete, type {LrFinder}.plot_lrs() to see the graph.
# Min numerical gradient: 2.09E-03
# Min loss divided by 10: 1.58E-03

# %%
base_lr = 1e-03

# %% [markdown]
# ### 3.1.2. Treinando

# %%
model.compile(optimizer=Adam(learning_rate= base_lr), 
              loss=tf.keras.losses.CategoricalCrossentropy(), 
              metrics=metricasEscolhidas)

# %%
history = model.fit(train_ds,
                    class_weight = weights_train_dict,
                    steps_per_epoch = train_steps,
                    epochs=first_epoch,
                    validation_data=val_ds,
                    validation_steps = val_steps)
# Out:
# Epoch 1/30
# 626/626 [==============================] - 1403s 2s/step - loss: 7.6747 - acc: 0.3296 - auc: 0.7633 - precision: 0.3732 - recall: 0.1274 - val_loss: 1.5696 - val_acc: 0.3938 - val_auc: 0.7887 - val_precision: 0.4444 - val_recall: 0.1865
# Epoch 2/30
# 626/626 [==============================] - 74s 117ms/step - loss: 6.5179 - acc: 0.4222 - auc: 0.8211 - precision: 0.5015 - recall: 0.2367 - val_loss: 1.5982 - val_acc: 0.3679 - val_auc: 0.7976 - val_precision: 0.4444 - val_recall: 0.2487
# Epoch 3/30
# 626/626 [==============================] - 74s 117ms/step - loss: 6.2053 - acc: 0.4477 - auc: 0.8353 - precision: 0.5344 - recall: 0.2833 - val_loss: 1.2207 - val_acc: 0.5389 - val_auc: 0.8758 - val_precision: 0.6569 - val_recall: 0.3472
# Epoch 4/30
# 626/626 [==============================] - 74s 117ms/step - loss: 5.9479 - acc: 0.4630 - auc: 0.8479 - precision: 0.5482 - recall: 0.3121 - val_loss: 1.3641 - val_acc: 0.4715 - val_auc: 0.8472 - val_precision: 0.5702 - val_recall: 0.3368
# Epoch 5/30
# 626/626 [==============================] - 74s 117ms/step - loss: 5.6546 - acc: 0.4785 - auc: 0.8549 - precision: 0.5608 - recall: 0.3290 - val_loss: 1.4207 - val_acc: 0.4041 - val_auc: 0.8406 - val_precision: 0.4921 - val_recall: 0.3212
# Epoch 6/30
# 626/626 [==============================] - 74s 118ms/step - loss: 5.5323 - acc: 0.4917 - auc: 0.8587 - precision: 0.5762 - recall: 0.3546 - val_loss: 1.4727 - val_acc: 0.3990 - val_auc: 0.8348 - val_precision: 0.5000 - val_recall: 0.3264
# Epoch 7/30
# 626/626 [==============================] - 74s 118ms/step - loss: 5.4940 - acc: 0.4908 - auc: 0.8627 - precision: 0.5665 - recall: 0.3591 - val_loss: 1.2054 - val_acc: 0.5492 - val_auc: 0.8816 - val_precision: 0.5952 - val_recall: 0.3886
# Epoch 8/30
# 626/626 [==============================] - 74s 118ms/step - loss: 5.4582 - acc: 0.4968 - auc: 0.8667 - precision: 0.5793 - recall: 0.3704 - val_loss: 1.3556 - val_acc: 0.4870 - val_auc: 0.8553 - val_precision: 0.5714 - val_recall: 0.3523
# Epoch 9/30
# 626/626 [==============================] - 74s 117ms/step - loss: 5.3506 - acc: 0.5020 - auc: 0.8670 - precision: 0.5781 - recall: 0.3755 - val_loss: 1.4076 - val_acc: 0.4922 - val_auc: 0.8475 - val_precision: 0.5703 - val_recall: 0.3782
# Epoch 10/30
# 626/626 [==============================] - 74s 117ms/step - loss: 5.2382 - acc: 0.5084 - auc: 0.8707 - precision: 0.5884 - recall: 0.3853 - val_loss: 1.2842 - val_acc: 0.5078 - val_auc: 0.8710 - val_precision: 0.6032 - val_recall: 0.3938
# Epoch 11/30
# 626/626 [==============================] - 74s 117ms/step - loss: 5.2247 - acc: 0.5150 - auc: 0.8725 - precision: 0.5951 - recall: 0.3978 - val_loss: 1.2320 - val_acc: 0.5233 - val_auc: 0.8794 - val_precision: 0.6124 - val_recall: 0.4093
# Epoch 12/30
# 626/626 [==============================] - 74s 117ms/step - loss: 5.1731 - acc: 0.5123 - auc: 0.8743 - precision: 0.5863 - recall: 0.4009 - val_loss: 1.2299 - val_acc: 0.5492 - val_auc: 0.8831 - val_precision: 0.6324 - val_recall: 0.4456
# Epoch 13/30
# 626/626 [==============================] - 74s 117ms/step - loss: 5.0996 - acc: 0.5113 - auc: 0.8750 - precision: 0.5875 - recall: 0.4057 - val_loss: 1.3043 - val_acc: 0.4767 - val_auc: 0.8677 - val_precision: 0.5954 - val_recall: 0.4041
# Epoch 14/30
# 626/626 [==============================] - 74s 117ms/step - loss: 5.1944 - acc: 0.5130 - auc: 0.8763 - precision: 0.5872 - recall: 0.4073 - val_loss: 1.3216 - val_acc: 0.5285 - val_auc: 0.8686 - val_precision: 0.5957 - val_recall: 0.4352
# Epoch 15/30
# 626/626 [==============================] - 73s 117ms/step - loss: 5.0897 - acc: 0.5189 - auc: 0.8769 - precision: 0.5888 - recall: 0.4066 - val_loss: 1.3089 - val_acc: 0.4819 - val_auc: 0.8708 - val_precision: 0.5926 - val_recall: 0.4145
# Epoch 16/30
# 626/626 [==============================] - 74s 117ms/step - loss: 4.9895 - acc: 0.5277 - auc: 0.8795 - precision: 0.5959 - recall: 0.4211 - val_loss: 1.3474 - val_acc: 0.4767 - val_auc: 0.8653 - val_precision: 0.5278 - val_recall: 0.3938
# Epoch 17/30
# 626/626 [==============================] - 74s 117ms/step - loss: 5.1044 - acc: 0.5251 - auc: 0.8789 - precision: 0.6005 - recall: 0.4214 - val_loss: 1.3591 - val_acc: 0.4663 - val_auc: 0.8600 - val_precision: 0.5362 - val_recall: 0.3834
# Epoch 18/30
# 626/626 [==============================] - 73s 117ms/step - loss: 5.0909 - acc: 0.5239 - auc: 0.8815 - precision: 0.5929 - recall: 0.4233 - val_loss: 1.2559 - val_acc: 0.5337 - val_auc: 0.8772 - val_precision: 0.6127 - val_recall: 0.4508
# Epoch 19/30
# 626/626 [==============================] - 73s 117ms/step - loss: 4.9892 - acc: 0.5278 - auc: 0.8814 - precision: 0.5969 - recall: 0.4264 - val_loss: 1.2913 - val_acc: 0.5078 - val_auc: 0.8744 - val_precision: 0.5652 - val_recall: 0.4041
# Epoch 20/30
# 626/626 [==============================] - 74s 117ms/step - loss: 5.1375 - acc: 0.5173 - auc: 0.8768 - precision: 0.5888 - recall: 0.4185 - val_loss: 1.1125 - val_acc: 0.5648 - val_auc: 0.8997 - val_precision: 0.6479 - val_recall: 0.4767
# Epoch 21/30
# 626/626 [==============================] - 73s 117ms/step - loss: 4.9331 - acc: 0.5277 - auc: 0.8811 - precision: 0.5997 - recall: 0.4301 - val_loss: 1.2441 - val_acc: 0.5181 - val_auc: 0.8812 - val_precision: 0.6056 - val_recall: 0.4456
# Epoch 22/30
# 626/626 [==============================] - 74s 117ms/step - loss: 5.0181 - acc: 0.5227 - auc: 0.8813 - precision: 0.5914 - recall: 0.4329 - val_loss: 1.2059 - val_acc: 0.5544 - val_auc: 0.8882 - val_precision: 0.6222 - val_recall: 0.4352
# Epoch 23/30
# 626/626 [==============================] - 74s 117ms/step - loss: 5.0823 - acc: 0.5202 - auc: 0.8775 - precision: 0.5833 - recall: 0.4229 - val_loss: 1.3335 - val_acc: 0.4767 - val_auc: 0.8641 - val_precision: 0.5745 - val_recall: 0.4197
# Epoch 24/30
# 626/626 [==============================] - 74s 117ms/step - loss: 5.0501 - acc: 0.5269 - auc: 0.8806 - precision: 0.5899 - recall: 0.4270 - val_loss: 1.1696 - val_acc: 0.5596 - val_auc: 0.8912 - val_precision: 0.6408 - val_recall: 0.4715
# Epoch 25/30
# 626/626 [==============================] - 74s 117ms/step - loss: 5.0585 - acc: 0.5254 - auc: 0.8791 - precision: 0.5977 - recall: 0.4284 - val_loss: 1.3198 - val_acc: 0.5233 - val_auc: 0.8685 - val_precision: 0.6143 - val_recall: 0.4456
# Epoch 26/30
# 626/626 [==============================] - 74s 117ms/step - loss: 4.9316 - acc: 0.5283 - auc: 0.8803 - precision: 0.5893 - recall: 0.4298 - val_loss: 1.1937 - val_acc: 0.5751 - val_auc: 0.8917 - val_precision: 0.6107 - val_recall: 0.4715
# Epoch 27/30
# 626/626 [==============================] - 74s 117ms/step - loss: 4.9061 - acc: 0.5283 - auc: 0.8837 - precision: 0.5953 - recall: 0.4293 - val_loss: 1.2370 - val_acc: 0.5337 - val_auc: 0.8822 - val_precision: 0.6000 - val_recall: 0.4508
# Epoch 28/30
# 626/626 [==============================] - 74s 117ms/step - loss: 4.9478 - acc: 0.5250 - auc: 0.8791 - precision: 0.5945 - recall: 0.4288 - val_loss: 1.3376 - val_acc: 0.5078 - val_auc: 0.8680 - val_precision: 0.5556 - val_recall: 0.4145
# Epoch 29/30
# 626/626 [==============================] - 73s 117ms/step - loss: 4.7989 - acc: 0.5391 - auc: 0.8859 - precision: 0.6028 - recall: 0.4445 - val_loss: 1.2285 - val_acc: 0.5389 - val_auc: 0.8861 - val_precision: 0.5772 - val_recall: 0.4456
# Epoch 30/30
# 626/626 [==============================] - 74s 117ms/step - loss: 4.8543 - acc: 0.5345 - auc: 0.8858 - precision: 0.5998 - recall: 0.4479 - val_loss: 1.2800 - val_acc: 0.5078 - val_auc: 0.8763 - val_precision: 0.5735 - val_recall: 0.4041

# %% [markdown]
# ### 3.1.3. Avaliando o treinamento do modelo

# %%
acc = history.history['acc']
val_acc = history.history['val_acc']

loss = history.history['loss']
val_loss = history.history['val_loss']

plt.figure(figsize=(8, 8))
plt.subplot(2, 1, 1)
plt.plot(acc, label='Acuracia do treinamento')
plt.plot(val_acc, label='Acuracia da validação')
plt.legend(loc='lower right')
plt.ylabel('Acuracia')
plt.ylim([0,1])
plt.title('Acuracia do treinamento e validação')

plt.subplot(2, 1, 2)
plt.plot(loss, label='Perda do treinamento')
plt.plot(val_loss, label='Perda da validação')
plt.legend(loc='upper right')
plt.ylabel('Entropia Cruzada')
plt.ylim([0,8])
plt.title('Perda do treinamento e validação')
plt.xlabel('epoca')
plt.show()

# %% [markdown]
# ## 3.2. Criando o modelo: Segundo Momento

# %%
modelBase.trainable = True # Descongelando os pesos do modelo base para o treinamento

# %%
model.summary()
# Out:
# Model: "EfficientNetB2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         [(None, 448, 448, 3)]     0
# _________________________________________________________________
# data_augmentation (Sequentia (None, 448, 448, 3)       0
# _________________________________________________________________
# efficientnetb2 (Functional)  (None, 14, 14, 1408)      7768569
# _________________________________________________________________
# global_average_pooling2d (Gl (None, 1408)              0
# _________________________________________________________________
# dropout (Dropout)            (None, 1408)              0
# _________________________________________________________________
# dense (Dense)                (None, 7)                 9863
# =================================================================
# Total params: 7,778,432
# Trainable params: 7,710,857
# Non-trainable params: 67,575
# _________________________________________________________________

# %% [markdown]
# ### 3.2.1. Buscando a taxa de aprendizado: LRFinder 2

# %%
optimizer = tf.keras.optimizers.Adam()
loss_fn = tf.keras.losses.CategoricalCrossentropy()

# %%
lr_find = LrFinder(model, optimizer, loss_fn)
lr_find.range_test(train_ds)
lr_find.plot_lrs(suggestion=True, show_grid=True)
# Out:
# Finding best initial lr over 100 steps
#   0%|          | 0/100 [00:00<?, ?it/s]
# LR Finder is complete, type {LrFinder}.plot_lrs() to see the graph.
# Min numerical gradient: 1.10E-06
# Min loss divided by 10: 1.20E-04

# %%
base_lr = 1e-6
max_lr = 1e-5

# %% [markdown]
# ### 3.2.2. Definindo os Callbacks

# %% [markdown]
# #### 3.2.2.1. CyclicalLR

# %%
step_size = train_steps
clr = CyclicalLR(max_lr=max_lr, 
                 base_lr=base_lr, 
                 step_size=step_size, 
                 cyclical_momentum=False)

# %% [markdown]
# #### 3.2.2.2. Checkpoint

# %%
checkpoint = ModelCheckpoint(save_dir + str(nomeDoModelo) + '.h5',
                                                  monitor='val_auc', verbose=1,
                                                  save_best_only=True, mode='max')

# %% [markdown]
# #### 3.2.2.3. Earlystopping

# %%
earlystopping = EarlyStopping(monitor='val_loss',
                              verbose=1, mode='min', 
                              restore_best_weights=False,
                              patience=15)

# %%
# Lista contendo todos os callbacks
callbacks_list = [checkpoint, earlystopping, clr]

# %% [markdown]
# ### 3.2.3. Treinando

# %%
model.compile(optimizer=Adam(learning_rate=base_lr), 
              loss=tf.keras.losses.CategoricalCrossentropy(), 
              metrics=metricasEscolhidas)

# %%
history_fine = model.fit(train_ds,
                    class_weight = weights_train_dict,
                    steps_per_epoch = train_steps,
                    epochs=second_epoch,
                    initial_epoch=history.epoch[-1],
                    validation_data=val_ds,
                    validation_steps = val_steps,
                    callbacks = callbacks_list)
# Out:
# Epoch 30/100
# 626/626 [==============================] - 463s 723ms/step - loss: 4.6060 - acc: 0.5500 - auc: 0.8924 - precision: 0.6133 - recall: 0.4686 - val_loss: 1.1689 - val_acc: 0.5389 - val_auc: 0.8972 - val_precision: 0.6101 - val_recall: 0.5026
#
# Epoch 00030: val_auc improved from -inf to 0.89723, saving model to /content/drive/MyDrive/TCC-Melo/Kaggle/Modelos_checkPoint_val_test/EfficientNetB2.h5
# /usr/local/lib/python3.7/dist-packages/keras/utils/generic_utils.py:497: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   category=CustomMaskWarning)
# Epoch 31/100
# 626/626 [==============================] - 446s 713ms/step - loss: 4.1976 - acc: 0.5803 - auc: 0.9090 - precision: 0.6329 - recall: 0.5085 - val_loss: 1.1347 - val_acc: 0.5389 - val_auc: 0.9035 - val_precision: 0.5926 - val_recall: 0.4974
#
# Epoch 00031: val_auc improved from 0.89723 to 0.90352, saving model to /content/drive/MyDrive/TCC-Melo/Kaggle/Modelos_checkPoint_val_test/EfficientNetB2.h5
# Epoch 32/100
# 626/626 [==============================] - 451s 720ms/step - loss: 3.8209 - acc: 0.6011 - auc: 0.9168 - precision: 0.6512 - recall: 0.5380 - val_loss: 1.0163 - val_acc: 0.6010 - val_auc: 0.9200 - val_precision: 0.6374 - val_recall: 0.5648
#
# Epoch 00032: val_auc improved from 0.90352 to 0.92004, saving model to /content/drive/MyDrive/TCC-Melo/Kaggle/Modelos_checkPoint_val_test/EfficientNetB2.h5
# Epoch 33/100
# 626/626 [==============================] - 451s 721ms/step - loss: 3.6429 - acc: 0.6153 - auc: 0.9239 - precision: 0.6574 - recall: 0.5610 - val_loss: 1.0861 - val_acc: 0.5907 - val_auc: 0.9117 - val_precision: 0.6140 - val_recall: 0.5440
#
# Epoch 00033: val_auc did not improve from 0.92004
# Epoch 34/100
# 626/626 [==============================] - 450s 719ms/step - loss: 3.3687 - acc: 0.6296 - auc: 0.9314 - precision: 0.6693 - recall: 0.5808 - val_loss: 0.9870 - val_acc: 0.6218 - val_auc: 0.9255 - val_precision: 0.6765 - val_recall: 0.5959
#
# Epoch 00034: val_auc improved from 0.92004 to 0.92549, saving model to /content/drive/MyDrive/TCC-Melo/Kaggle/Modelos_checkPoint_val_test/EfficientNetB2.h5
# Epoch 35/100
# 626/626 [==============================] - 450s 718ms/step - loss: 3.2438 - acc: 0.6419 - auc: 0.9340 - precision: 0.6813 - recall: 0.5952 - val_loss: 1.0628 - val_acc: 0.6218 - val_auc: 0.9163 - val_precision: 0.6550 - val_recall: 0.5803
#
# Epoch 00035: val_auc did not improve from 0.92549
# Epoch 36/100
# 626/626 [==============================] - 450s 719ms/step - loss: 3.0649 - acc: 0.6575 - auc: 0.9399 - precision: 0.6970 - recall: 0.6168 - val_loss: 1.0776 - val_acc: 0.6114 - val_auc: 0.9181 - val_precision: 0.6374 - val_recall: 0.5648
#
# Epoch 00036: val_auc did not improve from 0.92549
# Epoch 37/100
# 626/626 [==============================] - 450s 718ms/step - loss: 3.0780 - acc: 0.6558 - auc: 0.9391 - precision: 0.6958 - recall: 0.6125 - val_loss: 0.9963 - val_acc: 0.6218 - val_auc: 0.9242 - val_precision: 0.6608 - val_recall: 0.5855
#
# Epoch 00037: val_auc did not improve from 0.92549
# Epoch 38/100
# 626/626 [==============================] - 443s 707ms/step - loss: 2.8006 - acc: 0.6770 - auc: 0.9461 - precision: 0.7112 - recall: 0.6392 - val_loss: 1.0286 - val_acc: 0.6218 - val_auc: 0.9256 - val_precision: 0.6416 - val_recall: 0.5751
#
# Epoch 00038: val_auc improved from 0.92549 to 0.92557, saving model to /content/drive/MyDrive/TCC-Melo/Kaggle/Modelos_checkPoint_val_test/EfficientNetB2.h5
# Epoch 39/100
# 626/626 [==============================] - 451s 720ms/step - loss: 2.7417 - acc: 0.6842 - auc: 0.9478 - precision: 0.7205 - recall: 0.6459 - val_loss: 0.9321 - val_acc: 0.6684 - val_auc: 0.9339 - val_precision: 0.7176 - val_recall: 0.6321
#
# Epoch 00039: val_auc improved from 0.92557 to 0.93392, saving model to /content/drive/MyDrive/TCC-Melo/Kaggle/Modelos_checkPoint_val_test/EfficientNetB2.h5
# Epoch 40/100
# 626/626 [==============================] - 449s 717ms/step - loss: 2.5475 - acc: 0.7029 - auc: 0.9525 - precision: 0.7337 - recall: 0.6685 - val_loss: 0.9363 - val_acc: 0.6632 - val_auc: 0.9333 - val_precision: 0.6936 - val_recall: 0.6218
#
# Epoch 00040: val_auc did not improve from 0.93392
# Epoch 41/100
# 626/626 [==============================] - 449s 717ms/step - loss: 2.5115 - acc: 0.6975 - auc: 0.9527 - precision: 0.7305 - recall: 0.6656 - val_loss: 0.9607 - val_acc: 0.6788 - val_auc: 0.9314 - val_precision: 0.7151 - val_recall: 0.6373
#
# Epoch 00041: val_auc did not improve from 0.93392
# Epoch 42/100
# 626/626 [==============================] - 448s 715ms/step - loss: 2.3566 - acc: 0.7158 - auc: 0.9575 - precision: 0.7446 - recall: 0.6864 - val_loss: 0.9043 - val_acc: 0.6684 - val_auc: 0.9417 - val_precision: 0.7216 - val_recall: 0.6580
#
# Epoch 00042: val_auc improved from 0.93392 to 0.94173, saving model to /content/drive/MyDrive/TCC-Melo/Kaggle/Modelos_checkPoint_val_test/EfficientNetB2.h5
# Epoch 43/100
# 626/626 [==============================] - 448s 716ms/step - loss: 2.2589 - acc: 0.7191 - auc: 0.9585 - precision: 0.7486 - recall: 0.6906 - val_loss: 0.9235 - val_acc: 0.6891 - val_auc: 0.9369 - val_precision: 0.7232 - val_recall: 0.6632
#
# Epoch 00043: val_auc did not improve from 0.94173
# Epoch 44/100
# 626/626 [==============================] - 449s 716ms/step - loss: 2.1636 - acc: 0.7348 - auc: 0.9629 - precision: 0.7658 - recall: 0.7091 - val_loss: 1.0456 - val_acc: 0.6373 - val_auc: 0.9282 - val_precision: 0.6839 - val_recall: 0.6166
#
# Epoch 00044: val_auc did not improve from 0.94173
# Epoch 45/100
# 626/626 [==============================] - 453s 723ms/step - loss: 2.0752 - acc: 0.7415 - auc: 0.9632 - precision: 0.7685 - recall: 0.7148 - val_loss: 0.8938 - val_acc: 0.6995 - val_auc: 0.9402 - val_precision: 0.7416 - val_recall: 0.6839
#
# Epoch 00045: val_auc did not improve from 0.94173
# Epoch 46/100
# 626/626 [==============================] - 450s 718ms/step - loss: 2.0082 - acc: 0.7439 - auc: 0.9645 - precision: 0.7693 - recall: 0.7205 - val_loss: 0.8568 - val_acc: 0.7098 - val_auc: 0.9455 - val_precision: 0.7543 - val_recall: 0.6839
#
# Epoch 00046: val_auc improved from 0.94173 to 0.94550, saving model to /content/drive/MyDrive/TCC-Melo/Kaggle/Modelos_checkPoint_val_test/EfficientNetB2.h5
# Epoch 47/100
# 626/626 [==============================] - 451s 720ms/step - loss: 1.9572 - acc: 0.7547 - auc: 0.9653 - precision: 0.7782 - recall: 0.7299 - val_loss: 0.9194 - val_acc: 0.7047 - val_auc: 0.9422 - val_precision: 0.7283 - val_recall: 0.6943
#
# Epoch 00047: val_auc did not improve from 0.94550
# Epoch 48/100
# 626/626 [==============================] - 451s 720ms/step - loss: 1.8093 - acc: 0.7689 - auc: 0.9691 - precision: 0.7893 - recall: 0.7475 - val_loss: 0.9610 - val_acc: 0.6684 - val_auc: 0.9402 - val_precision: 0.7257 - val_recall: 0.6580
#
# Epoch 00048: val_auc did not improve from 0.94550
# Epoch 49/100
# 626/626 [==============================] - 451s 719ms/step - loss: 1.7540 - acc: 0.7709 - auc: 0.9698 - precision: 0.7928 - recall: 0.7517 - val_loss: 0.8165 - val_acc: 0.7306 - val_auc: 0.9520 - val_precision: 0.7598 - val_recall: 0.7047
#
# Epoch 00049: val_auc improved from 0.94550 to 0.95201, saving model to /content/drive/MyDrive/TCC-Melo/Kaggle/Modelos_checkPoint_val_test/EfficientNetB2.h5
# Epoch 50/100
# 626/626 [==============================] - 446s 712ms/step - loss: 1.6476 - acc: 0.7887 - auc: 0.9735 - precision: 0.8099 - recall: 0.7687 - val_loss: 0.9482 - val_acc: 0.6736 - val_auc: 0.9393 - val_precision: 0.7062 - val_recall: 0.6477
#
# Epoch 00050: val_auc did not improve from 0.95201
# Epoch 51/100
# 626/626 [==============================] - 450s 718ms/step - loss: 1.7101 - acc: 0.7762 - auc: 0.9719 - precision: 0.7962 - recall: 0.7585 - val_loss: 0.8526 - val_acc: 0.7047 - val_auc: 0.9483 - val_precision: 0.7363 - val_recall: 0.6943
#
# Epoch 00051: val_auc did not improve from 0.95201
# Epoch 52/100
# 626/626 [==============================] - 447s 713ms/step - loss: 1.5807 - acc: 0.7917 - auc: 0.9743 - precision: 0.8108 - recall: 0.7729 - val_loss: 0.8317 - val_acc: 0.7358 - val_auc: 0.9541 - val_precision: 0.7582 - val_recall: 0.7150
#
# Epoch 00052: val_auc improved from 0.95201 to 0.95405, saving model to /content/drive/MyDrive/TCC-Melo/Kaggle/Modelos_checkPoint_val_test/EfficientNetB2.h5
# Epoch 53/100
# 626/626 [==============================] - 451s 720ms/step - loss: 1.5465 - acc: 0.7979 - auc: 0.9755 - precision: 0.8159 - recall: 0.7795 - val_loss: 0.8057 - val_acc: 0.7254 - val_auc: 0.9541 - val_precision: 0.7637 - val_recall: 0.7202
#
# Epoch 00053: val_auc improved from 0.95405 to 0.95406, saving model to /content/drive/MyDrive/TCC-Melo/Kaggle/Modelos_checkPoint_val_test/EfficientNetB2.h5
# Epoch 54/100
# 626/626 [==============================] - 451s 721ms/step - loss: 1.4220 - acc: 0.8128 - auc: 0.9778 - precision: 0.8305 - recall: 0.7938 - val_loss: 1.0651 - val_acc: 0.6891 - val_auc: 0.9330 - val_precision: 0.7011 - val_recall: 0.6684
#
# Epoch 00054: val_auc did not improve from 0.95406
# Epoch 55/100
# 626/626 [==============================] - 453s 723ms/step - loss: 1.4526 - acc: 0.8080 - auc: 0.9770 - precision: 0.8260 - recall: 0.7907 - val_loss: 0.8469 - val_acc: 0.7306 - val_auc: 0.9524 - val_precision: 0.7527 - val_recall: 0.7098
#
# Epoch 00055: val_auc did not improve from 0.95406
# Epoch 56/100
# 626/626 [==============================] - 451s 720ms/step - loss: 1.3615 - acc: 0.8196 - auc: 0.9799 - precision: 0.8364 - recall: 0.8038 - val_loss: 1.1652 - val_acc: 0.6580 - val_auc: 0.9204 - val_precision: 0.6757 - val_recall: 0.6477
#
# Epoch 00056: val_auc did not improve from 0.95406
# Epoch 57/100
# 626/626 [==============================] - 451s 719ms/step - loss: 1.3492 - acc: 0.8174 - auc: 0.9792 - precision: 0.8362 - recall: 0.8002 - val_loss: 0.8368 - val_acc: 0.7306 - val_auc: 0.9521 - val_precision: 0.7500 - val_recall: 0.6995
#
# Epoch 00057: val_auc did not improve from 0.95406
# Epoch 58/100
# 626/626 [==============================] - 452s 721ms/step - loss: 1.1803 - acc: 0.8299 - auc: 0.9820 - precision: 0.8469 - recall: 0.8168 - val_loss: 1.1091 - val_acc: 0.6684 - val_auc: 0.9274 - val_precision: 0.6791 - val_recall: 0.6580
#
# Epoch 00058: val_auc did not improve from 0.95406
# Epoch 59/100
# 626/626 [==============================] - 450s 719ms/step - loss: 1.2027 - acc: 0.8352 - auc: 0.9819 - precision: 0.8512 - recall: 0.8236 - val_loss: 0.7965 - val_acc: 0.7565 - val_auc: 0.9557 - val_precision: 0.7845 - val_recall: 0.7358
#
# Epoch 00059: val_auc improved from 0.95406 to 0.95571, saving model to /content/drive/MyDrive/TCC-Melo/Kaggle/Modelos_checkPoint_val_test/EfficientNetB2.h5
# Epoch 60/100
# 626/626 [==============================] - 452s 722ms/step - loss: 1.0892 - acc: 0.8441 - auc: 0.9838 - precision: 0.8585 - recall: 0.8327 - val_loss: 0.9981 - val_acc: 0.7254 - val_auc: 0.9428 - val_precision: 0.7391 - val_recall: 0.7047
#
# Epoch 00060: val_auc did not improve from 0.95571
# Epoch 61/100
# 626/626 [==============================] - 449s 716ms/step - loss: 1.1508 - acc: 0.8438 - auc: 0.9825 - precision: 0.8576 - recall: 0.8312 - val_loss: 0.7979 - val_acc: 0.7668 - val_auc: 0.9541 - val_precision: 0.7796 - val_recall: 0.7513
#
# Epoch 00061: val_auc did not improve from 0.95571
# Epoch 62/100
# 626/626 [==============================] - 451s 720ms/step - loss: 1.0004 - acc: 0.8569 - auc: 0.9854 - precision: 0.8691 - recall: 0.8480 - val_loss: 1.0654 - val_acc: 0.6891 - val_auc: 0.9374 - val_precision: 0.6952 - val_recall: 0.6736
#
# Epoch 00062: val_auc did not improve from 0.95571
# Epoch 63/100
# 626/626 [==============================] - 451s 720ms/step - loss: 1.0512 - acc: 0.8525 - auc: 0.9847 - precision: 0.8670 - recall: 0.8429 - val_loss: 0.7441 - val_acc: 0.7565 - val_auc: 0.9614 - val_precision: 0.7742 - val_recall: 0.7461
#
# Epoch 00063: val_auc improved from 0.95571 to 0.96137, saving model to /content/drive/MyDrive/TCC-Melo/Kaggle/Modelos_checkPoint_val_test/EfficientNetB2.h5
# Epoch 64/100
# 626/626 [==============================] - 451s 720ms/step - loss: 0.9585 - acc: 0.8643 - auc: 0.9867 - precision: 0.8762 - recall: 0.8547 - val_loss: 0.8025 - val_acc: 0.7409 - val_auc: 0.9585 - val_precision: 0.7554 - val_recall: 0.7202
#
# Epoch 00064: val_auc did not improve from 0.96137
# Epoch 65/100
# 626/626 [==============================] - 450s 719ms/step - loss: 0.9351 - acc: 0.8596 - auc: 0.9859 - precision: 0.8709 - recall: 0.8507 - val_loss: 0.7577 - val_acc: 0.7565 - val_auc: 0.9613 - val_precision: 0.7701 - val_recall: 0.7461
#
# Epoch 00065: val_auc did not improve from 0.96137
# Epoch 66/100
# 626/626 [==============================] - 452s 721ms/step - loss: 0.8752 - acc: 0.8700 - auc: 0.9884 - precision: 0.8812 - recall: 0.8622 - val_loss: 1.3358 - val_acc: 0.6528 - val_auc: 0.9075 - val_precision: 0.6632 - val_recall: 0.6528
#
# Epoch 00066: val_auc did not improve from 0.96137
# Epoch 67/100
# 626/626 [==============================] - 450s 718ms/step - loss: 0.9048 - acc: 0.8664 - auc: 0.9870 - precision: 0.8777 - recall: 0.8571 - val_loss: 0.8109 - val_acc: 0.7513 - val_auc: 0.9530 - val_precision: 0.7742 - val_recall: 0.7461
#
# Epoch 00067: val_auc did not improve from 0.96137
# Epoch 68/100
# 626/626 [==============================] - 451s 720ms/step - loss: 0.8555 - acc: 0.8806 - auc: 0.9889 - precision: 0.8899 - recall: 0.8721 - val_loss: 1.0991 - val_acc: 0.6995 - val_auc: 0.9319 - val_precision: 0.7135 - val_recall: 0.6839
#
# Epoch 00068: val_auc did not improve from 0.96137
# Epoch 69/100
# 626/626 [==============================] - 451s 721ms/step - loss: 0.7868 - acc: 0.8800 - auc: 0.9888 - precision: 0.8880 - recall: 0.8728 - val_loss: 0.7807 - val_acc: 0.7461 - val_auc: 0.9574 - val_precision: 0.7717 - val_recall: 0.7358
#
# Epoch 00069: val_auc did not improve from 0.96137
# Epoch 70/100
# 626/626 [==============================] - 452s 722ms/step - loss: 0.7709 - acc: 0.8867 - auc: 0.9901 - precision: 0.8960 - recall: 0.8790 - val_loss: 1.1168 - val_acc: 0.7150 - val_auc: 0.9309 - val_precision: 0.7234 - val_recall: 0.7047
#
# Epoch 00070: val_auc did not improve from 0.96137
# Epoch 71/100
# 626/626 [==============================] - 452s 721ms/step - loss: 0.7499 - acc: 0.8864 - auc: 0.9896 - precision: 0.8955 - recall: 0.8794 - val_loss: 0.7626 - val_acc: 0.7617 - val_auc: 0.9607 - val_precision: 0.7819 - val_recall: 0.7617
#
# Epoch 00071: val_auc did not improve from 0.96137
# Epoch 72/100
# 626/626 [==============================] - 450s 718ms/step - loss: 0.6980 - acc: 0.8956 - auc: 0.9909 - precision: 0.9034 - recall: 0.8880 - val_loss: 0.7058 - val_acc: 0.7824 - val_auc: 0.9643 - val_precision: 0.8132 - val_recall: 0.7668
#
# Epoch 00072: val_auc improved from 0.96137 to 0.96426, saving model to /content/drive/MyDrive/TCC-Melo/Kaggle/Modelos_checkPoint_val_test/EfficientNetB2.h5
# Epoch 73/100
# 626/626 [==============================] - 446s 712ms/step - loss: 0.6838 - acc: 0.8935 - auc: 0.9910 - precision: 0.9008 - recall: 0.8876 - val_loss: 0.7387 - val_acc: 0.7720 - val_auc: 0.9610 - val_precision: 0.7831 - val_recall: 0.7668
#
# Epoch 00073: val_auc did not improve from 0.96426
# Epoch 74/100
# 626/626 [==============================] - 453s 723ms/step - loss: 0.6848 - acc: 0.9016 - auc: 0.9919 - precision: 0.9085 - recall: 0.8961 - val_loss: 0.7877 - val_acc: 0.7513 - val_auc: 0.9636 - val_precision: 0.7672 - val_recall: 0.7513
#
# Epoch 00074: val_auc did not improve from 0.96426
# Epoch 75/100
# 626/626 [==============================] - 452s 722ms/step - loss: 0.7166 - acc: 0.8938 - auc: 0.9908 - precision: 0.9025 - recall: 0.8885 - val_loss: 0.7933 - val_acc: 0.7668 - val_auc: 0.9601 - val_precision: 0.7861 - val_recall: 0.7617
#
# Epoch 00075: val_auc did not improve from 0.96426
# Epoch 76/100
# 626/626 [==============================] - 449s 717ms/step - loss: 0.6289 - acc: 0.9073 - auc: 0.9918 - precision: 0.9146 - recall: 0.9008 - val_loss: 0.7958 - val_acc: 0.7513 - val_auc: 0.9597 - val_precision: 0.7526 - val_recall: 0.7409
#
# Epoch 00076: val_auc did not improve from 0.96426
# Epoch 77/100
# 626/626 [==============================] - 449s 716ms/step - loss: 0.5773 - acc: 0.9060 - auc: 0.9928 - precision: 0.9138 - recall: 0.9013 - val_loss: 0.8149 - val_acc: 0.7617 - val_auc: 0.9571 - val_precision: 0.7696 - val_recall: 0.7617
#
# Epoch 00077: val_auc did not improve from 0.96426
# Epoch 78/100
# 626/626 [==============================] - 449s 717ms/step - loss: 0.5685 - acc: 0.9119 - auc: 0.9933 - precision: 0.9178 - recall: 0.9072 - val_loss: 1.4877 - val_acc: 0.6580 - val_auc: 0.9050 - val_precision: 0.6649 - val_recall: 0.6477
#
# Epoch 00078: val_auc did not improve from 0.96426
# Epoch 79/100
# 626/626 [==============================] - 449s 717ms/step - loss: 0.5619 - acc: 0.9093 - auc: 0.9926 - precision: 0.9159 - recall: 0.9038 - val_loss: 0.7510 - val_acc: 0.7513 - val_auc: 0.9677 - val_precision: 0.7566 - val_recall: 0.7409
#
# Epoch 00079: val_auc improved from 0.96426 to 0.96771, saving model to /content/drive/MyDrive/TCC-Melo/Kaggle/Modelos_checkPoint_val_test/EfficientNetB2.h5
# Epoch 80/100
# 626/626 [==============================] - 449s 718ms/step - loss: 0.5381 - acc: 0.9143 - auc: 0.9933 - precision: 0.9219 - recall: 0.9108 - val_loss: 0.8510 - val_acc: 0.7876 - val_auc: 0.9621 - val_precision: 0.7937 - val_recall: 0.7772
#
# Epoch 00080: val_auc did not improve from 0.96771
# Epoch 81/100
# 626/626 [==============================] - 450s 719ms/step - loss: 0.5623 - acc: 0.9087 - auc: 0.9934 - precision: 0.9147 - recall: 0.9037 - val_loss: 0.6982 - val_acc: 0.8031 - val_auc: 0.9672 - val_precision: 0.8115 - val_recall: 0.8031
#
# Epoch 00081: val_auc did not improve from 0.96771
# Epoch 82/100
# 626/626 [==============================] - 449s 718ms/step - loss: 0.4911 - acc: 0.9194 - auc: 0.9936 - precision: 0.9253 - recall: 0.9158 - val_loss: 0.8972 - val_acc: 0.7461 - val_auc: 0.9551 - val_precision: 0.7461 - val_recall: 0.7461
#
# Epoch 00082: val_auc did not improve from 0.96771
# Epoch 83/100
# 626/626 [==============================] - 449s 717ms/step - loss: 0.4876 - acc: 0.9219 - auc: 0.9944 - precision: 0.9279 - recall: 0.9175 - val_loss: 0.8178 - val_acc: 0.7565 - val_auc: 0.9592 - val_precision: 0.7644 - val_recall: 0.7565
#
# Epoch 00083: val_auc did not improve from 0.96771
# Epoch 84/100
# 626/626 [==============================] - 449s 716ms/step - loss: 0.4609 - acc: 0.9253 - auc: 0.9949 - precision: 0.9323 - recall: 0.9222 - val_loss: 0.8175 - val_acc: 0.7720 - val_auc: 0.9630 - val_precision: 0.7796 - val_recall: 0.7513
#
# Epoch 00084: val_auc did not improve from 0.96771
# Epoch 85/100
# 626/626 [==============================] - 449s 717ms/step - loss: 0.4688 - acc: 0.9275 - auc: 0.9945 - precision: 0.9321 - recall: 0.9229 - val_loss: 0.7377 - val_acc: 0.7772 - val_auc: 0.9676 - val_precision: 0.7842 - val_recall: 0.7720
#
# Epoch 00085: val_auc did not improve from 0.96771
# Epoch 86/100
# 626/626 [==============================] - 448s 716ms/step - loss: 0.4412 - acc: 0.9301 - auc: 0.9949 - precision: 0.9346 - recall: 0.9265 - val_loss: 0.8474 - val_acc: 0.7772 - val_auc: 0.9618 - val_precision: 0.7760 - val_recall: 0.7720
#
# Epoch 00086: val_auc did not improve from 0.96771
# Epoch 87/100
# 626/626 [==============================] - 449s 717ms/step - loss: 0.4389 - acc: 0.9308 - auc: 0.9955 - precision: 0.9348 - recall: 0.9268 - val_loss: 0.8670 - val_acc: 0.7617 - val_auc: 0.9552 - val_precision: 0.7684 - val_recall: 0.7565
#
# Epoch 00087: val_auc did not improve from 0.96771
# Epoch 88/100
# 626/626 [==============================] - 448s 716ms/step - loss: 0.3788 - acc: 0.9375 - auc: 0.9960 - precision: 0.9424 - recall: 0.9341 - val_loss: 0.7356 - val_acc: 0.8031 - val_auc: 0.9635 - val_precision: 0.8065 - val_recall: 0.7772
#
# Epoch 00088: val_auc did not improve from 0.96771
# Epoch 89/100
# 626/626 [==============================] - 449s 717ms/step - loss: 0.4309 - acc: 0.9338 - auc: 0.9957 - precision: 0.9380 - recall: 0.9308 - val_loss: 0.7333 - val_acc: 0.7979 - val_auc: 0.9638 - val_precision: 0.8010 - val_recall: 0.7927
#
# Epoch 00089: val_auc did not improve from 0.96771
# Epoch 90/100
# 626/626 [==============================] - 449s 717ms/step - loss: 0.4037 - acc: 0.9389 - auc: 0.9961 - precision: 0.9427 - recall: 0.9351 - val_loss: 0.8711 - val_acc: 0.7668 - val_auc: 0.9515 - val_precision: 0.7737 - val_recall: 0.7617
#
# Epoch 00090: val_auc did not improve from 0.96771
# Epoch 91/100
# 626/626 [==============================] - 448s 716ms/step - loss: 0.3940 - acc: 0.9361 - auc: 0.9958 - precision: 0.9404 - recall: 0.9325 - val_loss: 0.7668 - val_acc: 0.7824 - val_auc: 0.9629 - val_precision: 0.7853 - val_recall: 0.7772
#
# Epoch 00091: val_auc did not improve from 0.96771
# Epoch 92/100
# 626/626 [==============================] - 447s 714ms/step - loss: 0.3106 - acc: 0.9478 - auc: 0.9966 - precision: 0.9509 - recall: 0.9448 - val_loss: 1.4331 - val_acc: 0.7047 - val_auc: 0.9099 - val_precision: 0.7053 - val_recall: 0.6943
#
# Epoch 00092: val_auc did not improve from 0.96771
# Epoch 93/100
# 626/626 [==============================] - 451s 721ms/step - loss: 0.4015 - acc: 0.9382 - auc: 0.9957 - precision: 0.9416 - recall: 0.9351 - val_loss: 0.6945 - val_acc: 0.7772 - val_auc: 0.9681 - val_precision: 0.7812 - val_recall: 0.7772
#
# Epoch 00093: val_auc improved from 0.96771 to 0.96811, saving model to /content/drive/MyDrive/TCC-Melo/Kaggle/Modelos_checkPoint_val_test/EfficientNetB2.h5
# Epoch 94/100
# 626/626 [==============================] - 449s 716ms/step - loss: 0.3356 - acc: 0.9449 - auc: 0.9959 - precision: 0.9484 - recall: 0.9413 - val_loss: 1.3437 - val_acc: 0.7098 - val_auc: 0.9080 - val_precision: 0.7158 - val_recall: 0.7047
#
# Epoch 00094: val_auc did not improve from 0.96811
# Epoch 95/100
# 626/626 [==============================] - 451s 719ms/step - loss: 0.3535 - acc: 0.9417 - auc: 0.9959 - precision: 0.9450 - recall: 0.9390 - val_loss: 0.7442 - val_acc: 0.7927 - val_auc: 0.9643 - val_precision: 0.8053 - val_recall: 0.7927
#
# Epoch 00095: val_auc did not improve from 0.96811
# Epoch 96/100
# 626/626 [==============================] - 448s 715ms/step - loss: 0.3180 - acc: 0.9481 - auc: 0.9968 - precision: 0.9520 - recall: 0.9457 - val_loss: 0.8272 - val_acc: 0.7824 - val_auc: 0.9602 - val_precision: 0.7884 - val_recall: 0.7720
#
# Epoch 00096: val_auc did not improve from 0.96811
# Epoch 97/100
# 626/626 [==============================] - 451s 719ms/step - loss: 0.3336 - acc: 0.9454 - auc: 0.9966 - precision: 0.9485 - recall: 0.9422 - val_loss: 0.7508 - val_acc: 0.7876 - val_auc: 0.9655 - val_precision: 0.8000 - val_recall: 0.7876
#
# Epoch 00097: val_auc did not improve from 0.96811
# Epoch 98/100
# 626/626 [==============================] - 449s 717ms/step - loss: 0.2921 - acc: 0.9537 - auc: 0.9973 - precision: 0.9560 - recall: 0.9513 - val_loss: 0.9127 - val_acc: 0.7772 - val_auc: 0.9559 - val_precision: 0.7801 - val_recall: 0.7720
#
# Epoch 00098: val_auc did not improve from 0.96811
# Epoch 99/100
# 626/626 [==============================] - 447s 714ms/step - loss: 0.3671 - acc: 0.9468 - auc: 0.9967 - precision: 0.9504 - recall: 0.9434 - val_loss: 0.7161 - val_acc: 0.7979 - val_auc: 0.9688 - val_precision: 0.8010 - val_recall: 0.7927
#
# Epoch 00099: val_auc improved from 0.96811 to 0.96885, saving model to /content/drive/MyDrive/TCC-Melo/Kaggle/Modelos_checkPoint_val_test/EfficientNetB2.h5
# Epoch 100/100
# 626/626 [==============================] - 451s 720ms/step - loss: 0.2750 - acc: 0.9542 - auc: 0.9970 - precision: 0.9565 - recall: 0.9515 - val_loss: 0.7525 - val_acc: 0.8238 - val_auc: 0.9648 - val_precision: 0.8316 - val_recall: 0.8187
#
# Epoch 00100: val_auc did not improve from 0.96885

# %% [markdown]
# ### 3.2.4. Avaliando o treinamento do modelo

# %%
acc += history_fine.history['acc']
val_acc += history_fine.history['val_acc']

loss += history_fine.history['loss']
val_loss += history_fine.history['val_loss']

# %%
plt.figure(figsize=(8, 8))
plt.subplot(2, 1, 1)
plt.plot(acc, label='Acuracia de treinamento')
plt.plot(val_acc, label='Acuracia de validação')
plt.ylim([0, 1])
plt.plot([first_epoch-1,first_epoch-1],
          plt.ylim(), label='Começo do Fine Tuning')
plt.legend(loc='lower right')
plt.title('Acuracia do treinamento e validação')

plt.subplot(2, 1, 2)
plt.plot(loss, label='Perda do treinamento')
plt.plot(val_loss, label='Perda da validação')
plt.ylim([0, 8])
plt.plot([first_epoch-1,first_epoch-1],
         plt.ylim(), label='Começo do Fine Tuning')
plt.legend(loc='upper right')
plt.title('Perda do treinamento e validação')
plt.xlabel('epoca')
plt.show()

# %% [markdown]
# #### 3.2.4.1. Verificando CLR

# %%
clr.plot_lr((14, 3.5))

# %% [markdown]
# # 4. Avaliando o modelo - Validação

# %%
#model.load_weights(save_dir + str(nomeDoModelo) + '.h5')
model = tf.keras.models.load_model(save_dir + str(nomeDoModelo) + '.h5')

# %%
model.evaluate(val_ds)
# Out:
# 13/13 [==============================] - 40s 2s/step - loss: 0.8442 - acc: 0.8031 - auc: 0.9593 - precision: 0.8118 - recall: 0.7824
# [0.8442480564117432,
#  0.803108811378479,
#  0.9593479633331299,
#  0.8118279576301575,
#  0.7823834419250488]

# %% [markdown]
# ## 4.1. Realizando as previsões

# %%
# Obtendo a tabela verdade 
true_categories = tf.concat([y for x, y in val_ds], axis=0)
true_categories  = tf.argmax(true_categories , axis=1)

# %%
# Realizando as previsões
predictions = model.predict(val_ds, verbose=1) 

# salvando as previsões para o ensemble
df_predict = pd.DataFrame(data=predictions, columns=classes)
df_predict.to_csv(save_dir_previsoes_val + f'{nomeDoModelo}_val.csv', index=False)

# Realizando o processo de maximizar os resultados
y_pred = tf.argmax(predictions, axis=1)
# Out:
# 13/13 [==============================] - 3s 95ms/step

# %%
# Transformando para numpy e realizar o processo de dummy
true_categories_np = true_categories.numpy()
y_pred_np = y_pred.numpy()

ohe = OneHotEncoder(sparse=False)

true_categories_np_ohe = ohe.fit_transform(true_categories_np.reshape(-1, 1))
y_pred_np_ohe = ohe.transform(y_pred_np.reshape(-1, 1))

# %% [markdown]
# ## 4.3. Metricas de avaliação

# %% [markdown]
# ### 4.3.1. Curva ROC-AUC

# %%
# Curva ROC-AUC
fig, ax1 = plt.subplots(1, 1, figsize=(10, 10))

for i, classe in enumerate(classes):

    tpr, fpr, thresh = roc_curve(y_true=true_categories_np_ohe[:, i], y_score=y_pred_np_ohe[:, i])

    auc_roc = roc_auc_score(y_true=true_categories_np_ohe[:, i], y_score=y_pred_np_ohe[:, i])

    ax1.plot(tpr, fpr, marker='.', label=f'{classe} (AUC:{auc_roc:2.1%})')

ax1.plot([0, 1], [0, 1], linestyle='--', label='Limiar', color='k')
ax1.legend()
plt.xlabel("Taxa de falso positivo")
plt.ylabel("Taxa de verdadeiro positivo")
plt.tight_layout()
plt.savefig(save_dir_plot + f'{nomeDoModelo}_ROC-AUC.png')

# %% [markdown]
# ### 4.3.2. Curva Precisão-Revocação

# %%
# Curva Precisão-Recall

fig, ax1 = plt.subplots(1, 1, figsize=(10, 10))
precision_med = []
recall_med = []
no_skill = len(true_categories[true_categories==1]) / len(true_categories)

for i, classe in enumerate(classes):

    precision, recall, thresh = precision_recall_curve(true_categories_np_ohe[:, i], y_pred_np_ohe[:, i])
    precision_med.append(precision_score(true_categories_np_ohe[:, i], y_pred_np_ohe[:, i]))
    recall_med.append(recall_score(true_categories_np_ohe[:, i], y_pred_np_ohe[:, i]))
    ax1.plot(recall, precision, marker='.', label=f'{classe} (Precisão: {precision_med[i]:2.1%} / Revocação: {recall_med[i]:2.1%})')


precision = sum(precision_med)/len(precision_med)
recall = sum(recall_med)/len(recall_med)
ax1.axhline(y=precision, linestyle='--', color='k', label=f'Precisão Media do modelo: {precision:2.1%}')
ax1.axvline(x=recall, linestyle='--', color='k', label=f'Recall Media do modelo: {recall:2.1%}')
ax1.legend(loc="best")
plt.xlabel("Revocação")
plt.ylabel("Precisão")
plt.tight_layout()
plt.savefig(save_dir_plot + f'{nomeDoModelo}_Prec_Recall.png')

# %% [markdown]
# ### 4.3.3. Predições

# %%
plt.figure(figsize=(10, 10))

for images, labels in val_ds.take(1):
  labels = np.argmax(labels, axis=1)
  for i in range(9):
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(images[i].numpy().astype("uint8"))
    c_title = f'{classes[labels[i]]}\nPred: {100*predictions[i, true_categories[i]]:2.1f}%'
    plt.title(c_title)
    plt.axis("off")

plt.savefig(save_dir_plot + f'{nomeDoModelo}_predito.png')

# %% [markdown]
# ### 4.3.4. Quadro de metricas

# %%
print(classification_report(true_categories , y_pred, target_names=classes))
# Out:
#               precision    recall  f1-score   support
#
#        AKIEC       0.40      0.50      0.44         8
#          BCC       0.62      0.67      0.65        15
#          BKL       0.59      0.77      0.67        22
#           DF       0.25      1.00      0.40         1
#          MEL       0.62      0.71      0.67        21
#           NV       0.98      0.85      0.91       123
#         VASC       1.00      1.00      1.00         3
#
#     accuracy                           0.80       193
#    macro avg       0.64      0.79      0.68       193
# weighted avg       0.84      0.80      0.82       193

# %% [markdown]
# ### 4.3.5. Matriz de confusão

# %%
cm = confusion_matrix(true_categories , y_pred)
fig, ax = plot_confusion_matrix(conf_mat=cm,
                                show_absolute=True,
                                show_normed=True, 
                                class_names=classes)
plt.xlabel("Valor Predito")
plt.ylabel("Valor Verdadeiro")
plt.savefig(save_dir_plot + f'{nomeDoModelo}_matConf.png')

# %% [markdown]
# ### 4.3.6. Acurácia balanceada

# %%
bAcc= sklearn.metrics.balanced_accuracy_score(true_categories, y_pred)
print(f'Acurácia balanceada: {bAcc*100:.6f}%')
# Out:
# Acurácia balanceada: 78.676260%

# %% [markdown]
# # 5. Avaliando o modelo - Teste

# %%
model.load_weights(save_dir + str(nomeDoModelo) + '.h5')
#model = tf.keras.models.load_model(save_dir + str(nomeDoModelo) + '.h5'')

# %%
# Realizando a previsão
predictions = model.predict(test_ds, verbose=1)
# Out:
# 53/95 [===============>..............] - ETA: 1:19

# %%
# Pegando nome dos arquivos

rtxt = re.compile(r'(.*?)\.jpg')
files = (rtxt.match(file) for file in os.listdir(test_path))
files = [match.group(1) for match in files if match]
files = sorted(files)

# %% [markdown]
# ## 5.1. Realizando as previsões

# %%
df_predict = pd.DataFrame(data=predictions,index=files ,columns=classes).reset_index().rename(columns={'index':'image'})
df_predict.to_csv(save_dir_previsoes_test + f'{nomeDoModelo}_test.csv', index=False)
