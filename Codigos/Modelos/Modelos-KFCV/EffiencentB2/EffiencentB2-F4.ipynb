# %% [markdown]
# # 1. Comando Iniciais

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ## 1.1. Importando Bibliotecas

# %%
# !pip install mlxtend --upgrade --no-deps # Versão do Mlxtend: 0.19.0
# Out:
# Requirement already satisfied: mlxtend in /usr/local/lib/python3.7/dist-packages (0.14.0)
# Collecting mlxtend
#   Downloading mlxtend-0.19.0-py2.py3-none-any.whl (1.3 MB)
#      |████████████████████████████████| 1.3 MB 4.3 MB/s
# Installing collected packages: mlxtend
#   Attempting uninstall: mlxtend
#     Found existing installation: mlxtend 0.14.0
#     Uninstalling mlxtend-0.14.0:
#       Successfully uninstalled mlxtend-0.14.0
# Successfully installed mlxtend-0.19.0

# %%
import numpy as np
import pandas as pd

import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
import plotly 
import plotly.express as px

import tensorflow as tf
from tensorflow.keras.layers import Dense, Dropout, Conv2D, Flatten, GlobalAveragePooling2D, Input
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.preprocessing import image_dataset_from_directory
from tensorflow.keras.models import Model
from tensorflow.keras.callbacks import ReduceLROnPlateau, ModelCheckpoint, EarlyStopping
from tensorflow.keras.metrics import CategoricalAccuracy, AUC, Precision, Recall
from tensorflow import keras

import sklearn
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import confusion_matrix, classification_report

import mlxtend
from mlxtend.plotting import plot_confusion_matrix

import itertools

import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# %%
# Utility Script - Criados dentro do Kaggle Code, devido ao fato que são modulo customizados 
# %cd /content/drive/MyDrive/TCC-Melo/Kaggle/
from lrfinder import *
from cyclicallr import *
# Out:
# /content/drive/MyDrive/TCC-Melo/Kaggle

# %% [markdown]
# ### 1.1.1. Demostrando versões das bibliotecas

# %%
print(f'Versão do Numpy: {np.__version__}')
print(f'Versão do Pandas: {pd.__version__}')
print(f'Versão do Matplotlib: {mpl.__version__}')
print(f'Versão do Season: {sns.__version__}')
print(f'Versão do Plotly: {plotly.__version__}')
print(f'Versão do TensorFlow: {tf.__version__}')
print(f'Versão do Keras: {keras.__version__}')
print(f'Versão do Sklearn: {sklearn.__version__}')
print(f'Versão do Mlxtend: {mlxtend.__version__}')
# Out:
# Versão do Numpy: 1.19.5
# Versão do Pandas: 1.1.5
# Versão do Matplotlib: 3.2.2
# Versão do Season: 0.11.2
# Versão do Plotly: 4.4.1
# Versão do TensorFlow: 2.6.0
# Versão do Keras: 2.6.0
# Versão do Sklearn: 0.22.2.post1
# Versão do Mlxtend: 0.19.0

# %% [markdown]
# ## 1.2. Verificando Accelerator

# %%
gpu_info = !nvidia-smi
gpu_info = '\n'.join(gpu_info)
if gpu_info.find('failed') >= 0:
  print('Not connected to a GPU')
else:
  print(gpu_info)
# Out:
# Fri Oct 15 02:49:41 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 470.74       Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   49C    P0    30W / 250W |      0MiB / 16280MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
gpus = tf.config.list_physical_devices('GPU')
for gpu in gpus:
    print("Name:", gpu.name, "  Type:", gpu.device_type)
tf.test.is_gpu_available()
# Out:
# Name: /physical_device:GPU:0   Type: GPU
# WARNING:tensorflow:From <ipython-input-8-f99a3e65d632>:4: is_gpu_available (from tensorflow.python.framework.test_util) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.config.list_physical_devices('GPU')` instead.
# True

# %% [markdown]
# ## 1.3. Variaveis Globais

# %%
# Caminho para salvar os melhores modelos do callback checkpoint
save_dir = '/content/drive/MyDrive/TCC-Melo/Kaggle/modelos_checkPoint/'

# Caminho dos Folds
fold_var = 4 # Folder selecionado

train_path = f'/content/drive/MyDrive/TCC-Melo/Dados/Folds_Modified/fold_{fold_var}/train_dir'    # Imagens em JPG separadas em folders
valid_path = f'/content/drive/MyDrive/TCC-Melo/Dados/Folds_Modified/fold_{fold_var}/val_dir'    # Imagens em JPG separadas em folders

# Ordem das categorias
classes = ['AKIEC', 'BCC', 'BKL', 'DF', 'MEL', 'NV', 'VASC']
#         [0      , 1    , 2    , 3   , 4    , 5   , 6]

# Tamanho da batch
batch_size = 16

# Dimensão das imagens de entrada
image_size = (448, 448)

# Numero de epochs
## Primeiro Momento:
first_epoch = 30

## Segundo Momento:
second_epoch = first_epoch + 70

# Calculando os passos para o treinamento
train_steps = np.ceil(8912 / batch_size)
val_steps = np.ceil(1103 / batch_size)

# Carregando os pesos para as categorias para o treinamento 
weights_train_dict = {0: 15, 1: 10, 2: 5, 3: 42,
                      4: 20, 5: 1, 6: 35}

# %% [markdown]
# ## 1.4. Metricas de avaliação

# %%
metricasEscolhidas = [CategoricalAccuracy(name='acc'), 
                      AUC(name='auc'),
                      Precision(name='precision'), 
                      Recall(name='recall')]

# %% [markdown]
# ## 1.5. Carregando os dados

# %% [markdown]
#  ### 1.5.1. Treinamento

# %%
train_ds = image_dataset_from_directory(train_path,
                                        batch_size=batch_size,
                                        image_size = image_size,
                                        label_mode='categorical',
                                        shuffle=True,
                                        seed=42)
# Out:
# Found 8912 files belonging to 7 classes.

# %%
val_ds = image_dataset_from_directory(valid_path,
                                      batch_size=batch_size,
                                      image_size = image_size,
                                      label_mode='categorical',
                                      shuffle=False,
                                      seed=42)
# Out:
# Found 1103 files belonging to 7 classes.

# %% [markdown]
# #### 1.5.1.1. Alta velocidade de treinamento

# %%
for image_batch, labels_batch in train_ds:
  print(image_batch.shape)
  print(labels_batch.shape)
  break
# Out:
# (16, 448, 448, 3)
# (16, 7)

# %%
AUTOTUNE = tf.data.AUTOTUNE

#train_ds = train_ds.cache().prefetch(buffer_size=AUTOTUNE)
train_ds = train_ds.prefetch(buffer_size=AUTOTUNE)
#val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.prefetch(buffer_size=AUTOTUNE)

# %% [markdown]
# ## 1.6. Modelo Pré-treinado

# %%
num_model = 12

# %% [markdown]
# ### 1.6.1. Selecionando modelo

# %%
if num_model == 1:
    nomeDoModelo = 'DenseNet121'
    modelo = tf.keras.applications.DenseNet121(weights='imagenet', 
                                               include_top=False, 
                                               input_tensor=Input(shape=image_size+(3,)))
elif num_model == 2:
    nomeDoModelo = 'DenseNet169'
    modelo = tf.keras.applications.DenseNet169(weights='imagenet', 
                                               include_top=False, 
                                               input_tensor=Input(shape=image_size+(3,)))
elif num_model == 3:
    nomeDoModelo = 'DenseNet201'
    modelo = tf.keras.applications.DenseNet201(weights='imagenet', 
                                               include_top=False, 
                                               input_tensor=Input(shape=image_size+(3,)))
elif num_model == 4:
    nomeDoModelo = 'ResNet50V2'
    modelo = tf.keras.applications.ResNet50V2(weights='imagenet', 
                                               include_top=False, 
                                               input_tensor=Input(shape=image_size+(3,)))
elif num_model == 5:
    nomeDoModelo = 'ResNet101V2'
    modelo = tf.keras.applications.ResNet101V2(weights='imagenet', 
                                               include_top=False, 
                                               input_tensor=Input(shape=image_size+(3,)))
elif num_model == 6:
    nomeDoModelo = 'ResNet152V2'
    modelo = tf.keras.applications.ResNet152V2(weights='imagenet', 
                                               include_top=False, 
                                               input_tensor=Input(shape=image_size+(3,)))
elif num_model == 7:
    nomeDoModelo = 'Xception'
    modelo = tf.keras.applications.Xception(weights='imagenet', 
                                               include_top=False, 
                                               input_tensor=Input(shape=image_size+(3,)))
elif num_model == 8:
    nomeDoModelo = 'InceptionV3'
    modelo = tf.keras.applications.InceptionV3(weights='imagenet', 
                                               include_top=False, 
                                               input_tensor=Input(shape=image_size+(3,)))
elif num_model == 9:
    nomeDoModelo = 'InceptionResNetV2'
    modelo = tf.keras.applications.InceptionResNetV2(weights='imagenet', 
                                               include_top=False, 
                                               input_tensor=Input(shape=image_size+(3,)))
elif num_model == 10:
    nomeDoModelo = 'EfficientNetB0'
    modelo = tf.keras.applications.EfficientNetB0(weights='imagenet', 
                                               include_top=False, 
                                               input_tensor=Input(shape=image_size+(3,)))
elif num_model == 11:
    nomeDoModelo = 'EfficientNetB1'
    modelo = tf.keras.applications.EfficientNetB1(weights='imagenet', 
                                               include_top=False, 
                                               input_tensor=Input(shape=image_size+(3,)))
elif num_model == 12:
    nomeDoModelo = 'EfficientNetB2'
    modelo = tf.keras.applications.EfficientNetB2(weights='imagenet', 
                                               include_top=False, 
                                               input_tensor=Input(shape=image_size+(3,)))
elif num_model == 13:
    nomeDoModelo = 'EfficientNetB3'
    modelo = tf.keras.applications.EfficientNetB3(weights='imagenet', 
                                               include_top=False, 
                                               input_tensor=Input(shape=image_size+(3,)))
    
print(f'O modelo selecionado foi {nomeDoModelo}')
# Out:
# Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb2_notop.h5
# 31793152/31790344 [==============================] - 0s 0us/step
# 31801344/31790344 [==============================] - 0s 0us/step
# O modelo selecionado foi EfficientNetB2

# %% [markdown]
# # 2. Preprocessamento

# %% [markdown]
# ## 2.1. Camada de aumento de dados

# %%
camada_ad = tf.keras.Sequential([
  tf.keras.layers.experimental.preprocessing.RandomFlip('horizontal'),
  tf.keras.layers.experimental.preprocessing.RandomFlip('vertical'),
  tf.keras.layers.experimental.preprocessing.RandomRotation(0.3),
  tf.keras.layers.experimental.preprocessing.RandomContrast((0.8, 1.1)),
], name='data_augmentation')

# %% [markdown]
# ## 2.2. Camada de reescalonamento

# %%
if num_model in [1, 2, 3]:
    camada_reescal = tf.keras.applications.densenet.preprocess_input
elif num_model in [4, 5, 6]:
    camada_reescal = tf.keras.applications.resnet_v2.preprocess_input
elif num_model == 7:
    camada_reescal = tf.keras.applications.xception.preprocess_input
elif num_model == 8:
    camada_reescal = tf.keras.applications.inception_v3.preprocess_input
elif num_model == 9:
    camada_reescal = tf.keras.applications.inception_resnet_v2.preprocess_input
elif num_model in [10, 11, 12, 13]:
    camada_reescal = tf.keras.applications.efficientnet.preprocess_input
    
print(f'A camada selecionada foi {camada_reescal}')
# Out:
# A camada selecionada foi <function preprocess_input at 0x7f8f41881170>

# %% [markdown]
# # 3. Classificação

# %% [markdown]
# ## 3.1. Criando o modelo: Primeiro Momento

# %%
modelBase = modelo

modelBase.trainable = False # Congelando os pesos do modelo base

inputs = tf.keras.Input(shape=image_size+(3,))
x = camada_ad(inputs)
x = camada_reescal(x)
x = modelBase(x, training=False) # Deixando o modelo em modo enferência por causa das camadas BatchNormalization
x = GlobalAveragePooling2D()(x)
x = Dropout(0.3)(x)
predictions = Dense(7, activation='softmax')(x)
model = tf.keras.Model(inputs, predictions, name=nomeDoModelo)

# %%
model.summary()
# Out:
# Model: "EfficientNetB2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         [(None, 448, 448, 3)]     0
# _________________________________________________________________
# data_augmentation (Sequentia (None, 448, 448, 3)       0
# _________________________________________________________________
# efficientnetb2 (Functional)  (None, 14, 14, 1408)      7768569
# _________________________________________________________________
# global_average_pooling2d (Gl (None, 1408)              0
# _________________________________________________________________
# dropout (Dropout)            (None, 1408)              0
# _________________________________________________________________
# dense (Dense)                (None, 7)                 9863
# =================================================================
# Total params: 7,778,432
# Trainable params: 9,863
# Non-trainable params: 7,768,569
# _________________________________________________________________

# %% [markdown]
# ### 3.1.1. Buscando a taxa de aprendizado: LRFinder 1

# %%
optimizer = tf.keras.optimizers.Adam()
loss_fn = tf.keras.losses.CategoricalCrossentropy()

# %%
lr_find = LrFinder(model, optimizer, loss_fn)
lr_find.range_test(train_ds)
lr_find.plot_lrs(suggestion=True, show_grid=True)
# Out:
# Finding best initial lr over 100 steps
#   0%|          | 0/100 [00:00<?, ?it/s]
# LR Finder is complete, type {LrFinder}.plot_lrs() to see the graph.
# Min numerical gradient: 9.12E-03
# Min loss divided by 10: 5.75E-03

# %%
base_lr = 5e-03

# %% [markdown]
# ### 3.1.2. Treinando

# %%
model.compile(optimizer=Adam(learning_rate= base_lr), 
              loss=tf.keras.losses.CategoricalCrossentropy(), 
              metrics=metricasEscolhidas)

# %%
history = model.fit(train_ds,
                    class_weight = weights_train_dict,
                    steps_per_epoch = train_steps,
                    epochs=first_epoch,
                    validation_data=val_ds,
                    validation_steps = val_steps)
# Out:
# Epoch 1/30
# 557/557 [==============================] - 442s 778ms/step - loss: 8.4364 - acc: 0.3439 - auc: 0.7695 - precision: 0.3889 - recall: 0.2289 - val_loss: 1.0260 - val_acc: 0.6156 - val_auc: 0.9118 - val_precision: 0.6832 - val_recall: 0.5258
# Epoch 2/30
# 557/557 [==============================] - 73s 130ms/step - loss: 7.5496 - acc: 0.4191 - auc: 0.8110 - precision: 0.4642 - recall: 0.3344 - val_loss: 1.1905 - val_acc: 0.5694 - val_auc: 0.8890 - val_precision: 0.6085 - val_recall: 0.4778
# Epoch 3/30
# 557/557 [==============================] - 73s 131ms/step - loss: 7.1971 - acc: 0.4422 - auc: 0.8247 - precision: 0.4889 - recall: 0.3721 - val_loss: 1.1243 - val_acc: 0.5839 - val_auc: 0.9007 - val_precision: 0.6406 - val_recall: 0.5122
# Epoch 4/30
# 557/557 [==============================] - 73s 131ms/step - loss: 6.8531 - acc: 0.4632 - auc: 0.8382 - precision: 0.5070 - recall: 0.3918 - val_loss: 1.1692 - val_acc: 0.6020 - val_auc: 0.8943 - val_precision: 0.6527 - val_recall: 0.5095
# Epoch 5/30
# 557/557 [==============================] - 73s 130ms/step - loss: 6.9662 - acc: 0.4467 - auc: 0.8321 - precision: 0.4817 - recall: 0.3789 - val_loss: 1.1953 - val_acc: 0.5367 - val_auc: 0.8959 - val_precision: 0.5580 - val_recall: 0.4796
# Epoch 6/30
# 557/557 [==============================] - 73s 130ms/step - loss: 6.9342 - acc: 0.4538 - auc: 0.8317 - precision: 0.4901 - recall: 0.3974 - val_loss: 1.2295 - val_acc: 0.5639 - val_auc: 0.8852 - val_precision: 0.6256 - val_recall: 0.4968
# Epoch 7/30
# 557/557 [==============================] - 73s 130ms/step - loss: 7.1573 - acc: 0.4463 - auc: 0.8342 - precision: 0.4811 - recall: 0.3913 - val_loss: 1.2139 - val_acc: 0.5920 - val_auc: 0.8932 - val_precision: 0.6178 - val_recall: 0.5277
# Epoch 8/30
# 557/557 [==============================] - 73s 130ms/step - loss: 7.1280 - acc: 0.4526 - auc: 0.8319 - precision: 0.4898 - recall: 0.4000 - val_loss: 0.9465 - val_acc: 0.6854 - val_auc: 0.9314 - val_precision: 0.7216 - val_recall: 0.6673
# Epoch 9/30
# 557/557 [==============================] - 73s 130ms/step - loss: 7.1377 - acc: 0.4624 - auc: 0.8397 - precision: 0.5003 - recall: 0.4146 - val_loss: 0.8284 - val_acc: 0.7298 - val_auc: 0.9437 - val_precision: 0.7654 - val_recall: 0.6981
# Epoch 10/30
# 557/557 [==============================] - 73s 131ms/step - loss: 7.0595 - acc: 0.4558 - auc: 0.8408 - precision: 0.4927 - recall: 0.4094 - val_loss: 1.0370 - val_acc: 0.6383 - val_auc: 0.9189 - val_precision: 0.6763 - val_recall: 0.5911
# Epoch 11/30
# 557/557 [==============================] - 73s 130ms/step - loss: 6.8322 - acc: 0.4737 - auc: 0.8501 - precision: 0.5050 - recall: 0.4238 - val_loss: 1.1641 - val_acc: 0.5884 - val_auc: 0.9031 - val_precision: 0.6188 - val_recall: 0.5431
# Epoch 12/30
# 557/557 [==============================] - 73s 130ms/step - loss: 6.8474 - acc: 0.4595 - auc: 0.8452 - precision: 0.4929 - recall: 0.4116 - val_loss: 1.1503 - val_acc: 0.6047 - val_auc: 0.9043 - val_precision: 0.6361 - val_recall: 0.5721
# Epoch 13/30
# 557/557 [==============================] - 73s 130ms/step - loss: 7.1611 - acc: 0.4597 - auc: 0.8392 - precision: 0.4858 - recall: 0.4118 - val_loss: 0.8475 - val_acc: 0.7271 - val_auc: 0.9429 - val_precision: 0.7593 - val_recall: 0.7035
# Epoch 14/30
# 557/557 [==============================] - 73s 130ms/step - loss: 6.7676 - acc: 0.4800 - auc: 0.8512 - precision: 0.5098 - recall: 0.4302 - val_loss: 0.7213 - val_acc: 0.7480 - val_auc: 0.9567 - val_precision: 0.7811 - val_recall: 0.7117
# Epoch 15/30
# 557/557 [==============================] - 73s 130ms/step - loss: 7.0662 - acc: 0.4678 - auc: 0.8445 - precision: 0.4974 - recall: 0.4219 - val_loss: 0.9868 - val_acc: 0.6491 - val_auc: 0.9245 - val_precision: 0.6837 - val_recall: 0.6056
# Epoch 16/30
# 557/557 [==============================] - 73s 130ms/step - loss: 7.0943 - acc: 0.4566 - auc: 0.8415 - precision: 0.4870 - recall: 0.4129 - val_loss: 1.1192 - val_acc: 0.6083 - val_auc: 0.9103 - val_precision: 0.6451 - val_recall: 0.5703
# Epoch 17/30
# 557/557 [==============================] - 73s 130ms/step - loss: 6.8928 - acc: 0.4671 - auc: 0.8430 - precision: 0.4991 - recall: 0.4209 - val_loss: 1.5388 - val_acc: 0.5014 - val_auc: 0.8549 - val_precision: 0.5428 - val_recall: 0.4597
# Epoch 18/30
# 557/557 [==============================] - 72s 129ms/step - loss: 6.8998 - acc: 0.4800 - auc: 0.8460 - precision: 0.5114 - recall: 0.4386 - val_loss: 1.0203 - val_acc: 0.6618 - val_auc: 0.9212 - val_precision: 0.6957 - val_recall: 0.6219
# Epoch 19/30
# 557/557 [==============================] - 72s 128ms/step - loss: 7.0817 - acc: 0.4748 - auc: 0.8497 - precision: 0.5028 - recall: 0.4302 - val_loss: 0.9543 - val_acc: 0.6963 - val_auc: 0.9304 - val_precision: 0.7223 - val_recall: 0.6627
# Epoch 20/30
# 557/557 [==============================] - 72s 128ms/step - loss: 6.8479 - acc: 0.4714 - auc: 0.8465 - precision: 0.4982 - recall: 0.4227 - val_loss: 0.9013 - val_acc: 0.7063 - val_auc: 0.9391 - val_precision: 0.7334 - val_recall: 0.6709
# Epoch 21/30
# 557/557 [==============================] - 72s 129ms/step - loss: 7.2258 - acc: 0.4585 - auc: 0.8418 - precision: 0.4891 - recall: 0.4157 - val_loss: 1.8581 - val_acc: 0.4025 - val_auc: 0.8304 - val_precision: 0.4018 - val_recall: 0.3690
# Epoch 22/30
# 557/557 [==============================] - 72s 129ms/step - loss: 6.9374 - acc: 0.4666 - auc: 0.8432 - precision: 0.4925 - recall: 0.4191 - val_loss: 0.7827 - val_acc: 0.7380 - val_auc: 0.9494 - val_precision: 0.7702 - val_recall: 0.7081
# Epoch 23/30
# 557/557 [==============================] - 72s 128ms/step - loss: 7.0397 - acc: 0.4622 - auc: 0.8435 - precision: 0.4875 - recall: 0.4194 - val_loss: 0.8643 - val_acc: 0.7153 - val_auc: 0.9434 - val_precision: 0.7322 - val_recall: 0.6890
# Epoch 24/30
# 557/557 [==============================] - 72s 129ms/step - loss: 6.8429 - acc: 0.4744 - auc: 0.8488 - precision: 0.5037 - recall: 0.4333 - val_loss: 1.1128 - val_acc: 0.6636 - val_auc: 0.9200 - val_precision: 0.6836 - val_recall: 0.6464
# Epoch 25/30
# 557/557 [==============================] - 72s 128ms/step - loss: 6.9944 - acc: 0.4659 - auc: 0.8475 - precision: 0.4901 - recall: 0.4218 - val_loss: 1.0876 - val_acc: 0.6256 - val_auc: 0.9163 - val_precision: 0.6572 - val_recall: 0.5857
# Epoch 26/30
# 557/557 [==============================] - 72s 128ms/step - loss: 6.9382 - acc: 0.4773 - auc: 0.8491 - precision: 0.5022 - recall: 0.4351 - val_loss: 1.3191 - val_acc: 0.5476 - val_auc: 0.8909 - val_precision: 0.5662 - val_recall: 0.5041
# Epoch 27/30
# 557/557 [==============================] - 72s 128ms/step - loss: 6.9120 - acc: 0.4762 - auc: 0.8487 - precision: 0.5025 - recall: 0.4358 - val_loss: 0.8901 - val_acc: 0.6981 - val_auc: 0.9393 - val_precision: 0.7259 - val_recall: 0.6745
# Epoch 28/30
# 557/557 [==============================] - 72s 128ms/step - loss: 6.9633 - acc: 0.4814 - auc: 0.8515 - precision: 0.5106 - recall: 0.4393 - val_loss: 0.7054 - val_acc: 0.7489 - val_auc: 0.9584 - val_precision: 0.7825 - val_recall: 0.7307
# Epoch 29/30
# 557/557 [==============================] - 72s 129ms/step - loss: 6.9419 - acc: 0.4711 - auc: 0.8503 - precision: 0.4992 - recall: 0.4292 - val_loss: 1.1558 - val_acc: 0.5938 - val_auc: 0.9029 - val_precision: 0.6238 - val_recall: 0.5413
# Epoch 30/30
# 557/557 [==============================] - 72s 128ms/step - loss: 7.0821 - acc: 0.4687 - auc: 0.8435 - precision: 0.4980 - recall: 0.4298 - val_loss: 1.1865 - val_acc: 0.5848 - val_auc: 0.9009 - val_precision: 0.6006 - val_recall: 0.5440

# %% [markdown]
# ### 3.1.3. Avaliando o treinamento do modelo

# %%
acc = history.history['acc']
val_acc = history.history['val_acc']

loss = history.history['loss']
val_loss = history.history['val_loss']

plt.figure(figsize=(8, 8))
plt.subplot(2, 1, 1)
plt.plot(acc, label='Acuracia do treinamento')
plt.plot(val_acc, label='Acuracia da validação')
plt.legend(loc='lower right')
plt.ylabel('Acuracia')
plt.ylim([0,1])
plt.title('Acuracia do treinamento e validação')

plt.subplot(2, 1, 2)
plt.plot(loss, label='Perda do treinamento')
plt.plot(val_loss, label='Perda da validação')
plt.legend(loc='upper right')
plt.ylabel('Entropia Cruzada')
plt.ylim([0,8])
plt.title('Perda do treinamento e validação')
plt.xlabel('epoca')
plt.show()

# %% [markdown]
# ## 3.2. Criando o modelo: Segundo Momento

# %%
modelBase.trainable = True # Descongelando os pesos do modelo base para o treinamento

# %%
model.summary()
# Out:
# Model: "EfficientNetB2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         [(None, 448, 448, 3)]     0
# _________________________________________________________________
# data_augmentation (Sequentia (None, 448, 448, 3)       0
# _________________________________________________________________
# efficientnetb2 (Functional)  (None, 14, 14, 1408)      7768569
# _________________________________________________________________
# global_average_pooling2d (Gl (None, 1408)              0
# _________________________________________________________________
# dropout (Dropout)            (None, 1408)              0
# _________________________________________________________________
# dense (Dense)                (None, 7)                 9863
# =================================================================
# Total params: 7,778,432
# Trainable params: 7,710,857
# Non-trainable params: 67,575
# _________________________________________________________________

# %% [markdown]
# ### 3.2.1. Buscando a taxa de aprendizado: LRFinder 2

# %%
optimizer = tf.keras.optimizers.Adam()
loss_fn = tf.keras.losses.CategoricalCrossentropy()

# %%
lr_find = LrFinder(model, optimizer, loss_fn)
lr_find.range_test(train_ds)
lr_find.plot_lrs(suggestion=True, show_grid=True)
# Out:
# Finding best initial lr over 100 steps
#   0%|          | 0/100 [00:00<?, ?it/s]
# LR Finder is complete, type {LrFinder}.plot_lrs() to see the graph.
# Min numerical gradient: 1.20E-05
# Min loss divided by 10: 7.59E-06

# %%
base_lr = 5e-6
max_lr = 1e-5

# %% [markdown]
# ### 3.2.2. Definindo os Callbacks

# %% [markdown]
# #### 3.2.2.1. CyclicalLR

# %%
step_size = train_steps
clr = CyclicalLR(max_lr=max_lr, 
                 base_lr=base_lr, 
                 step_size=step_size, 
                 cyclical_momentum=False)

# %% [markdown]
# #### 3.2.2.2. Checkpoint

# %%
# salva os melhores modelos para o callback
def get_model_name(k):
    return str(nomeDoModelo)+'_folder_'+ str(k)+'.h5'

# %%
checkpoint = ModelCheckpoint(save_dir+get_model_name(fold_var),
                                                  monitor='val_auc', verbose=1,
                                                  save_best_only=True, mode='max')

# %% [markdown]
# #### 3.2.2.3. Earlystopping

# %%
earlystopping = EarlyStopping(monitor='val_loss',
                              verbose=1, mode='min', 
                              restore_best_weights=False,
                              patience=15)

# %%
# Lista contendo todos os callbacks
callbacks_list = [checkpoint, earlystopping, clr]

# %% [markdown]
# ### 3.2.3. Treinando

# %%
model.compile(optimizer=Adam(learning_rate=base_lr), 
              loss=tf.keras.losses.CategoricalCrossentropy(), 
              metrics=metricasEscolhidas)

# %%
history_fine = model.fit(train_ds,
                    class_weight = weights_train_dict,
                    steps_per_epoch = train_steps,
                    epochs=second_epoch,
                    initial_epoch=history.epoch[-1],
                    validation_data=val_ds,
                    validation_steps = val_steps,
                    callbacks = callbacks_list)
# Out:
# Epoch 30/100
#   6/557 [..............................] - ETA: 6:39 - loss: 6.5920 - acc: 0.5855 - auc: 0.9000 - precision: 0.5994 - recall: 0.5405WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.2748s vs `on_train_batch_end` time: 0.3757s). Check your callbacks.
# 557/557 [==============================] - 424s 739ms/step - loss: 5.7256 - acc: 0.5331 - auc: 0.8816 - precision: 0.5634 - recall: 0.4798 - val_loss: 0.8954 - val_acc: 0.6763 - val_auc: 0.9338 - val_precision: 0.7159 - val_recall: 0.6192
#
# Epoch 00030: val_auc improved from -inf to 0.93378, saving model to /content/drive/MyDrive/TCC-Melo/Kaggle/modelos_checkPoint/EfficientNetB2_folder_4.h5
# /usr/local/lib/python3.7/dist-packages/keras/utils/generic_utils.py:497: CustomMaskWarning:
#
# Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
# Epoch 31/100
# 557/557 [==============================] - 411s 737ms/step - loss: 4.9428 - acc: 0.5349 - auc: 0.8899 - precision: 0.5735 - recall: 0.4861 - val_loss: 0.8375 - val_acc: 0.6945 - val_auc: 0.9418 - val_precision: 0.7281 - val_recall: 0.6482
#
# Epoch 00031: val_auc improved from 0.93378 to 0.94179, saving model to /content/drive/MyDrive/TCC-Melo/Kaggle/modelos_checkPoint/EfficientNetB2_folder_4.h5
# Epoch 32/100
# 557/557 [==============================] - 410s 736ms/step - loss: 4.3636 - acc: 0.5582 - auc: 0.9022 - precision: 0.5982 - recall: 0.5088 - val_loss: 0.7402 - val_acc: 0.7280 - val_auc: 0.9544 - val_precision: 0.7574 - val_recall: 0.6963
#
# Epoch 00032: val_auc improved from 0.94179 to 0.95444, saving model to /content/drive/MyDrive/TCC-Melo/Kaggle/modelos_checkPoint/EfficientNetB2_folder_4.h5
# Epoch 33/100
# 557/557 [==============================] - 410s 735ms/step - loss: 4.1909 - acc: 0.5820 - auc: 0.9106 - precision: 0.6168 - recall: 0.5377 - val_loss: 0.7045 - val_acc: 0.7307 - val_auc: 0.9594 - val_precision: 0.7642 - val_recall: 0.7081
#
# Epoch 00033: val_auc improved from 0.95444 to 0.95935, saving model to /content/drive/MyDrive/TCC-Melo/Kaggle/modelos_checkPoint/EfficientNetB2_folder_4.h5
# Epoch 34/100
# 557/557 [==============================] - 405s 727ms/step - loss: 3.8000 - acc: 0.6038 - auc: 0.9200 - precision: 0.6365 - recall: 0.5605 - val_loss: 0.6348 - val_acc: 0.7688 - val_auc: 0.9658 - val_precision: 0.7959 - val_recall: 0.7425
#
# Epoch 00034: val_auc improved from 0.95935 to 0.96579, saving model to /content/drive/MyDrive/TCC-Melo/Kaggle/modelos_checkPoint/EfficientNetB2_folder_4.h5
# Epoch 35/100
# 557/557 [==============================] - 404s 725ms/step - loss: 3.5484 - acc: 0.6100 - auc: 0.9224 - precision: 0.6461 - recall: 0.5667 - val_loss: 0.6661 - val_acc: 0.7570 - val_auc: 0.9628 - val_precision: 0.7870 - val_recall: 0.7335
#
# Epoch 00035: val_auc did not improve from 0.96579
# Epoch 36/100
# 557/557 [==============================] - 411s 737ms/step - loss: 3.3193 - acc: 0.6325 - auc: 0.9308 - precision: 0.6643 - recall: 0.5937 - val_loss: 0.7188 - val_acc: 0.7307 - val_auc: 0.9574 - val_precision: 0.7605 - val_recall: 0.7081
#
# Epoch 00036: val_auc did not improve from 0.96579
# Epoch 37/100
# 557/557 [==============================] - 407s 731ms/step - loss: 3.2774 - acc: 0.6290 - auc: 0.9312 - precision: 0.6617 - recall: 0.5923 - val_loss: 0.6205 - val_acc: 0.7779 - val_auc: 0.9677 - val_precision: 0.8033 - val_recall: 0.7588
#
# Epoch 00037: val_auc improved from 0.96579 to 0.96772, saving model to /content/drive/MyDrive/TCC-Melo/Kaggle/modelos_checkPoint/EfficientNetB2_folder_4.h5
# Epoch 38/100
# 557/557 [==============================] - 410s 735ms/step - loss: 3.0173 - acc: 0.6574 - auc: 0.9393 - precision: 0.6878 - recall: 0.6211 - val_loss: 0.6239 - val_acc: 0.7761 - val_auc: 0.9678 - val_precision: 0.8046 - val_recall: 0.7579
#
# Epoch 00038: val_auc improved from 0.96772 to 0.96783, saving model to /content/drive/MyDrive/TCC-Melo/Kaggle/modelos_checkPoint/EfficientNetB2_folder_4.h5
# Epoch 39/100
# 557/557 [==============================] - 407s 730ms/step - loss: 2.8693 - acc: 0.6676 - auc: 0.9426 - precision: 0.6973 - recall: 0.6344 - val_loss: 0.6496 - val_acc: 0.7643 - val_auc: 0.9647 - val_precision: 0.7940 - val_recall: 0.7407
#
# Epoch 00039: val_auc did not improve from 0.96783
# Epoch 40/100
# 557/557 [==============================] - 409s 735ms/step - loss: 2.7401 - acc: 0.6784 - auc: 0.9436 - precision: 0.7055 - recall: 0.6431 - val_loss: 0.7340 - val_acc: 0.7398 - val_auc: 0.9580 - val_precision: 0.7615 - val_recall: 0.7235
#
# Epoch 00040: val_auc did not improve from 0.96783
# Epoch 41/100
# 557/557 [==============================] - 408s 732ms/step - loss: 2.4670 - acc: 0.6923 - auc: 0.9496 - precision: 0.7210 - recall: 0.6655 - val_loss: 0.6143 - val_acc: 0.7897 - val_auc: 0.9697 - val_precision: 0.8151 - val_recall: 0.7715
#
# Epoch 00041: val_auc improved from 0.96783 to 0.96968, saving model to /content/drive/MyDrive/TCC-Melo/Kaggle/modelos_checkPoint/EfficientNetB2_folder_4.h5
# Epoch 42/100
# 557/557 [==============================] - 408s 732ms/step - loss: 2.4697 - acc: 0.7084 - auc: 0.9544 - precision: 0.7345 - recall: 0.6826 - val_loss: 0.5805 - val_acc: 0.7869 - val_auc: 0.9720 - val_precision: 0.8175 - val_recall: 0.7715
#
# Epoch 00042: val_auc improved from 0.96968 to 0.97197, saving model to /content/drive/MyDrive/TCC-Melo/Kaggle/modelos_checkPoint/EfficientNetB2_folder_4.h5
# Epoch 43/100
# 557/557 [==============================] - 410s 735ms/step - loss: 2.1956 - acc: 0.7173 - auc: 0.9569 - precision: 0.7444 - recall: 0.6949 - val_loss: 0.5544 - val_acc: 0.8042 - val_auc: 0.9745 - val_precision: 0.8265 - val_recall: 0.7906
#
# Epoch 00043: val_auc improved from 0.97197 to 0.97447, saving model to /content/drive/MyDrive/TCC-Melo/Kaggle/modelos_checkPoint/EfficientNetB2_folder_4.h5
# Epoch 44/100
# 557/557 [==============================] - 410s 735ms/step - loss: 2.1915 - acc: 0.7176 - auc: 0.9570 - precision: 0.7403 - recall: 0.6946 - val_loss: 0.4941 - val_acc: 0.8250 - val_auc: 0.9784 - val_precision: 0.8430 - val_recall: 0.8132
#
# Epoch 00044: val_auc improved from 0.97447 to 0.97842, saving model to /content/drive/MyDrive/TCC-Melo/Kaggle/modelos_checkPoint/EfficientNetB2_folder_4.h5
# Epoch 45/100
# 557/557 [==============================] - 406s 728ms/step - loss: 2.1714 - acc: 0.7289 - auc: 0.9605 - precision: 0.7516 - recall: 0.7040 - val_loss: 0.6091 - val_acc: 0.7897 - val_auc: 0.9696 - val_precision: 0.8119 - val_recall: 0.7788
#
# Epoch 00045: val_auc did not improve from 0.97842
# Epoch 46/100
# 557/557 [==============================] - 409s 733ms/step - loss: 2.0895 - acc: 0.7354 - auc: 0.9611 - precision: 0.7590 - recall: 0.7124 - val_loss: 0.6837 - val_acc: 0.7616 - val_auc: 0.9633 - val_precision: 0.7785 - val_recall: 0.7489
#
# Epoch 00046: val_auc did not improve from 0.97842
# Epoch 47/100
# 557/557 [==============================] - 405s 727ms/step - loss: 2.0340 - acc: 0.7421 - auc: 0.9640 - precision: 0.7654 - recall: 0.7233 - val_loss: 0.4822 - val_acc: 0.8296 - val_auc: 0.9800 - val_precision: 0.8430 - val_recall: 0.8132
#
# Epoch 00047: val_auc improved from 0.97842 to 0.97999, saving model to /content/drive/MyDrive/TCC-Melo/Kaggle/modelos_checkPoint/EfficientNetB2_folder_4.h5
# Epoch 48/100
# 557/557 [==============================] - 405s 726ms/step - loss: 1.8977 - acc: 0.7490 - auc: 0.9644 - precision: 0.7706 - recall: 0.7306 - val_loss: 0.5316 - val_acc: 0.8196 - val_auc: 0.9765 - val_precision: 0.8318 - val_recall: 0.8024
#
# Epoch 00048: val_auc did not improve from 0.97999
# Epoch 49/100
# 557/557 [==============================] - 408s 731ms/step - loss: 1.8695 - acc: 0.7550 - auc: 0.9666 - precision: 0.7761 - recall: 0.7379 - val_loss: 0.5397 - val_acc: 0.8187 - val_auc: 0.9761 - val_precision: 0.8389 - val_recall: 0.7978
#
# Epoch 00049: val_auc did not improve from 0.97999
# Epoch 50/100
# 557/557 [==============================] - 408s 732ms/step - loss: 1.7240 - acc: 0.7704 - auc: 0.9689 - precision: 0.7903 - recall: 0.7501 - val_loss: 0.5616 - val_acc: 0.8033 - val_auc: 0.9736 - val_precision: 0.8186 - val_recall: 0.7897
#
# Epoch 00050: val_auc did not improve from 0.97999
# Epoch 51/100
# 557/557 [==============================] - 403s 723ms/step - loss: 1.6934 - acc: 0.7681 - auc: 0.9699 - precision: 0.7881 - recall: 0.7508 - val_loss: 0.5389 - val_acc: 0.8105 - val_auc: 0.9758 - val_precision: 0.8311 - val_recall: 0.7987
#
# Epoch 00051: val_auc did not improve from 0.97999
# Epoch 52/100
# 557/557 [==============================] - 409s 734ms/step - loss: 1.5495 - acc: 0.7924 - auc: 0.9735 - precision: 0.8079 - recall: 0.7749 - val_loss: 0.5372 - val_acc: 0.8196 - val_auc: 0.9757 - val_precision: 0.8338 - val_recall: 0.8096
#
# Epoch 00052: val_auc did not improve from 0.97999
# Epoch 53/100
# 557/557 [==============================] - 404s 725ms/step - loss: 1.4732 - acc: 0.8039 - auc: 0.9755 - precision: 0.8203 - recall: 0.7876 - val_loss: 0.4588 - val_acc: 0.8468 - val_auc: 0.9813 - val_precision: 0.8577 - val_recall: 0.8359
#
# Epoch 00053: val_auc improved from 0.97999 to 0.98130, saving model to /content/drive/MyDrive/TCC-Melo/Kaggle/modelos_checkPoint/EfficientNetB2_folder_4.h5
# Epoch 54/100
# 557/557 [==============================] - 408s 731ms/step - loss: 1.4682 - acc: 0.8003 - auc: 0.9751 - precision: 0.8155 - recall: 0.7880 - val_loss: 0.6056 - val_acc: 0.7996 - val_auc: 0.9698 - val_precision: 0.8122 - val_recall: 0.7842
#
# Epoch 00054: val_auc did not improve from 0.98130
# Epoch 55/100
# 557/557 [==============================] - 404s 724ms/step - loss: 1.3873 - acc: 0.8085 - auc: 0.9768 - precision: 0.8237 - recall: 0.7915 - val_loss: 0.5206 - val_acc: 0.8323 - val_auc: 0.9768 - val_precision: 0.8429 - val_recall: 0.8223
#
# Epoch 00055: val_auc did not improve from 0.98130
# Epoch 56/100
# 557/557 [==============================] - 406s 729ms/step - loss: 1.2982 - acc: 0.8116 - auc: 0.9785 - precision: 0.8286 - recall: 0.7976 - val_loss: 0.4396 - val_acc: 0.8495 - val_auc: 0.9829 - val_precision: 0.8633 - val_recall: 0.8413
#
# Epoch 00056: val_auc improved from 0.98130 to 0.98288, saving model to /content/drive/MyDrive/TCC-Melo/Kaggle/modelos_checkPoint/EfficientNetB2_folder_4.h5
# Epoch 57/100
# 557/557 [==============================] - 404s 725ms/step - loss: 1.2377 - acc: 0.8265 - auc: 0.9801 - precision: 0.8413 - recall: 0.8142 - val_loss: 0.4708 - val_acc: 0.8459 - val_auc: 0.9800 - val_precision: 0.8591 - val_recall: 0.8350
#
# Epoch 00057: val_auc did not improve from 0.98288
# Epoch 58/100
# 557/557 [==============================] - 407s 730ms/step - loss: 1.2819 - acc: 0.8273 - auc: 0.9801 - precision: 0.8413 - recall: 0.8158 - val_loss: 0.4724 - val_acc: 0.8422 - val_auc: 0.9797 - val_precision: 0.8561 - val_recall: 0.8359
#
# Epoch 00058: val_auc did not improve from 0.98288
# Epoch 59/100
# 557/557 [==============================] - 407s 730ms/step - loss: 1.1643 - acc: 0.8342 - auc: 0.9814 - precision: 0.8467 - recall: 0.8227 - val_loss: 0.4772 - val_acc: 0.8549 - val_auc: 0.9793 - val_precision: 0.8655 - val_recall: 0.8459
#
# Epoch 00059: val_auc did not improve from 0.98288
# Epoch 60/100
# 557/557 [==============================] - 407s 731ms/step - loss: 1.1265 - acc: 0.8382 - auc: 0.9827 - precision: 0.8490 - recall: 0.8278 - val_loss: 0.5624 - val_acc: 0.8286 - val_auc: 0.9739 - val_precision: 0.8373 - val_recall: 0.8214
#
# Epoch 00060: val_auc did not improve from 0.98288
# Epoch 61/100
# 557/557 [==============================] - 408s 731ms/step - loss: 1.0752 - acc: 0.8452 - auc: 0.9841 - precision: 0.8577 - recall: 0.8355 - val_loss: 0.4837 - val_acc: 0.8531 - val_auc: 0.9782 - val_precision: 0.8668 - val_recall: 0.8495
#
# Epoch 00061: val_auc did not improve from 0.98288
# Epoch 62/100
# 557/557 [==============================] - 406s 729ms/step - loss: 1.0301 - acc: 0.8499 - auc: 0.9839 - precision: 0.8611 - recall: 0.8398 - val_loss: 0.6030 - val_acc: 0.8368 - val_auc: 0.9703 - val_precision: 0.8436 - val_recall: 0.8314
#
# Epoch 00062: val_auc did not improve from 0.98288
# Epoch 63/100
# 557/557 [==============================] - 403s 723ms/step - loss: 1.0154 - acc: 0.8527 - auc: 0.9844 - precision: 0.8644 - recall: 0.8437 - val_loss: 0.4458 - val_acc: 0.8694 - val_auc: 0.9816 - val_precision: 0.8740 - val_recall: 0.8613
#
# Epoch 00063: val_auc did not improve from 0.98288
# Epoch 64/100
# 557/557 [==============================] - 408s 732ms/step - loss: 0.9675 - acc: 0.8583 - auc: 0.9855 - precision: 0.8694 - recall: 0.8513 - val_loss: 0.4554 - val_acc: 0.8568 - val_auc: 0.9815 - val_precision: 0.8654 - val_recall: 0.8513
#
# Epoch 00064: val_auc did not improve from 0.98288
# Epoch 65/100
# 557/557 [==============================] - 407s 730ms/step - loss: 0.8598 - acc: 0.8743 - auc: 0.9873 - precision: 0.8823 - recall: 0.8660 - val_loss: 0.5031 - val_acc: 0.8540 - val_auc: 0.9783 - val_precision: 0.8612 - val_recall: 0.8495
#
# Epoch 00065: val_auc did not improve from 0.98288
# Epoch 66/100
# 557/557 [==============================] - 408s 732ms/step - loss: 0.9204 - acc: 0.8654 - auc: 0.9867 - precision: 0.8744 - recall: 0.8577 - val_loss: 0.5459 - val_acc: 0.8441 - val_auc: 0.9741 - val_precision: 0.8512 - val_recall: 0.8350
#
# Epoch 00066: val_auc did not improve from 0.98288
# Epoch 67/100
# 557/557 [==============================] - 408s 732ms/step - loss: 0.8130 - acc: 0.8740 - auc: 0.9878 - precision: 0.8851 - recall: 0.8656 - val_loss: 0.5360 - val_acc: 0.8477 - val_auc: 0.9756 - val_precision: 0.8525 - val_recall: 0.8386
#
# Epoch 00067: val_auc did not improve from 0.98288
# Epoch 68/100
# 557/557 [==============================] - 409s 734ms/step - loss: 0.8179 - acc: 0.8846 - auc: 0.9884 - precision: 0.8917 - recall: 0.8766 - val_loss: 0.4653 - val_acc: 0.8586 - val_auc: 0.9795 - val_precision: 0.8641 - val_recall: 0.8531
#
# Epoch 00068: val_auc did not improve from 0.98288
# Epoch 69/100
# 557/557 [==============================] - 408s 732ms/step - loss: 0.7362 - acc: 0.8871 - auc: 0.9899 - precision: 0.8961 - recall: 0.8806 - val_loss: 0.5041 - val_acc: 0.8676 - val_auc: 0.9760 - val_precision: 0.8695 - val_recall: 0.8577
#
# Epoch 00069: val_auc did not improve from 0.98288
# Epoch 70/100
# 557/557 [==============================] - 403s 724ms/step - loss: 0.7907 - acc: 0.8861 - auc: 0.9895 - precision: 0.8939 - recall: 0.8795 - val_loss: 0.4635 - val_acc: 0.8713 - val_auc: 0.9798 - val_precision: 0.8755 - val_recall: 0.8667
#
# Epoch 00070: val_auc did not improve from 0.98288
# Epoch 71/100
# 557/557 [==============================] - 406s 728ms/step - loss: 0.6805 - acc: 0.8921 - auc: 0.9908 - precision: 0.8990 - recall: 0.8852 - val_loss: 0.5049 - val_acc: 0.8658 - val_auc: 0.9779 - val_precision: 0.8710 - val_recall: 0.8631
#
# Epoch 00071: val_auc did not improve from 0.98288
# Epoch 00071: early stopping

# %% [markdown]
# ### 3.2.4. Avaliando o treinamento do modelo

# %%
acc += history_fine.history['acc']
val_acc += history_fine.history['val_acc']

loss += history_fine.history['loss']
val_loss += history_fine.history['val_loss']

# %%
plt.figure(figsize=(8, 8))
plt.subplot(2, 1, 1)
plt.plot(acc, label='Acuracia de treinamento')
plt.plot(val_acc, label='Acuracia de validação')
plt.ylim([0, 1])
plt.plot([first_epoch-1,first_epoch-1],
          plt.ylim(), label='Começo do Fine Tuning')
plt.legend(loc='lower right')
plt.title('Acuracia do treinamento e validação')

plt.subplot(2, 1, 2)
plt.plot(loss, label='Perda do treinamento')
plt.plot(val_loss, label='Perda da validação')
plt.ylim([0, 8])
plt.plot([first_epoch-1,first_epoch-1],
         plt.ylim(), label='Começo do Fine Tuning')
plt.legend(loc='upper right')
plt.title('Perda do treinamento e validação')
plt.xlabel('epoca')
plt.show()

# %% [markdown]
# #### 3.2.4.1. Verificando CLR

# %%
clr.plot_lr((14, 3.5))

# %% [markdown]
# # 4. Avaliando o modelo

# %%
model.load_weights(save_dir + str(nomeDoModelo)+'_folder_'+ str(fold_var)+'.h5')
# model_all = tf.keras.models.load_model(save_dir + str(nomeDoModelo)+'_folder_'+ str(fold_var)+'.h5')

# %%
model.evaluate(val_ds)
# Out:
# 69/69 [==============================] - 7s 107ms/step - loss: 0.4396 - acc: 0.8495 - auc: 0.9829 - precision: 0.8633 - recall: 0.8413
# [0.43955567479133606,
#  0.849501371383667,
#  0.9828786849975586,
#  0.8632557988166809,
#  0.8413417935371399]

# %% [markdown]
# ## 4.1. Realizando as previsões

# %%
# Obtendo a tabela verdade 
true_categories = tf.concat([y for x, y in val_ds], axis=0)
true_categories  = tf.argmax(true_categories , axis=1)

# %%
# Realizando as previsões
predictions = model.predict(val_ds, verbose=1)
y_pred = tf.argmax(predictions, axis=1)
# Out:
# 69/69 [==============================] - 8s 93ms/step

# %% [markdown]
# ## 4.3. Metricas de avaliação

# %% [markdown]
# ### 4.3.1. Quadro de metricas

# %%
cm_plot_labels = ['akiec', 'bcc', 'bkl', 'df', 'mel','nv', 'vasc']
print(classification_report(true_categories , y_pred, target_names=cm_plot_labels))
# Out:
#               precision    recall  f1-score   support
#
#        akiec       0.81      0.55      0.65        31
#          bcc       0.77      0.77      0.77        35
#          bkl       0.60      0.77      0.68        88
#           df       0.86      0.75      0.80         8
#          mel       0.27      0.80      0.41        46
#           nv       0.99      0.87      0.93       883
#         vasc       1.00      0.92      0.96        12
#
#     accuracy                           0.85      1103
#    macro avg       0.76      0.78      0.74      1103
# weighted avg       0.91      0.85      0.87      1103

# %% [markdown]
# ### 4.3.2. Matriz de confusão

# %%
cm = confusion_matrix(true_categories , y_pred)
fig, ax = plot_confusion_matrix(conf_mat=cm,
                                show_absolute=True,
                                show_normed=True, 
                                class_names=cm_plot_labels)

# %% [markdown]
# ### 4.3.3. Acurácia balanceada

# %%
bAcc= sklearn.metrics.balanced_accuracy_score(true_categories, y_pred)
print(f'Acurácia balanceada: {bAcc*100:.6f}%')
# Out:
# Acurácia balanceada: 77.667387%
