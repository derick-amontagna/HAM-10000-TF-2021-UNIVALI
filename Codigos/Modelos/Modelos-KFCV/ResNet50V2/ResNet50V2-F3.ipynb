# %% [markdown]
# # 1. Comando Iniciais

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ## 1.1. Importando Bibliotecas

# %%
# !pip install mlxtend --upgrade --no-deps # Versão do Mlxtend: 0.19.0
# Out:
# Requirement already satisfied: mlxtend in /usr/local/lib/python3.7/dist-packages (0.14.0)
# Collecting mlxtend
#   Downloading mlxtend-0.19.0-py2.py3-none-any.whl (1.3 MB)
#      |████████████████████████████████| 1.3 MB 4.3 MB/s
# Installing collected packages: mlxtend
#   Attempting uninstall: mlxtend
#     Found existing installation: mlxtend 0.14.0
#     Uninstalling mlxtend-0.14.0:
#       Successfully uninstalled mlxtend-0.14.0
# Successfully installed mlxtend-0.19.0

# %%
import numpy as np
import pandas as pd

import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
import plotly 
import plotly.express as px

import tensorflow as tf
from tensorflow.keras.layers import Dense, Dropout, Conv2D, Flatten, GlobalAveragePooling2D, Input
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.preprocessing import image_dataset_from_directory
from tensorflow.keras.models import Model
from tensorflow.keras.callbacks import ReduceLROnPlateau, ModelCheckpoint, EarlyStopping
from tensorflow.keras.metrics import CategoricalAccuracy, AUC, Precision, Recall
from tensorflow import keras

import sklearn
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import confusion_matrix, classification_report

import mlxtend
from mlxtend.plotting import plot_confusion_matrix

import itertools

import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# %%
# Utility Script - Criados dentro do Kaggle Code, devido ao fato que são modulo customizados 
# %cd /content/drive/MyDrive/TCC-Melo/Kaggle/
from lrfinder import *
from cyclicallr import *
# Out:
# /content/drive/MyDrive/TCC-Melo/Kaggle

# %% [markdown]
# ### 1.1.1. Demostrando versões das bibliotecas

# %%
print(f'Versão do Numpy: {np.__version__}')
print(f'Versão do Pandas: {pd.__version__}')
print(f'Versão do Matplotlib: {mpl.__version__}')
print(f'Versão do Season: {sns.__version__}')
print(f'Versão do Plotly: {plotly.__version__}')
print(f'Versão do TensorFlow: {tf.__version__}')
print(f'Versão do Keras: {keras.__version__}')
print(f'Versão do Sklearn: {sklearn.__version__}')
print(f'Versão do Mlxtend: {mlxtend.__version__}')
# Out:
# Versão do Numpy: 1.19.5
# Versão do Pandas: 1.1.5
# Versão do Matplotlib: 3.2.2
# Versão do Season: 0.11.2
# Versão do Plotly: 4.4.1
# Versão do TensorFlow: 2.6.0
# Versão do Keras: 2.6.0
# Versão do Sklearn: 0.22.2.post1
# Versão do Mlxtend: 0.19.0

# %% [markdown]
# ## 1.2. Verificando Accelerator

# %%
gpu_info = !nvidia-smi
gpu_info = '\n'.join(gpu_info)
if gpu_info.find('failed') >= 0:
  print('Not connected to a GPU')
else:
  print(gpu_info)
# Out:
# Fri Oct  1 22:43:45 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 470.74       Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   35C    P0    27W / 250W |      0MiB / 16280MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
gpus = tf.config.list_physical_devices('GPU')
for gpu in gpus:
    print("Name:", gpu.name, "  Type:", gpu.device_type)
tf.test.is_gpu_available()
# Out:
# Name: /physical_device:GPU:0   Type: GPU
# WARNING:tensorflow:From <ipython-input-8-f99a3e65d632>:4: is_gpu_available (from tensorflow.python.framework.test_util) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.config.list_physical_devices('GPU')` instead.
# True

# %% [markdown]
# ## 1.3. Variaveis Globais

# %%
# Caminho para salvar os melhores modelos do callback checkpoint
save_dir = '/content/drive/MyDrive/TCC-Melo/Kaggle/modelos_checkPoint/'

# Caminho dos Folds
fold_var = 3 # Folder selecionado

train_path = f'/content/drive/MyDrive/TCC-Melo/Dados/Folds_Modified/fold_{fold_var}/train_dir'    # Imagens em JPG separadas em folders
valid_path = f'/content/drive/MyDrive/TCC-Melo/Dados/Folds_Modified/fold_{fold_var}/val_dir'    # Imagens em JPG separadas em folders

# Ordem das categorias
classes = ['AKIEC', 'BCC', 'BKL', 'DF', 'MEL', 'NV', 'VASC']
#         [0      , 1    , 2    , 3   , 4    , 5   , 6]

# Tamanho da batch
batch_size = 16

# Dimensão das imagens de entrada
image_size = (448, 448)

# Numero de epochs
## Primeiro Momento:
first_epoch = 30

## Segundo Momento:
second_epoch = first_epoch + 70

# Calculando os passos para o treinamento
train_steps = np.ceil(8912 / batch_size)
val_steps = np.ceil(1103 / batch_size)

# Carregando os pesos para as categorias para o treinamento 
weights_train_dict = {0: 15, 1: 10, 2: 5, 3: 42,
                      4: 20, 5: 1, 6: 35}

# %% [markdown]
# ## 1.4. Metricas de avaliação

# %%
metricasEscolhidas = [CategoricalAccuracy(name='acc'), 
                      AUC(name='auc'),
                      Precision(name='precision'), 
                      Recall(name='recall')]

# %% [markdown]
# ## 1.5. Carregando os dados

# %% [markdown]
#  ### 1.5.1. Treinamento

# %%
train_ds = image_dataset_from_directory(train_path,
                                        batch_size=batch_size,
                                        image_size = image_size,
                                        label_mode='categorical',
                                        shuffle=True,
                                        seed=42)
# Out:
# Found 8912 files belonging to 7 classes.

# %%
val_ds = image_dataset_from_directory(valid_path,
                                      batch_size=batch_size,
                                      image_size = image_size,
                                      label_mode='categorical',
                                      shuffle=False,
                                      seed=42)
# Out:
# Found 1103 files belonging to 7 classes.

# %% [markdown]
# #### 1.5.1.1. Alta velocidade de treinamento

# %%
for image_batch, labels_batch in train_ds:
  print(image_batch.shape)
  print(labels_batch.shape)
  break
# Out:
# (16, 448, 448, 3)
# (16, 7)

# %%
AUTOTUNE = tf.data.AUTOTUNE

#train_ds = train_ds.cache().prefetch(buffer_size=AUTOTUNE)
train_ds = train_ds.prefetch(buffer_size=AUTOTUNE)
#val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.prefetch(buffer_size=AUTOTUNE)

# %% [markdown]
# ## 1.6. Modelo Pré-treinado

# %%
num_model = 4

# %% [markdown]
# ### 1.6.1. Selecionando modelo

# %%
if num_model == 1:
    nomeDoModelo = 'DenseNet121'
    modelo = tf.keras.applications.DenseNet121(weights='imagenet', 
                                               include_top=False, 
                                               input_tensor=Input(shape=image_size+(3,)))
elif num_model == 2:
    nomeDoModelo = 'DenseNet169'
    modelo = tf.keras.applications.DenseNet169(weights='imagenet', 
                                               include_top=False, 
                                               input_tensor=Input(shape=image_size+(3,)))
elif num_model == 3:
    nomeDoModelo = 'DenseNet201'
    modelo = tf.keras.applications.DenseNet201(weights='imagenet', 
                                               include_top=False, 
                                               input_tensor=Input(shape=image_size+(3,)))
elif num_model == 4:
    nomeDoModelo = 'ResNet50V2'
    modelo = tf.keras.applications.ResNet50V2(weights='imagenet', 
                                               include_top=False, 
                                               input_tensor=Input(shape=image_size+(3,)))
elif num_model == 5:
    nomeDoModelo = 'ResNet101V2'
    modelo = tf.keras.applications.ResNet101V2(weights='imagenet', 
                                               include_top=False, 
                                               input_tensor=Input(shape=image_size+(3,)))
elif num_model == 6:
    nomeDoModelo = 'ResNet152V2'
    modelo = tf.keras.applications.ResNet152V2(weights='imagenet', 
                                               include_top=False, 
                                               input_tensor=Input(shape=image_size+(3,)))
elif num_model == 7:
    nomeDoModelo = 'Xception'
    modelo = tf.keras.applications.Xception(weights='imagenet', 
                                               include_top=False, 
                                               input_tensor=Input(shape=image_size+(3,)))
elif num_model == 8:
    nomeDoModelo = 'InceptionV3'
    modelo = tf.keras.applications.InceptionV3(weights='imagenet', 
                                               include_top=False, 
                                               input_tensor=Input(shape=image_size+(3,)))
elif num_model == 9:
    nomeDoModelo = 'InceptionResNetV2'
    modelo = tf.keras.applications.InceptionResNetV2(weights='imagenet', 
                                               include_top=False, 
                                               input_tensor=Input(shape=image_size+(3,)))
elif num_model == 10:
    nomeDoModelo = 'EfficientNetB0'
    modelo = tf.keras.applications.EfficientNetB0(weights='imagenet', 
                                               include_top=False, 
                                               input_tensor=Input(shape=image_size+(3,)))
elif num_model == 11:
    nomeDoModelo = 'EfficientNetB1'
    modelo = tf.keras.applications.EfficientNetB1(weights='imagenet', 
                                               include_top=False, 
                                               input_tensor=Input(shape=image_size+(3,)))
elif num_model == 12:
    nomeDoModelo = 'EfficientNetB2'
    modelo = tf.keras.applications.EfficientNetB2(weights='imagenet', 
                                               include_top=False, 
                                               input_tensor=Input(shape=image_size+(3,)))
elif num_model == 13:
    nomeDoModelo = 'EfficientNetB3'
    modelo = tf.keras.applications.EfficientNetB3(weights='imagenet', 
                                               include_top=False, 
                                               input_tensor=Input(shape=image_size+(3,)))
    
print(f'O modelo selecionado foi {nomeDoModelo}')
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50v2_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94674944/94668760 [==============================] - 3s 0us/step
# 94683136/94668760 [==============================] - 3s 0us/step
# O modelo selecionado foi ResNet50V2

# %% [markdown]
# # 2. Preprocessamento

# %% [markdown]
# ## 2.1. Camada de aumento de dados

# %%
camada_ad = tf.keras.Sequential([
  tf.keras.layers.experimental.preprocessing.RandomFlip('horizontal'),
  tf.keras.layers.experimental.preprocessing.RandomFlip('vertical'),
  tf.keras.layers.experimental.preprocessing.RandomRotation(0.3),
  tf.keras.layers.experimental.preprocessing.RandomContrast((0.8, 1.1)),
], name='data_augmentation')

# %% [markdown]
# ## 2.2. Camada de reescalonamento

# %%
if num_model in [1, 2, 3]:
    camada_reescal = tf.keras.applications.densenet.preprocess_input
elif num_model in [4, 5, 6]:
    camada_reescal = tf.keras.applications.resnet_v2.preprocess_input
elif num_model == 7:
    camada_reescal = tf.keras.applications.xception.preprocess_input
elif num_model == 8:
    camada_reescal = tf.keras.applications.inception_v3.preprocess_input
elif num_model == 9:
    camada_reescal = tf.keras.applications.inception_resnet_v2.preprocess_input
elif num_model in [10, 11, 12, 13]:
    camada_reescal = tf.keras.applications.efficientnet.preprocess_input
    
print(f'A camada selecionada foi {camada_reescal}')
# Out:
# A camada selecionada foi <function preprocess_input at 0x7fa17ca86710>

# %% [markdown]
# # 3. Classificação

# %% [markdown]
# ## 3.1. Criando o modelo: Primeiro Momento

# %%
modelBase = modelo

modelBase.trainable = False # Congelando os pesos do modelo base

inputs = tf.keras.Input(shape=image_size+(3,))
x = camada_ad(inputs)
x = camada_reescal(x)
x = modelBase(x, training=False) # Deixando o modelo em modo enferência por causa das camadas BatchNormalization
x = GlobalAveragePooling2D()(x)
x = Dropout(0.3)(x)
predictions = Dense(7, activation='softmax')(x)
model = tf.keras.Model(inputs, predictions, name=nomeDoModelo)

# %%
model.summary()
# Out:
# Model: "ResNet50V2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         [(None, 448, 448, 3)]     0
# _________________________________________________________________
# data_augmentation (Sequentia (None, 448, 448, 3)       0
# _________________________________________________________________
# tf.math.truediv (TFOpLambda) (None, 448, 448, 3)       0
# _________________________________________________________________
# tf.math.subtract (TFOpLambda (None, 448, 448, 3)       0
# _________________________________________________________________
# resnet50v2 (Functional)      (None, 14, 14, 2048)      23564800
# _________________________________________________________________
# global_average_pooling2d (Gl (None, 2048)              0
# _________________________________________________________________
# dropout (Dropout)            (None, 2048)              0
# _________________________________________________________________
# dense (Dense)                (None, 7)                 14343
# =================================================================
# Total params: 23,579,143
# Trainable params: 14,343
# Non-trainable params: 23,564,800
# _________________________________________________________________

# %% [markdown]
# ### 3.1.1. Buscando a taxa de aprendizado: LRFinder 1

# %%
optimizer = tf.keras.optimizers.Adam()
loss_fn = tf.keras.losses.CategoricalCrossentropy()

# %%
lr_find = LrFinder(model, optimizer, loss_fn)
lr_find.range_test(train_ds)
lr_find.plot_lrs(suggestion=True, show_grid=True)
# Out:
# Finding best initial lr over 100 steps
#   0%|          | 0/100 [00:00<?, ?it/s]
# LR Finder is complete, type {LrFinder}.plot_lrs() to see the graph.
# Min numerical gradient: 1.00E-03
# Min loss divided by 10: 5.75E-03

# %%
base_lr = 1e-03

# %% [markdown]
# ### 3.1.2. Treinando

# %%
model.compile(optimizer=Adam(learning_rate= base_lr), 
              loss=tf.keras.losses.CategoricalCrossentropy(), 
              metrics=metricasEscolhidas)

# %%
history = model.fit(train_ds,
                    class_weight = weights_train_dict,
                    steps_per_epoch = train_steps,
                    epochs=first_epoch,
                    validation_data=val_ds,
                    validation_steps = val_steps)
# Out:
# Epoch 1/30
# 557/557 [==============================] - 1012s 2s/step - loss: 8.0323 - acc: 0.3204 - auc: 0.7554 - precision: 0.3572 - recall: 0.1783 - val_loss: 1.0963 - val_acc: 0.5712 - val_auc: 0.9002 - val_precision: 0.6354 - val_recall: 0.3998
# Epoch 2/30
# 557/557 [==============================] - 66s 118ms/step - loss: 6.6497 - acc: 0.4137 - auc: 0.8247 - precision: 0.4716 - recall: 0.2865 - val_loss: 0.9444 - val_acc: 0.6455 - val_auc: 0.9258 - val_precision: 0.7395 - val_recall: 0.5122
# Epoch 3/30
# 557/557 [==============================] - 66s 118ms/step - loss: 6.2243 - acc: 0.4401 - auc: 0.8388 - precision: 0.4968 - recall: 0.3232 - val_loss: 1.0595 - val_acc: 0.5911 - val_auc: 0.9071 - val_precision: 0.6442 - val_recall: 0.4941
# Epoch 4/30
# 557/557 [==============================] - 66s 118ms/step - loss: 5.9649 - acc: 0.4629 - auc: 0.8508 - precision: 0.5236 - recall: 0.3597 - val_loss: 0.9603 - val_acc: 0.6419 - val_auc: 0.9226 - val_precision: 0.7387 - val_recall: 0.5177
# Epoch 5/30
# 557/557 [==============================] - 66s 117ms/step - loss: 5.9788 - acc: 0.4679 - auc: 0.8515 - precision: 0.5159 - recall: 0.3650 - val_loss: 1.0519 - val_acc: 0.5875 - val_auc: 0.9073 - val_precision: 0.6421 - val_recall: 0.4733
# Epoch 6/30
# 557/557 [==============================] - 66s 117ms/step - loss: 5.7456 - acc: 0.4840 - auc: 0.8580 - precision: 0.5369 - recall: 0.3833 - val_loss: 1.1982 - val_acc: 0.5204 - val_auc: 0.8858 - val_precision: 0.5486 - val_recall: 0.4397
# Epoch 7/30
# 557/557 [==============================] - 66s 117ms/step - loss: 5.6762 - acc: 0.4979 - auc: 0.8663 - precision: 0.5467 - recall: 0.3995 - val_loss: 0.8996 - val_acc: 0.6573 - val_auc: 0.9320 - val_precision: 0.7340 - val_recall: 0.5830
# Epoch 8/30
# 557/557 [==============================] - 66s 117ms/step - loss: 5.4030 - acc: 0.4947 - auc: 0.8637 - precision: 0.5423 - recall: 0.4018 - val_loss: 0.8856 - val_acc: 0.6727 - val_auc: 0.9339 - val_precision: 0.7512 - val_recall: 0.5775
# Epoch 9/30
# 557/557 [==============================] - 66s 117ms/step - loss: 5.5615 - acc: 0.5021 - auc: 0.8695 - precision: 0.5562 - recall: 0.4201 - val_loss: 1.1224 - val_acc: 0.5730 - val_auc: 0.8985 - val_precision: 0.6311 - val_recall: 0.4887
# Epoch 10/30
# 557/557 [==============================] - 66s 117ms/step - loss: 5.4738 - acc: 0.4988 - auc: 0.8674 - precision: 0.5464 - recall: 0.4171 - val_loss: 1.0065 - val_acc: 0.6192 - val_auc: 0.9177 - val_precision: 0.6641 - val_recall: 0.5431
# Epoch 11/30
# 557/557 [==============================] - 66s 117ms/step - loss: 5.3644 - acc: 0.5073 - auc: 0.8725 - precision: 0.5529 - recall: 0.4243 - val_loss: 0.7161 - val_acc: 0.7253 - val_auc: 0.9571 - val_precision: 0.8042 - val_recall: 0.6664
# Epoch 12/30
# 557/557 [==============================] - 66s 117ms/step - loss: 5.5817 - acc: 0.5134 - auc: 0.8725 - precision: 0.5585 - recall: 0.4328 - val_loss: 0.8796 - val_acc: 0.6564 - val_auc: 0.9349 - val_precision: 0.7283 - val_recall: 0.5784
# Epoch 13/30
# 557/557 [==============================] - 66s 117ms/step - loss: 5.3901 - acc: 0.4976 - auc: 0.8690 - precision: 0.5465 - recall: 0.4206 - val_loss: 1.0127 - val_acc: 0.6219 - val_auc: 0.9177 - val_precision: 0.6536 - val_recall: 0.5612
# Epoch 14/30
# 557/557 [==============================] - 66s 117ms/step - loss: 5.3788 - acc: 0.5071 - auc: 0.8716 - precision: 0.5570 - recall: 0.4276 - val_loss: 0.9593 - val_acc: 0.6446 - val_auc: 0.9238 - val_precision: 0.6878 - val_recall: 0.5712
# Epoch 15/30
# 557/557 [==============================] - 66s 117ms/step - loss: 5.3455 - acc: 0.4971 - auc: 0.8669 - precision: 0.5391 - recall: 0.4217 - val_loss: 0.7401 - val_acc: 0.7208 - val_auc: 0.9537 - val_precision: 0.7891 - val_recall: 0.6582
# Epoch 16/30
# 557/557 [==============================] - 66s 118ms/step - loss: 5.5571 - acc: 0.4976 - auc: 0.8707 - precision: 0.5430 - recall: 0.4248 - val_loss: 0.7691 - val_acc: 0.7180 - val_auc: 0.9500 - val_precision: 0.7907 - val_recall: 0.6510
# Epoch 17/30
# 557/557 [==============================] - 66s 117ms/step - loss: 5.3361 - acc: 0.5038 - auc: 0.8726 - precision: 0.5439 - recall: 0.4295 - val_loss: 0.8995 - val_acc: 0.6491 - val_auc: 0.9313 - val_precision: 0.7028 - val_recall: 0.5875
# Epoch 18/30
# 557/557 [==============================] - 66s 117ms/step - loss: 5.2680 - acc: 0.5155 - auc: 0.8767 - precision: 0.5611 - recall: 0.4410 - val_loss: 0.7359 - val_acc: 0.7171 - val_auc: 0.9542 - val_precision: 0.7790 - val_recall: 0.6646
# Epoch 19/30
# 557/557 [==============================] - 66s 117ms/step - loss: 5.3545 - acc: 0.5130 - auc: 0.8770 - precision: 0.5554 - recall: 0.4347 - val_loss: 0.6560 - val_acc: 0.7452 - val_auc: 0.9632 - val_precision: 0.8029 - val_recall: 0.6945
# Epoch 20/30
# 557/557 [==============================] - 66s 117ms/step - loss: 5.4689 - acc: 0.5076 - auc: 0.8743 - precision: 0.5511 - recall: 0.4378 - val_loss: 0.9401 - val_acc: 0.6283 - val_auc: 0.9276 - val_precision: 0.6574 - val_recall: 0.5811
# Epoch 21/30
# 557/557 [==============================] - 66s 117ms/step - loss: 5.0327 - acc: 0.5199 - auc: 0.8815 - precision: 0.5626 - recall: 0.4492 - val_loss: 1.2686 - val_acc: 0.5050 - val_auc: 0.8749 - val_precision: 0.5254 - val_recall: 0.3944
# Epoch 22/30
# 557/557 [==============================] - 66s 117ms/step - loss: 5.4316 - acc: 0.5062 - auc: 0.8727 - precision: 0.5459 - recall: 0.4345 - val_loss: 0.7580 - val_acc: 0.7081 - val_auc: 0.9513 - val_precision: 0.7702 - val_recall: 0.6473
# Epoch 23/30
# 557/557 [==============================] - 66s 117ms/step - loss: 5.2331 - acc: 0.5146 - auc: 0.8764 - precision: 0.5586 - recall: 0.4484 - val_loss: 0.7873 - val_acc: 0.6917 - val_auc: 0.9479 - val_precision: 0.7495 - val_recall: 0.6346
# Epoch 24/30
# 557/557 [==============================] - 66s 117ms/step - loss: 5.2248 - acc: 0.5194 - auc: 0.8771 - precision: 0.5600 - recall: 0.4458 - val_loss: 0.7949 - val_acc: 0.6936 - val_auc: 0.9468 - val_precision: 0.7445 - val_recall: 0.6500
# Epoch 25/30
# 557/557 [==============================] - 65s 117ms/step - loss: 5.2741 - acc: 0.5236 - auc: 0.8808 - precision: 0.5672 - recall: 0.4571 - val_loss: 0.7935 - val_acc: 0.7026 - val_auc: 0.9466 - val_precision: 0.7546 - val_recall: 0.6383
# Epoch 26/30
# 557/557 [==============================] - 66s 117ms/step - loss: 5.2159 - acc: 0.5128 - auc: 0.8776 - precision: 0.5554 - recall: 0.4467 - val_loss: 0.7163 - val_acc: 0.7208 - val_auc: 0.9560 - val_precision: 0.7725 - val_recall: 0.6836
# Epoch 27/30
# 557/557 [==============================] - 66s 117ms/step - loss: 5.2206 - acc: 0.5096 - auc: 0.8745 - precision: 0.5513 - recall: 0.4450 - val_loss: 1.0875 - val_acc: 0.5875 - val_auc: 0.9057 - val_precision: 0.6303 - val_recall: 0.5086
# Epoch 28/30
# 557/557 [==============================] - 66s 117ms/step - loss: 5.2704 - acc: 0.5210 - auc: 0.8781 - precision: 0.5614 - recall: 0.4506 - val_loss: 0.8142 - val_acc: 0.7026 - val_auc: 0.9444 - val_precision: 0.7417 - val_recall: 0.6455
# Epoch 29/30
# 557/557 [==============================] - 66s 117ms/step - loss: 5.2946 - acc: 0.5148 - auc: 0.8763 - precision: 0.5606 - recall: 0.4520 - val_loss: 0.7720 - val_acc: 0.7017 - val_auc: 0.9501 - val_precision: 0.7528 - val_recall: 0.6655
# Epoch 30/30
# 557/557 [==============================] - 66s 117ms/step - loss: 5.3111 - acc: 0.5183 - auc: 0.8771 - precision: 0.5612 - recall: 0.4492 - val_loss: 0.7626 - val_acc: 0.7217 - val_auc: 0.9509 - val_precision: 0.7799 - val_recall: 0.6618

# %% [markdown]
# ### 3.1.3. Avaliando o treinamento do modelo

# %%
acc = history.history['acc']
val_acc = history.history['val_acc']

loss = history.history['loss']
val_loss = history.history['val_loss']

plt.figure(figsize=(8, 8))
plt.subplot(2, 1, 1)
plt.plot(acc, label='Acuracia do treinamento')
plt.plot(val_acc, label='Acuracia da validação')
plt.legend(loc='lower right')
plt.ylabel('Acuracia')
plt.ylim([0,1])
plt.title('Acuracia do treinamento e validação')

plt.subplot(2, 1, 2)
plt.plot(loss, label='Perda do treinamento')
plt.plot(val_loss, label='Perda da validação')
plt.legend(loc='upper right')
plt.ylabel('Entropia Cruzada')
plt.ylim([0,8])
plt.title('Perda do treinamento e validação')
plt.xlabel('epoca')
plt.show()

# %% [markdown]
# ## 3.2. Criando o modelo: Segundo Momento

# %%
modelBase.trainable = True # Descongelando os pesos do modelo base para o treinamento

# %%
model.summary()
# Out:
# Model: "ResNet50V2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         [(None, 448, 448, 3)]     0
# _________________________________________________________________
# data_augmentation (Sequentia (None, 448, 448, 3)       0
# _________________________________________________________________
# tf.math.truediv (TFOpLambda) (None, 448, 448, 3)       0
# _________________________________________________________________
# tf.math.subtract (TFOpLambda (None, 448, 448, 3)       0
# _________________________________________________________________
# resnet50v2 (Functional)      (None, 14, 14, 2048)      23564800
# _________________________________________________________________
# global_average_pooling2d (Gl (None, 2048)              0
# _________________________________________________________________
# dropout (Dropout)            (None, 2048)              0
# _________________________________________________________________
# dense (Dense)                (None, 7)                 14343
# =================================================================
# Total params: 23,579,143
# Trainable params: 23,533,703
# Non-trainable params: 45,440
# _________________________________________________________________

# %% [markdown]
# ### 3.2.1. Buscando a taxa de aprendizado: LRFinder 2

# %%
optimizer = tf.keras.optimizers.Adam()
loss_fn = tf.keras.losses.CategoricalCrossentropy()

# %%
lr_find = LrFinder(model, optimizer, loss_fn)
lr_find.range_test(train_ds)
lr_find.plot_lrs(suggestion=True, show_grid=True)
# Out:
# Finding best initial lr over 100 steps
#   0%|          | 0/100 [00:00<?, ?it/s]
# LR Finder is complete, type {LrFinder}.plot_lrs() to see the graph.
# Min numerical gradient: 6.31E-07
# Min loss divided by 10: 1.45E-06

# %%
base_lr = 1e-6
max_lr = 1e-5

# %% [markdown]
# ### 3.2.2. Definindo os Callbacks

# %% [markdown]
# #### 3.2.2.1. CyclicalLR

# %%
step_size = train_steps
clr = CyclicalLR(max_lr=max_lr, 
                 base_lr=base_lr, 
                 step_size=step_size, 
                 cyclical_momentum=False)

# %% [markdown]
# #### 3.2.2.2. Checkpoint

# %%
# salva os melhores modelos para o callback
def get_model_name(k):
    return str(nomeDoModelo)+'_folder_'+ str(k)+'.h5'

# %%
checkpoint = ModelCheckpoint(save_dir+get_model_name(fold_var),
                                                  monitor='val_auc', verbose=1,
                                                  save_best_only=True, mode='max')

# %% [markdown]
# #### 3.2.2.3. Earlystopping

# %%
earlystopping = EarlyStopping(monitor='val_loss',
                              verbose=1, mode='min', 
                              restore_best_weights=False,
                              patience=15)

# %%
# Lista contendo todos os callbacks
callbacks_list = [checkpoint, earlystopping, clr]

# %% [markdown]
# ### 3.2.3. Treinando

# %%
model.compile(optimizer=Adam(learning_rate=base_lr), 
              loss=tf.keras.losses.CategoricalCrossentropy(), 
              metrics=metricasEscolhidas)

# %%
history_fine = model.fit(train_ds,
                    class_weight = weights_train_dict,
                    steps_per_epoch = train_steps,
                    epochs=second_epoch,
                    initial_epoch=history.epoch[-1],
                    validation_data=val_ds,
                    validation_steps = val_steps,
                    callbacks = callbacks_list)
# Out:
# Epoch 30/100
# 557/557 [==============================] - 188s 329ms/step - loss: 5.1252 - acc: 0.5427 - auc: 0.8907 - precision: 0.5923 - recall: 0.4690 - val_loss: 0.9719 - val_acc: 0.5875 - val_auc: 0.9197 - val_precision: 0.6182 - val_recall: 0.4977
#
# Epoch 00030: val_auc improved from -inf to 0.91968, saving model to /content/drive/MyDrive/TCC-Melo/Kaggle/modelos_checkPoint/ResNet50V2_folder_3.h5
# /usr/local/lib/python3.7/dist-packages/keras/utils/generic_utils.py:497: CustomMaskWarning:
#
# Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
# Epoch 31/100
# 557/557 [==============================] - 182s 327ms/step - loss: 4.3413 - acc: 0.5535 - auc: 0.9019 - precision: 0.6011 - recall: 0.4835 - val_loss: 0.7719 - val_acc: 0.6908 - val_auc: 0.9487 - val_precision: 0.7335 - val_recall: 0.6337
#
# Epoch 00031: val_auc improved from 0.91968 to 0.94873, saving model to /content/drive/MyDrive/TCC-Melo/Kaggle/modelos_checkPoint/ResNet50V2_folder_3.h5
# Epoch 32/100
# 557/557 [==============================] - 182s 326ms/step - loss: 3.9308 - acc: 0.5877 - auc: 0.9132 - precision: 0.6344 - recall: 0.5288 - val_loss: 0.6183 - val_acc: 0.7543 - val_auc: 0.9674 - val_precision: 0.7922 - val_recall: 0.7226
#
# Epoch 00032: val_auc improved from 0.94873 to 0.96740, saving model to /content/drive/MyDrive/TCC-Melo/Kaggle/modelos_checkPoint/ResNet50V2_folder_3.h5
# Epoch 33/100
# 557/557 [==============================] - 183s 327ms/step - loss: 3.6132 - acc: 0.5903 - auc: 0.9195 - precision: 0.6329 - recall: 0.5376 - val_loss: 0.7177 - val_acc: 0.7189 - val_auc: 0.9558 - val_precision: 0.7580 - val_recall: 0.6845
#
# Epoch 00033: val_auc did not improve from 0.96740
# Epoch 34/100
# 557/557 [==============================] - 182s 327ms/step - loss: 3.4922 - acc: 0.6102 - auc: 0.9239 - precision: 0.6471 - recall: 0.5606 - val_loss: 0.7427 - val_acc: 0.7226 - val_auc: 0.9530 - val_precision: 0.7718 - val_recall: 0.6591
#
# Epoch 00034: val_auc did not improve from 0.96740
# Epoch 35/100
# 557/557 [==============================] - 182s 327ms/step - loss: 3.4288 - acc: 0.6130 - auc: 0.9262 - precision: 0.6485 - recall: 0.5706 - val_loss: 0.6061 - val_acc: 0.7588 - val_auc: 0.9682 - val_precision: 0.7863 - val_recall: 0.7307
#
# Epoch 00035: val_auc improved from 0.96740 to 0.96816, saving model to /content/drive/MyDrive/TCC-Melo/Kaggle/modelos_checkPoint/ResNet50V2_folder_3.h5
# Epoch 36/100
# 557/557 [==============================] - 182s 327ms/step - loss: 3.0521 - acc: 0.6443 - auc: 0.9357 - precision: 0.6785 - recall: 0.6012 - val_loss: 0.6155 - val_acc: 0.7552 - val_auc: 0.9672 - val_precision: 0.7891 - val_recall: 0.7189
#
# Epoch 00036: val_auc did not improve from 0.96816
# Epoch 37/100
# 557/557 [==============================] - 182s 327ms/step - loss: 3.0075 - acc: 0.6524 - auc: 0.9382 - precision: 0.6863 - recall: 0.6174 - val_loss: 0.5639 - val_acc: 0.7779 - val_auc: 0.9728 - val_precision: 0.8119 - val_recall: 0.7552
#
# Epoch 00037: val_auc improved from 0.96816 to 0.97276, saving model to /content/drive/MyDrive/TCC-Melo/Kaggle/modelos_checkPoint/ResNet50V2_folder_3.h5
# Epoch 38/100
# 557/557 [==============================] - 182s 327ms/step - loss: 2.8013 - acc: 0.6596 - auc: 0.9425 - precision: 0.6900 - recall: 0.6241 - val_loss: 0.6162 - val_acc: 0.7661 - val_auc: 0.9677 - val_precision: 0.8085 - val_recall: 0.7235
#
# Epoch 00038: val_auc did not improve from 0.97276
# Epoch 39/100
# 557/557 [==============================] - 182s 327ms/step - loss: 2.7713 - acc: 0.6583 - auc: 0.9413 - precision: 0.6888 - recall: 0.6240 - val_loss: 0.5702 - val_acc: 0.7779 - val_auc: 0.9723 - val_precision: 0.7985 - val_recall: 0.7543
#
# Epoch 00039: val_auc did not improve from 0.97276
# Epoch 40/100
# 557/557 [==============================] - 182s 327ms/step - loss: 2.6284 - acc: 0.6736 - auc: 0.9464 - precision: 0.7018 - recall: 0.6426 - val_loss: 0.6198 - val_acc: 0.7443 - val_auc: 0.9669 - val_precision: 0.7784 - val_recall: 0.7199
#
# Epoch 00040: val_auc did not improve from 0.97276
# Epoch 41/100
# 557/557 [==============================] - 182s 327ms/step - loss: 2.5835 - acc: 0.6781 - auc: 0.9481 - precision: 0.7089 - recall: 0.6463 - val_loss: 0.5452 - val_acc: 0.7906 - val_auc: 0.9744 - val_precision: 0.8164 - val_recall: 0.7661
#
# Epoch 00041: val_auc improved from 0.97276 to 0.97438, saving model to /content/drive/MyDrive/TCC-Melo/Kaggle/modelos_checkPoint/ResNet50V2_folder_3.h5
# Epoch 42/100
# 557/557 [==============================] - 182s 327ms/step - loss: 2.3693 - acc: 0.6986 - auc: 0.9540 - precision: 0.7252 - recall: 0.6703 - val_loss: 0.5911 - val_acc: 0.7688 - val_auc: 0.9696 - val_precision: 0.8047 - val_recall: 0.7398
#
# Epoch 00042: val_auc did not improve from 0.97438
# Epoch 43/100
# 557/557 [==============================] - 182s 327ms/step - loss: 2.3331 - acc: 0.6988 - auc: 0.9532 - precision: 0.7239 - recall: 0.6724 - val_loss: 0.4799 - val_acc: 0.8123 - val_auc: 0.9794 - val_precision: 0.8275 - val_recall: 0.7960
#
# Epoch 00043: val_auc improved from 0.97438 to 0.97939, saving model to /content/drive/MyDrive/TCC-Melo/Kaggle/modelos_checkPoint/ResNet50V2_folder_3.h5
# Epoch 44/100
# 557/557 [==============================] - 182s 327ms/step - loss: 2.1265 - acc: 0.7248 - auc: 0.9589 - precision: 0.7459 - recall: 0.6988 - val_loss: 0.8220 - val_acc: 0.6854 - val_auc: 0.9458 - val_precision: 0.7093 - val_recall: 0.6591
#
# Epoch 00044: val_auc did not improve from 0.97939
# Epoch 45/100
# 557/557 [==============================] - 182s 327ms/step - loss: 2.2403 - acc: 0.7095 - auc: 0.9576 - precision: 0.7340 - recall: 0.6847 - val_loss: 0.5892 - val_acc: 0.7715 - val_auc: 0.9708 - val_precision: 0.7888 - val_recall: 0.7552
#
# Epoch 00045: val_auc did not improve from 0.97939
# Epoch 46/100
# 557/557 [==============================] - 183s 327ms/step - loss: 1.9265 - acc: 0.7380 - auc: 0.9629 - precision: 0.7565 - recall: 0.7160 - val_loss: 0.4848 - val_acc: 0.8060 - val_auc: 0.9791 - val_precision: 0.8284 - val_recall: 0.7924
#
# Epoch 00046: val_auc did not improve from 0.97939
# Epoch 47/100
# 557/557 [==============================] - 183s 327ms/step - loss: 1.8786 - acc: 0.7341 - auc: 0.9633 - precision: 0.7529 - recall: 0.7149 - val_loss: 0.4896 - val_acc: 0.8160 - val_auc: 0.9785 - val_precision: 0.8333 - val_recall: 0.8024
#
# Epoch 00047: val_auc did not improve from 0.97939
# Epoch 48/100
# 557/557 [==============================] - 182s 327ms/step - loss: 1.9360 - acc: 0.7521 - auc: 0.9650 - precision: 0.7714 - recall: 0.7319 - val_loss: 0.5451 - val_acc: 0.7888 - val_auc: 0.9738 - val_precision: 0.8179 - val_recall: 0.7697
#
# Epoch 00048: val_auc did not improve from 0.97939
# Epoch 49/100
# 557/557 [==============================] - 182s 327ms/step - loss: 1.7856 - acc: 0.7499 - auc: 0.9666 - precision: 0.7667 - recall: 0.7307 - val_loss: 0.5064 - val_acc: 0.8105 - val_auc: 0.9788 - val_precision: 0.8251 - val_recall: 0.7996
#
# Epoch 00049: val_auc did not improve from 0.97939
# Epoch 50/100
# 557/557 [==============================] - 183s 327ms/step - loss: 1.7036 - acc: 0.7584 - auc: 0.9690 - precision: 0.7748 - recall: 0.7406 - val_loss: 0.7039 - val_acc: 0.7371 - val_auc: 0.9605 - val_precision: 0.7635 - val_recall: 0.7171
#
# Epoch 00050: val_auc did not improve from 0.97939
# Epoch 51/100
# 557/557 [==============================] - 182s 327ms/step - loss: 1.7643 - acc: 0.7599 - auc: 0.9670 - precision: 0.7773 - recall: 0.7412 - val_loss: 0.5313 - val_acc: 0.8033 - val_auc: 0.9761 - val_precision: 0.8140 - val_recall: 0.7897
#
# Epoch 00051: val_auc did not improve from 0.97939
# Epoch 52/100
# 557/557 [==============================] - 182s 327ms/step - loss: 1.5890 - acc: 0.7764 - auc: 0.9709 - precision: 0.7942 - recall: 0.7595 - val_loss: 0.5568 - val_acc: 0.7797 - val_auc: 0.9728 - val_precision: 0.7991 - val_recall: 0.7679
#
# Epoch 00052: val_auc did not improve from 0.97939
# Epoch 53/100
# 557/557 [==============================] - 182s 327ms/step - loss: 1.5816 - acc: 0.7702 - auc: 0.9714 - precision: 0.7862 - recall: 0.7559 - val_loss: 0.5106 - val_acc: 0.8096 - val_auc: 0.9765 - val_precision: 0.8338 - val_recall: 0.7960
#
# Epoch 00053: val_auc did not improve from 0.97939
# Epoch 54/100
# 557/557 [==============================] - 182s 327ms/step - loss: 1.4321 - acc: 0.7870 - auc: 0.9735 - precision: 0.8030 - recall: 0.7727 - val_loss: 0.6675 - val_acc: 0.7679 - val_auc: 0.9630 - val_precision: 0.7822 - val_recall: 0.7552
#
# Epoch 00054: val_auc did not improve from 0.97939
# Epoch 55/100
# 557/557 [==============================] - 183s 327ms/step - loss: 1.6520 - acc: 0.7700 - auc: 0.9706 - precision: 0.7883 - recall: 0.7497 - val_loss: 0.5049 - val_acc: 0.8232 - val_auc: 0.9777 - val_precision: 0.8374 - val_recall: 0.8123
#
# Epoch 00055: val_auc did not improve from 0.97939
# Epoch 56/100
# 557/557 [==============================] - 182s 327ms/step - loss: 1.4006 - acc: 0.7986 - auc: 0.9772 - precision: 0.8147 - recall: 0.7852 - val_loss: 0.4815 - val_acc: 0.8350 - val_auc: 0.9798 - val_precision: 0.8468 - val_recall: 0.8268
#
# Epoch 00056: val_auc improved from 0.97939 to 0.97976, saving model to /content/drive/MyDrive/TCC-Melo/Kaggle/modelos_checkPoint/ResNet50V2_folder_3.h5
# Epoch 57/100
# 557/557 [==============================] - 183s 327ms/step - loss: 1.4753 - acc: 0.7853 - auc: 0.9742 - precision: 0.8009 - recall: 0.7697 - val_loss: 0.5734 - val_acc: 0.8015 - val_auc: 0.9709 - val_precision: 0.8102 - val_recall: 0.7897
#
# Epoch 00057: val_auc did not improve from 0.97976
# Epoch 58/100
# 557/557 [==============================] - 183s 328ms/step - loss: 1.2698 - acc: 0.8094 - auc: 0.9783 - precision: 0.8239 - recall: 0.7976 - val_loss: 0.5757 - val_acc: 0.7915 - val_auc: 0.9712 - val_precision: 0.8228 - val_recall: 0.7661
#
# Epoch 00058: val_auc did not improve from 0.97976
# Epoch 00058: early stopping

# %% [markdown]
# ### 3.2.4. Avaliando o treinamento do modelo

# %%
acc += history_fine.history['acc']
val_acc += history_fine.history['val_acc']

loss += history_fine.history['loss']
val_loss += history_fine.history['val_loss']

# %%
plt.figure(figsize=(8, 8))
plt.subplot(2, 1, 1)
plt.plot(acc, label='Acuracia de treinamento')
plt.plot(val_acc, label='Acuracia de validação')
plt.ylim([0, 1])
plt.plot([first_epoch-1,first_epoch-1],
          plt.ylim(), label='Começo do Fine Tuning')
plt.legend(loc='lower right')
plt.title('Acuracia do treinamento e validação')

plt.subplot(2, 1, 2)
plt.plot(loss, label='Perda do treinamento')
plt.plot(val_loss, label='Perda da validação')
plt.ylim([0, 8])
plt.plot([first_epoch-1,first_epoch-1],
         plt.ylim(), label='Começo do Fine Tuning')
plt.legend(loc='upper right')
plt.title('Perda do treinamento e validação')
plt.xlabel('epoca')
plt.show()

# %% [markdown]
# #### 3.2.4.1. Verificando CLR

# %%
clr.plot_lr((14, 3.5))

# %% [markdown]
# # 4. Avaliando o modelo

# %%
model.load_weights(save_dir + str(nomeDoModelo)+'_folder_'+ str(fold_var)+'.h5')
# model_all = tf.keras.models.load_model(save_dir + str(nomeDoModelo)+'_folder_'+ str(fold_var)+'.h5')

# %%
model.evaluate(val_ds)
# Out:
# 69/69 [==============================] - 7s 98ms/step - loss: 0.4815 - acc: 0.8350 - auc: 0.9798 - precision: 0.8468 - recall: 0.8268
# [0.4814920127391815,
#  0.834995448589325,
#  0.979762852191925,
#  0.8467966318130493,
#  0.8268359303474426]

# %% [markdown]
# ## 4.1. Realizando as previsões

# %%
# Obtendo a tabela verdade 
true_categories = tf.concat([y for x, y in val_ds], axis=0)
true_categories  = tf.argmax(true_categories , axis=1)

# %%
# Realizando as previsões
predictions = model.predict(val_ds, verbose=1)
y_pred = tf.argmax(predictions, axis=1)

# %% [markdown]
# ## 4.3. Metricas de avaliação

# %% [markdown]
# ### 4.3.1. Quadro de metricas

# %%
cm_plot_labels = ['akiec', 'bcc', 'bkl', 'df', 'mel','nv', 'vasc']
print(classification_report(true_categories , y_pred, target_names=cm_plot_labels))

# %% [markdown]
# ### 4.3.2. Matriz de confusão

# %%
cm = confusion_matrix(true_categories , y_pred)
fig, ax = plot_confusion_matrix(conf_mat=cm,
                                show_absolute=True,
                                show_normed=True, 
                                class_names=cm_plot_labels)

# %% [markdown]
# ### 4.3.3. Acurácia balanceada

# %%
bAcc= sklearn.metrics.balanced_accuracy_score(true_categories, y_pred)
print(f'Acurácia balanceada: {bAcc*100:.6f}%')
# Out:
# Acurácia balanceada: 72.217929%
