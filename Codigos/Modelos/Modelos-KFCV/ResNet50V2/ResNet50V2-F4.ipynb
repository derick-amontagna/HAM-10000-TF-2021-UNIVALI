# %% [markdown]
# # 1. Comando Iniciais

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## 1.1. Importando Bibliotecas

# %%
# !pip install mlxtend --upgrade --no-deps # Versão do Mlxtend: 0.19.0
# Out:
# Requirement already satisfied: mlxtend in /usr/local/lib/python3.7/dist-packages (0.14.0)
# Collecting mlxtend
#   Downloading mlxtend-0.19.0-py2.py3-none-any.whl (1.3 MB)
#      |████████████████████████████████| 1.3 MB 5.1 MB/s
# Installing collected packages: mlxtend
#   Attempting uninstall: mlxtend
#     Found existing installation: mlxtend 0.14.0
#     Uninstalling mlxtend-0.14.0:
#       Successfully uninstalled mlxtend-0.14.0
# Successfully installed mlxtend-0.19.0

# %%
import numpy as np
import pandas as pd

import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
import plotly 
import plotly.express as px

import tensorflow as tf
from tensorflow.keras.layers import Dense, Dropout, Conv2D, Flatten, GlobalAveragePooling2D, Input
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.preprocessing import image_dataset_from_directory
from tensorflow.keras.models import Model
from tensorflow.keras.callbacks import ReduceLROnPlateau, ModelCheckpoint, EarlyStopping
from tensorflow.keras.metrics import CategoricalAccuracy, AUC, Precision, Recall
from tensorflow import keras

import sklearn
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import confusion_matrix, classification_report

import mlxtend
from mlxtend.plotting import plot_confusion_matrix

import itertools

import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# %%
# Utility Script - Criados dentro do Kaggle Code, devido ao fato que são modulo customizados 
# %cd /content/drive/MyDrive/TCC-Melo/Kaggle/
from lrfinder import *
from cyclicallr import *
# Out:
# /content/drive/MyDrive/TCC-Melo/Kaggle

# %% [markdown]
# ### 1.1.1. Demostrando versões das bibliotecas

# %%
print(f'Versão do Numpy: {np.__version__}')
print(f'Versão do Pandas: {pd.__version__}')
print(f'Versão do Matplotlib: {mpl.__version__}')
print(f'Versão do Season: {sns.__version__}')
print(f'Versão do Plotly: {plotly.__version__}')
print(f'Versão do TensorFlow: {tf.__version__}')
print(f'Versão do Keras: {keras.__version__}')
print(f'Versão do Sklearn: {sklearn.__version__}')
print(f'Versão do Mlxtend: {mlxtend.__version__}')
# Out:
# Versão do Numpy: 1.19.5
# Versão do Pandas: 1.1.5
# Versão do Matplotlib: 3.2.2
# Versão do Season: 0.11.2
# Versão do Plotly: 4.4.1
# Versão do TensorFlow: 2.6.0
# Versão do Keras: 2.6.0
# Versão do Sklearn: 0.22.2.post1
# Versão do Mlxtend: 0.19.0

# %% [markdown]
# ## 1.2. Verificando Accelerator

# %%
gpu_info = !nvidia-smi
gpu_info = '\n'.join(gpu_info)
if gpu_info.find('failed') >= 0:
  print('Not connected to a GPU')
else:
  print(gpu_info)
# Out:
# Sun Oct  3 12:17:49 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 470.74       Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   46C    P0    29W / 250W |      0MiB / 16280MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
gpus = tf.config.list_physical_devices('GPU')
for gpu in gpus:
    print("Name:", gpu.name, "  Type:", gpu.device_type)
tf.test.is_gpu_available()
# Out:
# Name: /physical_device:GPU:0   Type: GPU
# WARNING:tensorflow:From <ipython-input-8-f99a3e65d632>:4: is_gpu_available (from tensorflow.python.framework.test_util) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.config.list_physical_devices('GPU')` instead.
# True

# %% [markdown]
# ## 1.3. Variaveis Globais

# %%
# Caminho para salvar os melhores modelos do callback checkpoint
save_dir = '/content/drive/MyDrive/TCC-Melo/Kaggle/modelos_checkPoint/'

# Caminho dos Folds
fold_var = 4 # Folder selecionado

train_path = f'/content/drive/MyDrive/TCC-Melo/Dados/Folds_Modified/fold_{fold_var}/train_dir'    # Imagens em JPG separadas em folders
valid_path = f'/content/drive/MyDrive/TCC-Melo/Dados/Folds_Modified/fold_{fold_var}/val_dir'    # Imagens em JPG separadas em folders

# Ordem das categorias
classes = ['AKIEC', 'BCC', 'BKL', 'DF', 'MEL', 'NV', 'VASC']
#         [0      , 1    , 2    , 3   , 4    , 5   , 6]

# Tamanho da batch
batch_size = 16

# Dimensão das imagens de entrada
image_size = (448, 448)

# Numero de epochs
## Primeiro Momento:
first_epoch = 30

## Segundo Momento:
second_epoch = first_epoch + 70

# Calculando os passos para o treinamento
train_steps = np.ceil(8912 / batch_size)
val_steps = np.ceil(1103 / batch_size)

# Carregando os pesos para as categorias para o treinamento 
weights_train_dict = {0: 15, 1: 10, 2: 5, 3: 42,
                      4: 20, 5: 1, 6: 35}

# %% [markdown]
# ## 1.4. Metricas de avaliação

# %%
metricasEscolhidas = [CategoricalAccuracy(name='acc'), 
                      AUC(name='auc'),
                      Precision(name='precision'), 
                      Recall(name='recall')]

# %% [markdown]
# ## 1.5. Carregando os dados

# %% [markdown]
#  ### 1.5.1. Treinamento

# %%
train_ds = image_dataset_from_directory(train_path,
                                        batch_size=batch_size,
                                        image_size = image_size,
                                        label_mode='categorical',
                                        shuffle=True,
                                        seed=42)
# Out:
# Found 8912 files belonging to 7 classes.

# %%
val_ds = image_dataset_from_directory(valid_path,
                                      batch_size=batch_size,
                                      image_size = image_size,
                                      label_mode='categorical',
                                      shuffle=False,
                                      seed=42)
# Out:
# Found 1103 files belonging to 7 classes.

# %% [markdown]
# #### 1.5.1.1. Alta velocidade de treinamento

# %%
for image_batch, labels_batch in train_ds:
  print(image_batch.shape)
  print(labels_batch.shape)
  break
# Out:
# (16, 448, 448, 3)
# (16, 7)

# %%
AUTOTUNE = tf.data.AUTOTUNE

#train_ds = train_ds.cache().prefetch(buffer_size=AUTOTUNE)
train_ds = train_ds.prefetch(buffer_size=AUTOTUNE)
#val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.prefetch(buffer_size=AUTOTUNE)

# %% [markdown]
# ## 1.6. Modelo Pré-treinado

# %%
num_model = 4

# %% [markdown]
# ### 1.6.1. Selecionando modelo

# %%
if num_model == 1:
    nomeDoModelo = 'DenseNet121'
    modelo = tf.keras.applications.DenseNet121(weights='imagenet', 
                                               include_top=False, 
                                               input_tensor=Input(shape=image_size+(3,)))
elif num_model == 2:
    nomeDoModelo = 'DenseNet169'
    modelo = tf.keras.applications.DenseNet169(weights='imagenet', 
                                               include_top=False, 
                                               input_tensor=Input(shape=image_size+(3,)))
elif num_model == 3:
    nomeDoModelo = 'DenseNet201'
    modelo = tf.keras.applications.DenseNet201(weights='imagenet', 
                                               include_top=False, 
                                               input_tensor=Input(shape=image_size+(3,)))
elif num_model == 4:
    nomeDoModelo = 'ResNet50V2'
    modelo = tf.keras.applications.ResNet50V2(weights='imagenet', 
                                               include_top=False, 
                                               input_tensor=Input(shape=image_size+(3,)))
elif num_model == 5:
    nomeDoModelo = 'ResNet101V2'
    modelo = tf.keras.applications.ResNet101V2(weights='imagenet', 
                                               include_top=False, 
                                               input_tensor=Input(shape=image_size+(3,)))
elif num_model == 6:
    nomeDoModelo = 'ResNet152V2'
    modelo = tf.keras.applications.ResNet152V2(weights='imagenet', 
                                               include_top=False, 
                                               input_tensor=Input(shape=image_size+(3,)))
elif num_model == 7:
    nomeDoModelo = 'Xception'
    modelo = tf.keras.applications.Xception(weights='imagenet', 
                                               include_top=False, 
                                               input_tensor=Input(shape=image_size+(3,)))
elif num_model == 8:
    nomeDoModelo = 'InceptionV3'
    modelo = tf.keras.applications.InceptionV3(weights='imagenet', 
                                               include_top=False, 
                                               input_tensor=Input(shape=image_size+(3,)))
elif num_model == 9:
    nomeDoModelo = 'InceptionResNetV2'
    modelo = tf.keras.applications.InceptionResNetV2(weights='imagenet', 
                                               include_top=False, 
                                               input_tensor=Input(shape=image_size+(3,)))
elif num_model == 10:
    nomeDoModelo = 'EfficientNetB0'
    modelo = tf.keras.applications.EfficientNetB0(weights='imagenet', 
                                               include_top=False, 
                                               input_tensor=Input(shape=image_size+(3,)))
elif num_model == 11:
    nomeDoModelo = 'EfficientNetB1'
    modelo = tf.keras.applications.EfficientNetB1(weights='imagenet', 
                                               include_top=False, 
                                               input_tensor=Input(shape=image_size+(3,)))
elif num_model == 12:
    nomeDoModelo = 'EfficientNetB2'
    modelo = tf.keras.applications.EfficientNetB2(weights='imagenet', 
                                               include_top=False, 
                                               input_tensor=Input(shape=image_size+(3,)))
elif num_model == 13:
    nomeDoModelo = 'EfficientNetB3'
    modelo = tf.keras.applications.EfficientNetB3(weights='imagenet', 
                                               include_top=False, 
                                               input_tensor=Input(shape=image_size+(3,)))
    
print(f'O modelo selecionado foi {nomeDoModelo}')
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50v2_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94674944/94668760 [==============================] - 1s 0us/step
# 94683136/94668760 [==============================] - 1s 0us/step
# O modelo selecionado foi ResNet50V2

# %% [markdown]
# # 2. Preprocessamento

# %% [markdown]
# ## 2.1. Camada de aumento de dados

# %%
camada_ad = tf.keras.Sequential([
  tf.keras.layers.experimental.preprocessing.RandomFlip('horizontal'),
  tf.keras.layers.experimental.preprocessing.RandomFlip('vertical'),
  tf.keras.layers.experimental.preprocessing.RandomRotation(0.3),
  tf.keras.layers.experimental.preprocessing.RandomContrast((0.8, 1.1)),
], name='data_augmentation')

# %% [markdown]
# ## 2.2. Camada de reescalonamento

# %%
if num_model in [1, 2, 3]:
    camada_reescal = tf.keras.applications.densenet.preprocess_input
elif num_model in [4, 5, 6]:
    camada_reescal = tf.keras.applications.resnet_v2.preprocess_input
elif num_model == 7:
    camada_reescal = tf.keras.applications.xception.preprocess_input
elif num_model == 8:
    camada_reescal = tf.keras.applications.inception_v3.preprocess_input
elif num_model == 9:
    camada_reescal = tf.keras.applications.inception_resnet_v2.preprocess_input
elif num_model in [10, 11, 12, 13]:
    camada_reescal = tf.keras.applications.efficientnet.preprocess_input
    
print(f'A camada selecionada foi {camada_reescal}')
# Out:
# A camada selecionada foi <function preprocess_input at 0x7fa534559680>

# %% [markdown]
# # 3. Classificação

# %% [markdown]
# ## 3.1. Criando o modelo: Primeiro Momento

# %%
modelBase = modelo

modelBase.trainable = False # Congelando os pesos do modelo base

inputs = tf.keras.Input(shape=image_size+(3,))
x = camada_ad(inputs)
x = camada_reescal(x)
x = modelBase(x, training=False) # Deixando o modelo em modo enferência por causa das camadas BatchNormalization
x = GlobalAveragePooling2D()(x)
x = Dropout(0.3)(x)
predictions = Dense(7, activation='softmax')(x)
model = tf.keras.Model(inputs, predictions, name=nomeDoModelo)

# %%
model.summary()
# Out:
# Model: "ResNet50V2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         [(None, 448, 448, 3)]     0
# _________________________________________________________________
# data_augmentation (Sequentia (None, 448, 448, 3)       0
# _________________________________________________________________
# tf.math.truediv (TFOpLambda) (None, 448, 448, 3)       0
# _________________________________________________________________
# tf.math.subtract (TFOpLambda (None, 448, 448, 3)       0
# _________________________________________________________________
# resnet50v2 (Functional)      (None, 14, 14, 2048)      23564800
# _________________________________________________________________
# global_average_pooling2d (Gl (None, 2048)              0
# _________________________________________________________________
# dropout (Dropout)            (None, 2048)              0
# _________________________________________________________________
# dense (Dense)                (None, 7)                 14343
# =================================================================
# Total params: 23,579,143
# Trainable params: 14,343
# Non-trainable params: 23,564,800
# _________________________________________________________________

# %% [markdown]
# ### 3.1.1. Buscando a taxa de aprendizado: LRFinder 1

# %%
optimizer = tf.keras.optimizers.Adam()
loss_fn = tf.keras.losses.CategoricalCrossentropy()

# %%
lr_find = LrFinder(model, optimizer, loss_fn)
lr_find.range_test(train_ds)
lr_find.plot_lrs(suggestion=True, show_grid=True)
# Out:
# Finding best initial lr over 100 steps
#   0%|          | 0/100 [00:00<?, ?it/s]
# LR Finder is complete, type {LrFinder}.plot_lrs() to see the graph.
# Min numerical gradient: 9.12E-03
# Min loss divided by 10: 2.29E-03

# %%
base_lr = 1e-03

# %% [markdown]
# ### 3.1.2. Treinando

# %%
model.compile(optimizer=Adam(learning_rate= base_lr), 
              loss=tf.keras.losses.CategoricalCrossentropy(), 
              metrics=metricasEscolhidas)

# %%
history = model.fit(train_ds,
                    class_weight = weights_train_dict,
                    steps_per_epoch = train_steps,
                    epochs=first_epoch,
                    validation_data=val_ds,
                    validation_steps = val_steps)
# Out:
# Epoch 1/30
# 557/557 [==============================] - 571s 1s/step - loss: 8.1573 - acc: 0.3322 - auc: 0.7579 - precision: 0.3836 - recall: 0.1922 - val_loss: 0.9053 - val_acc: 0.6854 - val_auc: 0.9354 - val_precision: 0.7815 - val_recall: 0.5222
# Epoch 2/30
# 557/557 [==============================] - 67s 120ms/step - loss: 6.7497 - acc: 0.4183 - auc: 0.8239 - precision: 0.4748 - recall: 0.2912 - val_loss: 0.9435 - val_acc: 0.6546 - val_auc: 0.9268 - val_precision: 0.7394 - val_recall: 0.5041
# Epoch 3/30
# 557/557 [==============================] - 67s 120ms/step - loss: 6.2429 - acc: 0.4480 - auc: 0.8412 - precision: 0.5103 - recall: 0.3348 - val_loss: 1.0975 - val_acc: 0.5784 - val_auc: 0.8997 - val_precision: 0.6395 - val_recall: 0.4488
# Epoch 4/30
# 557/557 [==============================] - 67s 120ms/step - loss: 6.0847 - acc: 0.4595 - auc: 0.8467 - precision: 0.5113 - recall: 0.3501 - val_loss: 0.9057 - val_acc: 0.6609 - val_auc: 0.9314 - val_precision: 0.7382 - val_recall: 0.5394
# Epoch 5/30
# 557/557 [==============================] - 67s 120ms/step - loss: 5.8258 - acc: 0.4783 - auc: 0.8577 - precision: 0.5381 - recall: 0.3768 - val_loss: 0.7861 - val_acc: 0.7162 - val_auc: 0.9486 - val_precision: 0.7974 - val_recall: 0.6029
# Epoch 6/30
# 557/557 [==============================] - 67s 120ms/step - loss: 5.8283 - acc: 0.4815 - auc: 0.8567 - precision: 0.5325 - recall: 0.3839 - val_loss: 1.1406 - val_acc: 0.5485 - val_auc: 0.8936 - val_precision: 0.6132 - val_recall: 0.4642
# Epoch 7/30
# 557/557 [==============================] - 67s 120ms/step - loss: 5.7340 - acc: 0.4905 - auc: 0.8651 - precision: 0.5406 - recall: 0.4008 - val_loss: 0.7962 - val_acc: 0.7117 - val_auc: 0.9471 - val_precision: 0.8005 - val_recall: 0.6111
# Epoch 8/30
# 557/557 [==============================] - 67s 119ms/step - loss: 5.7397 - acc: 0.4988 - auc: 0.8642 - precision: 0.5469 - recall: 0.4070 - val_loss: 0.9458 - val_acc: 0.6446 - val_auc: 0.9242 - val_precision: 0.7173 - val_recall: 0.5476
# Epoch 9/30
# 557/557 [==============================] - 67s 119ms/step - loss: 5.6477 - acc: 0.4978 - auc: 0.8650 - precision: 0.5454 - recall: 0.4078 - val_loss: 0.9397 - val_acc: 0.6482 - val_auc: 0.9254 - val_precision: 0.7073 - val_recall: 0.5521
# Epoch 10/30
# 557/557 [==============================] - 67s 120ms/step - loss: 5.5077 - acc: 0.4979 - auc: 0.8665 - precision: 0.5460 - recall: 0.4134 - val_loss: 0.9800 - val_acc: 0.6319 - val_auc: 0.9196 - val_precision: 0.6927 - val_recall: 0.5394
# Epoch 11/30
# 557/557 [==============================] - 67s 120ms/step - loss: 5.5051 - acc: 0.5077 - auc: 0.8727 - precision: 0.5579 - recall: 0.4236 - val_loss: 0.8933 - val_acc: 0.6655 - val_auc: 0.9325 - val_precision: 0.7168 - val_recall: 0.6011
# Epoch 12/30
# 557/557 [==============================] - 67s 120ms/step - loss: 5.4225 - acc: 0.5186 - auc: 0.8731 - precision: 0.5689 - recall: 0.4376 - val_loss: 0.7527 - val_acc: 0.7271 - val_auc: 0.9526 - val_precision: 0.8046 - val_recall: 0.6346
# Epoch 13/30
# 557/557 [==============================] - 67s 120ms/step - loss: 5.5613 - acc: 0.5007 - auc: 0.8680 - precision: 0.5425 - recall: 0.4202 - val_loss: 0.9587 - val_acc: 0.6328 - val_auc: 0.9233 - val_precision: 0.6916 - val_recall: 0.5612
# Epoch 14/30
# 557/557 [==============================] - 67s 119ms/step - loss: 5.4269 - acc: 0.5112 - auc: 0.8728 - precision: 0.5593 - recall: 0.4336 - val_loss: 0.9560 - val_acc: 0.6228 - val_auc: 0.9231 - val_precision: 0.6941 - val_recall: 0.5431
# Epoch 15/30
# 557/557 [==============================] - 67s 119ms/step - loss: 5.4727 - acc: 0.5007 - auc: 0.8683 - precision: 0.5467 - recall: 0.4267 - val_loss: 0.7345 - val_acc: 0.7461 - val_auc: 0.9545 - val_precision: 0.8185 - val_recall: 0.6664
# Epoch 16/30
# 557/557 [==============================] - 67s 120ms/step - loss: 5.6730 - acc: 0.5021 - auc: 0.8678 - precision: 0.5479 - recall: 0.4296 - val_loss: 0.6655 - val_acc: 0.7706 - val_auc: 0.9631 - val_precision: 0.8370 - val_recall: 0.6845
# Epoch 17/30
# 557/557 [==============================] - 67s 120ms/step - loss: 5.4131 - acc: 0.5086 - auc: 0.8727 - precision: 0.5503 - recall: 0.4320 - val_loss: 0.9064 - val_acc: 0.6510 - val_auc: 0.9308 - val_precision: 0.7073 - val_recall: 0.5739
# Epoch 18/30
# 557/557 [==============================] - 67s 120ms/step - loss: 5.3914 - acc: 0.5093 - auc: 0.8727 - precision: 0.5525 - recall: 0.4342 - val_loss: 0.8804 - val_acc: 0.6673 - val_auc: 0.9344 - val_precision: 0.7205 - val_recall: 0.5984
# Epoch 19/30
# 557/557 [==============================] - 67s 120ms/step - loss: 5.2202 - acc: 0.5105 - auc: 0.8775 - precision: 0.5574 - recall: 0.4367 - val_loss: 0.8480 - val_acc: 0.6772 - val_auc: 0.9390 - val_precision: 0.7196 - val_recall: 0.6120
# Epoch 20/30
# 557/557 [==============================] - 67s 120ms/step - loss: 5.1523 - acc: 0.5151 - auc: 0.8789 - precision: 0.5584 - recall: 0.4491 - val_loss: 0.7685 - val_acc: 0.7044 - val_auc: 0.9493 - val_precision: 0.7658 - val_recall: 0.6491
# Epoch 21/30
# 557/557 [==============================] - 67s 120ms/step - loss: 5.4375 - acc: 0.5180 - auc: 0.8756 - precision: 0.5604 - recall: 0.4458 - val_loss: 0.9144 - val_acc: 0.6437 - val_auc: 0.9304 - val_precision: 0.7004 - val_recall: 0.5893
# Epoch 22/30
# 557/557 [==============================] - 67s 119ms/step - loss: 5.2213 - acc: 0.5213 - auc: 0.8792 - precision: 0.5644 - recall: 0.4522 - val_loss: 0.7336 - val_acc: 0.7344 - val_auc: 0.9536 - val_precision: 0.8071 - val_recall: 0.6600
# Epoch 23/30
# 557/557 [==============================] - 67s 120ms/step - loss: 5.3145 - acc: 0.5120 - auc: 0.8765 - precision: 0.5568 - recall: 0.4421 - val_loss: 0.8690 - val_acc: 0.6709 - val_auc: 0.9364 - val_precision: 0.7279 - val_recall: 0.5966
# Epoch 24/30
# 557/557 [==============================] - 67s 120ms/step - loss: 5.3588 - acc: 0.5298 - auc: 0.8792 - precision: 0.5739 - recall: 0.4614 - val_loss: 0.7161 - val_acc: 0.7380 - val_auc: 0.9562 - val_precision: 0.7906 - val_recall: 0.6709
# Epoch 25/30
# 557/557 [==============================] - 67s 119ms/step - loss: 5.2933 - acc: 0.5232 - auc: 0.8779 - precision: 0.5676 - recall: 0.4550 - val_loss: 0.9552 - val_acc: 0.6292 - val_auc: 0.9251 - val_precision: 0.6775 - val_recall: 0.5657
# Epoch 26/30
# 557/557 [==============================] - 67s 120ms/step - loss: 5.3013 - acc: 0.5287 - auc: 0.8812 - precision: 0.5775 - recall: 0.4648 - val_loss: 0.9707 - val_acc: 0.6111 - val_auc: 0.9231 - val_precision: 0.6473 - val_recall: 0.5558
# Epoch 27/30
# 557/557 [==============================] - 67s 119ms/step - loss: 5.3350 - acc: 0.5176 - auc: 0.8780 - precision: 0.5598 - recall: 0.4535 - val_loss: 0.9137 - val_acc: 0.6482 - val_auc: 0.9300 - val_precision: 0.6919 - val_recall: 0.5721
# Epoch 28/30
# 557/557 [==============================] - 67s 120ms/step - loss: 5.2122 - acc: 0.5215 - auc: 0.8804 - precision: 0.5620 - recall: 0.4523 - val_loss: 0.8372 - val_acc: 0.6772 - val_auc: 0.9403 - val_precision: 0.7343 - val_recall: 0.6238
# Epoch 29/30
# 557/557 [==============================] - 67s 120ms/step - loss: 5.2159 - acc: 0.5247 - auc: 0.8811 - precision: 0.5695 - recall: 0.4565 - val_loss: 0.9253 - val_acc: 0.6292 - val_auc: 0.9292 - val_precision: 0.6792 - val_recall: 0.5739
# Epoch 30/30
# 557/557 [==============================] - 67s 120ms/step - loss: 5.2636 - acc: 0.5228 - auc: 0.8791 - precision: 0.5648 - recall: 0.4551 - val_loss: 0.8703 - val_acc: 0.6782 - val_auc: 0.9364 - val_precision: 0.7237 - val_recall: 0.6102

# %% [markdown]
# ### 3.1.3. Avaliando o treinamento do modelo

# %%
acc = history.history['acc']
val_acc = history.history['val_acc']

loss = history.history['loss']
val_loss = history.history['val_loss']

plt.figure(figsize=(8, 8))
plt.subplot(2, 1, 1)
plt.plot(acc, label='Acuracia do treinamento')
plt.plot(val_acc, label='Acuracia da validação')
plt.legend(loc='lower right')
plt.ylabel('Acuracia')
plt.ylim([0,1])
plt.title('Acuracia do treinamento e validação')

plt.subplot(2, 1, 2)
plt.plot(loss, label='Perda do treinamento')
plt.plot(val_loss, label='Perda da validação')
plt.legend(loc='upper right')
plt.ylabel('Entropia Cruzada')
plt.ylim([0,8])
plt.title('Perda do treinamento e validação')
plt.xlabel('epoca')
plt.show()

# %% [markdown]
# ## 3.2. Criando o modelo: Segundo Momento

# %%
modelBase.trainable = True # Descongelando os pesos do modelo base para o treinamento

# %%
model.summary()
# Out:
# Model: "ResNet50V2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         [(None, 448, 448, 3)]     0
# _________________________________________________________________
# data_augmentation (Sequentia (None, 448, 448, 3)       0
# _________________________________________________________________
# tf.math.truediv (TFOpLambda) (None, 448, 448, 3)       0
# _________________________________________________________________
# tf.math.subtract (TFOpLambda (None, 448, 448, 3)       0
# _________________________________________________________________
# resnet50v2 (Functional)      (None, 14, 14, 2048)      23564800
# _________________________________________________________________
# global_average_pooling2d (Gl (None, 2048)              0
# _________________________________________________________________
# dropout (Dropout)            (None, 2048)              0
# _________________________________________________________________
# dense (Dense)                (None, 7)                 14343
# =================================================================
# Total params: 23,579,143
# Trainable params: 23,533,703
# Non-trainable params: 45,440
# _________________________________________________________________

# %% [markdown]
# ### 3.2.1. Buscando a taxa de aprendizado: LRFinder 2

# %%
optimizer = tf.keras.optimizers.Adam()
loss_fn = tf.keras.losses.CategoricalCrossentropy()

# %%
lr_find = LrFinder(model, optimizer, loss_fn)
lr_find.range_test(train_ds)
lr_find.plot_lrs(suggestion=True, show_grid=True)
# Out:
# Finding best initial lr over 100 steps
#   0%|          | 0/100 [00:00<?, ?it/s]
# LR Finder is complete, type {LrFinder}.plot_lrs() to see the graph.
# Min numerical gradient: 9.12E-07
# Min loss divided by 10: 1.20E-06

# %%
base_lr = 1e-6
max_lr = 1e-5

# %% [markdown]
# ### 3.2.2. Definindo os Callbacks

# %% [markdown]
# #### 3.2.2.1. CyclicalLR

# %%
step_size = train_steps
clr = CyclicalLR(max_lr=max_lr, 
                 base_lr=base_lr, 
                 step_size=step_size, 
                 cyclical_momentum=False)

# %% [markdown]
# #### 3.2.2.2. Checkpoint

# %%
# salva os melhores modelos para o callback
def get_model_name(k):
    return str(nomeDoModelo)+'_folder_'+ str(k)+'.h5'

# %%
checkpoint = ModelCheckpoint(save_dir+get_model_name(fold_var),
                                                  monitor='val_auc', verbose=1,
                                                  save_best_only=True, mode='max')

# %% [markdown]
# #### 3.2.2.3. Earlystopping

# %%
earlystopping = EarlyStopping(monitor='val_loss',
                              verbose=1, mode='min', 
                              restore_best_weights=False,
                              patience=15)

# %%
# Lista contendo todos os callbacks
callbacks_list = [checkpoint, earlystopping, clr]

# %% [markdown]
# ### 3.2.3. Treinando

# %%
model.compile(optimizer=Adam(learning_rate=base_lr), 
              loss=tf.keras.losses.CategoricalCrossentropy(), 
              metrics=metricasEscolhidas)

# %%
history_fine = model.fit(train_ds,
                    class_weight = weights_train_dict,
                    steps_per_epoch = train_steps,
                    epochs=second_epoch,
                    initial_epoch=history.epoch[-1],
                    validation_data=val_ds,
                    validation_steps = val_steps,
                    callbacks = callbacks_list)
# Out:
# Epoch 30/100
# 557/557 [==============================] - 192s 332ms/step - loss: 5.1139 - acc: 0.5424 - auc: 0.8938 - precision: 0.5925 - recall: 0.4674 - val_loss: 0.8572 - val_acc: 0.6591 - val_auc: 0.9372 - val_precision: 0.7058 - val_recall: 0.6111
#
# Epoch 00030: val_auc improved from -inf to 0.93722, saving model to /content/drive/MyDrive/TCC-Melo/Kaggle/modelos_checkPoint/ResNet50V2_folder_4.h5
# /usr/local/lib/python3.7/dist-packages/keras/utils/generic_utils.py:497: CustomMaskWarning:
#
# Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
# Epoch 31/100
# 557/557 [==============================] - 184s 330ms/step - loss: 4.5375 - acc: 0.5402 - auc: 0.8990 - precision: 0.5879 - recall: 0.4691 - val_loss: 0.7043 - val_acc: 0.7362 - val_auc: 0.9573 - val_precision: 0.7798 - val_recall: 0.6872
#
# Epoch 00031: val_auc improved from 0.93722 to 0.95732, saving model to /content/drive/MyDrive/TCC-Melo/Kaggle/modelos_checkPoint/ResNet50V2_folder_4.h5
# Epoch 32/100
# 557/557 [==============================] - 185s 330ms/step - loss: 3.9614 - acc: 0.5768 - auc: 0.9126 - precision: 0.6160 - recall: 0.5162 - val_loss: 0.8867 - val_acc: 0.6428 - val_auc: 0.9366 - val_precision: 0.6703 - val_recall: 0.6102
#
# Epoch 00032: val_auc did not improve from 0.95732
# Epoch 33/100
# 557/557 [==============================] - 184s 330ms/step - loss: 3.8543 - acc: 0.5886 - auc: 0.9170 - precision: 0.6307 - recall: 0.5314 - val_loss: 0.6240 - val_acc: 0.7552 - val_auc: 0.9658 - val_precision: 0.7952 - val_recall: 0.7217
#
# Epoch 00033: val_auc improved from 0.95732 to 0.96585, saving model to /content/drive/MyDrive/TCC-Melo/Kaggle/modelos_checkPoint/ResNet50V2_folder_4.h5
# Epoch 34/100
# 557/557 [==============================] - 185s 330ms/step - loss: 3.3989 - acc: 0.6143 - auc: 0.9281 - precision: 0.6496 - recall: 0.5697 - val_loss: 0.5385 - val_acc: 0.7969 - val_auc: 0.9751 - val_precision: 0.8433 - val_recall: 0.7661
#
# Epoch 00034: val_auc improved from 0.96585 to 0.97510, saving model to /content/drive/MyDrive/TCC-Melo/Kaggle/modelos_checkPoint/ResNet50V2_folder_4.h5
# Epoch 35/100
# 557/557 [==============================] - 184s 330ms/step - loss: 3.3026 - acc: 0.6205 - auc: 0.9296 - precision: 0.6580 - recall: 0.5768 - val_loss: 0.6265 - val_acc: 0.7652 - val_auc: 0.9666 - val_precision: 0.7870 - val_recall: 0.7371
#
# Epoch 00035: val_auc did not improve from 0.97510
# Epoch 36/100
# 557/557 [==============================] - 184s 330ms/step - loss: 3.0728 - acc: 0.6368 - auc: 0.9345 - precision: 0.6691 - recall: 0.6002 - val_loss: 0.8005 - val_acc: 0.7099 - val_auc: 0.9472 - val_precision: 0.7528 - val_recall: 0.6627
#
# Epoch 00036: val_auc did not improve from 0.97510
# Epoch 37/100
# 557/557 [==============================] - 184s 330ms/step - loss: 3.0048 - acc: 0.6508 - auc: 0.9387 - precision: 0.6811 - recall: 0.6157 - val_loss: 0.6326 - val_acc: 0.7661 - val_auc: 0.9669 - val_precision: 0.7860 - val_recall: 0.7425
#
# Epoch 00037: val_auc did not improve from 0.97510
# Epoch 38/100
# 557/557 [==============================] - 184s 330ms/step - loss: 2.7599 - acc: 0.6700 - auc: 0.9442 - precision: 0.6976 - recall: 0.6375 - val_loss: 0.8100 - val_acc: 0.6709 - val_auc: 0.9459 - val_precision: 0.7078 - val_recall: 0.6392
#
# Epoch 00038: val_auc did not improve from 0.97510
# Epoch 39/100
# 557/557 [==============================] - 184s 330ms/step - loss: 2.8035 - acc: 0.6618 - auc: 0.9430 - precision: 0.6930 - recall: 0.6278 - val_loss: 0.5467 - val_acc: 0.8005 - val_auc: 0.9747 - val_precision: 0.8221 - val_recall: 0.7833
#
# Epoch 00039: val_auc did not improve from 0.97510
# Epoch 40/100
# 557/557 [==============================] - 184s 330ms/step - loss: 2.4711 - acc: 0.6845 - auc: 0.9505 - precision: 0.7123 - recall: 0.6556 - val_loss: 0.6358 - val_acc: 0.7480 - val_auc: 0.9647 - val_precision: 0.7689 - val_recall: 0.7208
#
# Epoch 00040: val_auc did not improve from 0.97510
# Epoch 41/100
# 557/557 [==============================] - 184s 330ms/step - loss: 2.5510 - acc: 0.6805 - auc: 0.9485 - precision: 0.7115 - recall: 0.6520 - val_loss: 0.5168 - val_acc: 0.8096 - val_auc: 0.9767 - val_precision: 0.8322 - val_recall: 0.7960
#
# Epoch 00041: val_auc improved from 0.97510 to 0.97669, saving model to /content/drive/MyDrive/TCC-Melo/Kaggle/modelos_checkPoint/ResNet50V2_folder_4.h5
# Epoch 42/100
# 557/557 [==============================] - 185s 331ms/step - loss: 2.3640 - acc: 0.6941 - auc: 0.9537 - precision: 0.7220 - recall: 0.6693 - val_loss: 0.6925 - val_acc: 0.7244 - val_auc: 0.9598 - val_precision: 0.7569 - val_recall: 0.6917
#
# Epoch 00042: val_auc did not improve from 0.97669
# Epoch 43/100
# 557/557 [==============================] - 184s 330ms/step - loss: 2.2839 - acc: 0.6993 - auc: 0.9539 - precision: 0.7255 - recall: 0.6720 - val_loss: 0.5088 - val_acc: 0.8150 - val_auc: 0.9788 - val_precision: 0.8321 - val_recall: 0.7996
#
# Epoch 00043: val_auc improved from 0.97669 to 0.97879, saving model to /content/drive/MyDrive/TCC-Melo/Kaggle/modelos_checkPoint/ResNet50V2_folder_4.h5
# Epoch 44/100
# 557/557 [==============================] - 185s 331ms/step - loss: 2.1761 - acc: 0.7151 - auc: 0.9587 - precision: 0.7401 - recall: 0.6912 - val_loss: 0.9278 - val_acc: 0.6328 - val_auc: 0.9341 - val_precision: 0.6506 - val_recall: 0.5993
#
# Epoch 00044: val_auc did not improve from 0.97879
# Epoch 45/100
# 557/557 [==============================] - 184s 330ms/step - loss: 2.4346 - acc: 0.6960 - auc: 0.9529 - precision: 0.7200 - recall: 0.6682 - val_loss: 0.5520 - val_acc: 0.8015 - val_auc: 0.9749 - val_precision: 0.8202 - val_recall: 0.7860
#
# Epoch 00045: val_auc did not improve from 0.97879
# Epoch 46/100
# 557/557 [==============================] - 184s 330ms/step - loss: 2.0287 - acc: 0.7232 - auc: 0.9605 - precision: 0.7453 - recall: 0.6992 - val_loss: 0.7871 - val_acc: 0.7271 - val_auc: 0.9522 - val_precision: 0.7410 - val_recall: 0.7081
#
# Epoch 00046: val_auc did not improve from 0.97879
# Epoch 47/100
# 557/557 [==============================] - 184s 330ms/step - loss: 1.9187 - acc: 0.7352 - auc: 0.9618 - precision: 0.7539 - recall: 0.7088 - val_loss: 0.5165 - val_acc: 0.8187 - val_auc: 0.9770 - val_precision: 0.8290 - val_recall: 0.8087
#
# Epoch 00047: val_auc did not improve from 0.97879
# Epoch 48/100
# 557/557 [==============================] - 184s 330ms/step - loss: 1.8804 - acc: 0.7453 - auc: 0.9647 - precision: 0.7656 - recall: 0.7271 - val_loss: 0.4630 - val_acc: 0.8250 - val_auc: 0.9817 - val_precision: 0.8399 - val_recall: 0.8087
#
# Epoch 00048: val_auc improved from 0.97879 to 0.98169, saving model to /content/drive/MyDrive/TCC-Melo/Kaggle/modelos_checkPoint/ResNet50V2_folder_4.h5
# Epoch 49/100
# 557/557 [==============================] - 184s 330ms/step - loss: 1.8091 - acc: 0.7448 - auc: 0.9640 - precision: 0.7659 - recall: 0.7246 - val_loss: 0.4863 - val_acc: 0.8305 - val_auc: 0.9790 - val_precision: 0.8421 - val_recall: 0.8169
#
# Epoch 00049: val_auc did not improve from 0.98169
# Epoch 50/100
# 557/557 [==============================] - 184s 330ms/step - loss: 1.7040 - acc: 0.7616 - auc: 0.9691 - precision: 0.7798 - recall: 0.7435 - val_loss: 0.7163 - val_acc: 0.7452 - val_auc: 0.9590 - val_precision: 0.7650 - val_recall: 0.7289
#
# Epoch 00050: val_auc did not improve from 0.98169
# Epoch 51/100
# 557/557 [==============================] - 184s 330ms/step - loss: 1.7912 - acc: 0.7653 - auc: 0.9676 - precision: 0.7845 - recall: 0.7462 - val_loss: 0.4501 - val_acc: 0.8259 - val_auc: 0.9826 - val_precision: 0.8462 - val_recall: 0.8178
#
# Epoch 00051: val_auc improved from 0.98169 to 0.98260, saving model to /content/drive/MyDrive/TCC-Melo/Kaggle/modelos_checkPoint/ResNet50V2_folder_4.h5
# Epoch 52/100
# 557/557 [==============================] - 185s 330ms/step - loss: 1.5534 - acc: 0.7732 - auc: 0.9710 - precision: 0.7910 - recall: 0.7565 - val_loss: 0.4966 - val_acc: 0.8060 - val_auc: 0.9786 - val_precision: 0.8267 - val_recall: 0.7869
#
# Epoch 00052: val_auc did not improve from 0.98260
# Epoch 53/100
# 557/557 [==============================] - 184s 330ms/step - loss: 1.8177 - acc: 0.7631 - auc: 0.9681 - precision: 0.7823 - recall: 0.7412 - val_loss: 0.5181 - val_acc: 0.8259 - val_auc: 0.9778 - val_precision: 0.8401 - val_recall: 0.8096
#
# Epoch 00053: val_auc did not improve from 0.98260
# Epoch 54/100
# 557/557 [==============================] - 184s 330ms/step - loss: 1.5129 - acc: 0.7915 - auc: 0.9745 - precision: 0.8104 - recall: 0.7778 - val_loss: 0.6441 - val_acc: 0.7561 - val_auc: 0.9660 - val_precision: 0.7649 - val_recall: 0.7344
#
# Epoch 00054: val_auc did not improve from 0.98260
# Epoch 55/100
# 557/557 [==============================] - 184s 330ms/step - loss: 1.4301 - acc: 0.7879 - auc: 0.9737 - precision: 0.8041 - recall: 0.7727 - val_loss: 0.4616 - val_acc: 0.8450 - val_auc: 0.9819 - val_precision: 0.8578 - val_recall: 0.8368
#
# Epoch 00055: val_auc did not improve from 0.98260
# Epoch 56/100
# 557/557 [==============================] - 184s 330ms/step - loss: 1.5541 - acc: 0.7833 - auc: 0.9736 - precision: 0.7981 - recall: 0.7676 - val_loss: 0.6252 - val_acc: 0.7733 - val_auc: 0.9688 - val_precision: 0.7893 - val_recall: 0.7643
#
# Epoch 00056: val_auc did not improve from 0.98260
# Epoch 57/100
# 557/557 [==============================] - 184s 330ms/step - loss: 1.3792 - acc: 0.7931 - auc: 0.9753 - precision: 0.8113 - recall: 0.7793 - val_loss: 0.4539 - val_acc: 0.8513 - val_auc: 0.9816 - val_precision: 0.8647 - val_recall: 0.8459
#
# Epoch 00057: val_auc did not improve from 0.98260
# Epoch 58/100
# 557/557 [==============================] - 184s 330ms/step - loss: 1.2742 - acc: 0.8108 - auc: 0.9790 - precision: 0.8227 - recall: 0.7960 - val_loss: 0.4831 - val_acc: 0.8277 - val_auc: 0.9789 - val_precision: 0.8477 - val_recall: 0.8123
#
# Epoch 00058: val_auc did not improve from 0.98260
# Epoch 59/100
# 557/557 [==============================] - 184s 330ms/step - loss: 1.4856 - acc: 0.7967 - auc: 0.9758 - precision: 0.8135 - recall: 0.7759 - val_loss: 0.4959 - val_acc: 0.8395 - val_auc: 0.9795 - val_precision: 0.8496 - val_recall: 0.8296
#
# Epoch 00059: val_auc did not improve from 0.98260
# Epoch 60/100
# 557/557 [==============================] - 185s 331ms/step - loss: 1.2400 - acc: 0.8135 - auc: 0.9789 - precision: 0.8284 - recall: 0.8006 - val_loss: 0.4987 - val_acc: 0.8359 - val_auc: 0.9779 - val_precision: 0.8384 - val_recall: 0.8232
#
# Epoch 00060: val_auc did not improve from 0.98260
# Epoch 61/100
# 557/557 [==============================] - 185s 332ms/step - loss: 1.2126 - acc: 0.8108 - auc: 0.9786 - precision: 0.8261 - recall: 0.7991 - val_loss: 0.4373 - val_acc: 0.8577 - val_auc: 0.9824 - val_precision: 0.8667 - val_recall: 0.8486
#
# Epoch 00061: val_auc did not improve from 0.98260
# Epoch 62/100
# 557/557 [==============================] - 184s 331ms/step - loss: 1.1676 - acc: 0.8261 - auc: 0.9808 - precision: 0.8383 - recall: 0.8152 - val_loss: 0.4311 - val_acc: 0.8441 - val_auc: 0.9828 - val_precision: 0.8624 - val_recall: 0.8296
#
# Epoch 00062: val_auc improved from 0.98260 to 0.98285, saving model to /content/drive/MyDrive/TCC-Melo/Kaggle/modelos_checkPoint/ResNet50V2_folder_4.h5
# Epoch 63/100
# 557/557 [==============================] - 185s 332ms/step - loss: 1.3765 - acc: 0.8117 - auc: 0.9789 - precision: 0.8267 - recall: 0.7985 - val_loss: 0.4194 - val_acc: 0.8558 - val_auc: 0.9839 - val_precision: 0.8656 - val_recall: 0.8468
#
# Epoch 00063: val_auc improved from 0.98285 to 0.98387, saving model to /content/drive/MyDrive/TCC-Melo/Kaggle/modelos_checkPoint/ResNet50V2_folder_4.h5
# Epoch 64/100
# 557/557 [==============================] - 186s 332ms/step - loss: 1.0813 - acc: 0.8354 - auc: 0.9822 - precision: 0.8480 - recall: 0.8250 - val_loss: 0.4167 - val_acc: 0.8613 - val_auc: 0.9832 - val_precision: 0.8716 - val_recall: 0.8495
#
# Epoch 00064: val_auc did not improve from 0.98387
# Epoch 65/100
# 557/557 [==============================] - 185s 331ms/step - loss: 1.3992 - acc: 0.8069 - auc: 0.9781 - precision: 0.8220 - recall: 0.7925 - val_loss: 0.4665 - val_acc: 0.8386 - val_auc: 0.9823 - val_precision: 0.8544 - val_recall: 0.8350
#
# Epoch 00065: val_auc did not improve from 0.98387
# Epoch 66/100
# 557/557 [==============================] - 185s 331ms/step - loss: 1.0593 - acc: 0.8334 - auc: 0.9828 - precision: 0.8475 - recall: 0.8242 - val_loss: 0.5562 - val_acc: 0.8169 - val_auc: 0.9721 - val_precision: 0.8348 - val_recall: 0.7969
#
# Epoch 00066: val_auc did not improve from 0.98387
# Epoch 67/100
# 557/557 [==============================] - 185s 332ms/step - loss: 1.1710 - acc: 0.8195 - auc: 0.9815 - precision: 0.8337 - recall: 0.8094 - val_loss: 0.4307 - val_acc: 0.8667 - val_auc: 0.9829 - val_precision: 0.8772 - val_recall: 0.8549
#
# Epoch 00067: val_auc did not improve from 0.98387
# Epoch 68/100
# 557/557 [==============================] - 185s 332ms/step - loss: 0.9840 - acc: 0.8440 - auc: 0.9844 - precision: 0.8560 - recall: 0.8353 - val_loss: 0.5145 - val_acc: 0.8277 - val_auc: 0.9771 - val_precision: 0.8403 - val_recall: 0.8160
#
# Epoch 00068: val_auc did not improve from 0.98387
# Epoch 69/100
# 557/557 [==============================] - 185s 331ms/step - loss: 1.1314 - acc: 0.8327 - auc: 0.9823 - precision: 0.8451 - recall: 0.8221 - val_loss: 0.4563 - val_acc: 0.8450 - val_auc: 0.9798 - val_precision: 0.8528 - val_recall: 0.8350
#
# Epoch 00069: val_auc did not improve from 0.98387
# Epoch 70/100
# 557/557 [==============================] - 185s 331ms/step - loss: 0.9985 - acc: 0.8495 - auc: 0.9848 - precision: 0.8623 - recall: 0.8407 - val_loss: 0.5065 - val_acc: 0.8314 - val_auc: 0.9775 - val_precision: 0.8422 - val_recall: 0.8178
#
# Epoch 00070: val_auc did not improve from 0.98387
# Epoch 71/100
# 557/557 [==============================] - 185s 331ms/step - loss: 1.1090 - acc: 0.8406 - auc: 0.9843 - precision: 0.8519 - recall: 0.8306 - val_loss: 0.4506 - val_acc: 0.8577 - val_auc: 0.9820 - val_precision: 0.8660 - val_recall: 0.8495
#
# Epoch 00071: val_auc did not improve from 0.98387
# Epoch 72/100
# 557/557 [==============================] - 185s 331ms/step - loss: 0.9105 - acc: 0.8618 - auc: 0.9863 - precision: 0.8714 - recall: 0.8517 - val_loss: 0.6427 - val_acc: 0.7842 - val_auc: 0.9670 - val_precision: 0.8017 - val_recall: 0.7770
#
# Epoch 00072: val_auc did not improve from 0.98387
# Epoch 73/100
# 557/557 [==============================] - 185s 331ms/step - loss: 0.9751 - acc: 0.8566 - auc: 0.9852 - precision: 0.8660 - recall: 0.8444 - val_loss: 0.4432 - val_acc: 0.8586 - val_auc: 0.9810 - val_precision: 0.8641 - val_recall: 0.8531
#
# Epoch 00073: val_auc did not improve from 0.98387
# Epoch 74/100
# 557/557 [==============================] - 185s 332ms/step - loss: 0.9412 - acc: 0.8585 - auc: 0.9874 - precision: 0.8692 - recall: 0.8485 - val_loss: 0.5441 - val_acc: 0.8069 - val_auc: 0.9735 - val_precision: 0.8242 - val_recall: 0.7951
#
# Epoch 00074: val_auc did not improve from 0.98387
# Epoch 75/100
# 557/557 [==============================] - 185s 332ms/step - loss: 1.0002 - acc: 0.8539 - auc: 0.9853 - precision: 0.8641 - recall: 0.8447 - val_loss: 0.4246 - val_acc: 0.8776 - val_auc: 0.9819 - val_precision: 0.8815 - val_recall: 0.8704
#
# Epoch 00075: val_auc did not improve from 0.98387
# Epoch 76/100
# 557/557 [==============================] - 185s 332ms/step - loss: 0.8748 - acc: 0.8728 - auc: 0.9889 - precision: 0.8816 - recall: 0.8636 - val_loss: 0.4156 - val_acc: 0.8613 - val_auc: 0.9833 - val_precision: 0.8733 - val_recall: 0.8495
#
# Epoch 00076: val_auc did not improve from 0.98387
# Epoch 77/100
# 557/557 [==============================] - 185s 331ms/step - loss: 0.8646 - acc: 0.8701 - auc: 0.9882 - precision: 0.8782 - recall: 0.8605 - val_loss: 0.3990 - val_acc: 0.8776 - val_auc: 0.9834 - val_precision: 0.8842 - val_recall: 0.8722
#
# Epoch 00077: val_auc did not improve from 0.98387
# Epoch 78/100
# 557/557 [==============================] - 185s 331ms/step - loss: 0.7847 - acc: 0.8706 - auc: 0.9885 - precision: 0.8780 - recall: 0.8620 - val_loss: 0.5944 - val_acc: 0.8105 - val_auc: 0.9701 - val_precision: 0.8250 - val_recall: 0.8033
#
# Epoch 00078: val_auc did not improve from 0.98387
# Epoch 79/100
# 557/557 [==============================] - 185s 331ms/step - loss: 0.8933 - acc: 0.8658 - auc: 0.9881 - precision: 0.8752 - recall: 0.8572 - val_loss: 0.3930 - val_acc: 0.8794 - val_auc: 0.9827 - val_precision: 0.8867 - val_recall: 0.8731
#
# Epoch 00079: val_auc did not improve from 0.98387
# Epoch 80/100
# 557/557 [==============================] - 185s 331ms/step - loss: 0.7930 - acc: 0.8843 - auc: 0.9902 - precision: 0.8916 - recall: 0.8768 - val_loss: 0.5374 - val_acc: 0.8332 - val_auc: 0.9761 - val_precision: 0.8429 - val_recall: 0.8268
#
# Epoch 00080: val_auc did not improve from 0.98387
# Epoch 81/100
# 557/557 [==============================] - 185s 331ms/step - loss: 0.6676 - acc: 0.8898 - auc: 0.9904 - precision: 0.8977 - recall: 0.8841 - val_loss: 0.4467 - val_acc: 0.8749 - val_auc: 0.9799 - val_precision: 0.8829 - val_recall: 0.8685
#
# Epoch 00081: val_auc did not improve from 0.98387
# Epoch 82/100
# 557/557 [==============================] - 185s 331ms/step - loss: 0.7127 - acc: 0.8871 - auc: 0.9904 - precision: 0.8937 - recall: 0.8816 - val_loss: 0.8037 - val_acc: 0.7552 - val_auc: 0.9562 - val_precision: 0.7637 - val_recall: 0.7443
#
# Epoch 00082: val_auc did not improve from 0.98387
# Epoch 83/100
# 557/557 [==============================] - 185s 332ms/step - loss: 0.7782 - acc: 0.8784 - auc: 0.9880 - precision: 0.8856 - recall: 0.8710 - val_loss: 0.4673 - val_acc: 0.8631 - val_auc: 0.9794 - val_precision: 0.8672 - val_recall: 0.8586
#
# Epoch 00083: val_auc did not improve from 0.98387
# Epoch 84/100
# 557/557 [==============================] - 185s 332ms/step - loss: 0.6501 - acc: 0.8951 - auc: 0.9912 - precision: 0.9018 - recall: 0.8886 - val_loss: 0.4497 - val_acc: 0.8722 - val_auc: 0.9827 - val_precision: 0.8802 - val_recall: 0.8658
#
# Epoch 00084: val_auc did not improve from 0.98387
# Epoch 85/100
# 557/557 [==============================] - 185s 332ms/step - loss: 0.9014 - acc: 0.8702 - auc: 0.9877 - precision: 0.8814 - recall: 0.8621 - val_loss: 0.4498 - val_acc: 0.8613 - val_auc: 0.9805 - val_precision: 0.8723 - val_recall: 0.8549
#
# Epoch 00085: val_auc did not improve from 0.98387
# Epoch 86/100
# 557/557 [==============================] - 185s 331ms/step - loss: 0.7389 - acc: 0.8862 - auc: 0.9902 - precision: 0.8964 - recall: 0.8786 - val_loss: 0.5853 - val_acc: 0.8214 - val_auc: 0.9714 - val_precision: 0.8459 - val_recall: 0.8015
#
# Epoch 00086: val_auc did not improve from 0.98387
# Epoch 87/100
# 557/557 [==============================] - 185s 332ms/step - loss: 0.7506 - acc: 0.8890 - auc: 0.9898 - precision: 0.8984 - recall: 0.8813 - val_loss: 0.4519 - val_acc: 0.8685 - val_auc: 0.9801 - val_precision: 0.8801 - val_recall: 0.8649
#
# Epoch 00087: val_auc did not improve from 0.98387
# Epoch 88/100
# 557/557 [==============================] - 185s 332ms/step - loss: 0.6295 - acc: 0.9022 - auc: 0.9920 - precision: 0.9082 - recall: 0.8976 - val_loss: 0.5120 - val_acc: 0.8377 - val_auc: 0.9780 - val_precision: 0.8427 - val_recall: 0.8305
#
# Epoch 00088: val_auc did not improve from 0.98387
# Epoch 89/100
# 557/557 [==============================] - 185s 332ms/step - loss: 0.6784 - acc: 0.8952 - auc: 0.9912 - precision: 0.9011 - recall: 0.8882 - val_loss: 0.4524 - val_acc: 0.8704 - val_auc: 0.9820 - val_precision: 0.8768 - val_recall: 0.8649
#
# Epoch 00089: val_auc did not improve from 0.98387
# Epoch 90/100
# 557/557 [==============================] - 185s 331ms/step - loss: 0.6143 - acc: 0.9050 - auc: 0.9917 - precision: 0.9119 - recall: 0.9004 - val_loss: 0.4860 - val_acc: 0.8549 - val_auc: 0.9794 - val_precision: 0.8617 - val_recall: 0.8531
#
# Epoch 00090: val_auc did not improve from 0.98387
# Epoch 91/100
# 557/557 [==============================] - 185s 332ms/step - loss: 0.7198 - acc: 0.8940 - auc: 0.9917 - precision: 0.9015 - recall: 0.8878 - val_loss: 0.3984 - val_acc: 0.8885 - val_auc: 0.9834 - val_precision: 0.8909 - val_recall: 0.8812
#
# Epoch 00091: val_auc did not improve from 0.98387
# Epoch 92/100
# 557/557 [==============================] - 185s 332ms/step - loss: 0.5555 - acc: 0.9084 - auc: 0.9927 - precision: 0.9157 - recall: 0.9053 - val_loss: 0.6447 - val_acc: 0.8096 - val_auc: 0.9697 - val_precision: 0.8173 - val_recall: 0.8069
#
# Epoch 00092: val_auc did not improve from 0.98387
# Epoch 93/100
# 557/557 [==============================] - 185s 332ms/step - loss: 0.6687 - acc: 0.8909 - auc: 0.9909 - precision: 0.8991 - recall: 0.8849 - val_loss: 0.4043 - val_acc: 0.8830 - val_auc: 0.9834 - val_precision: 0.8918 - val_recall: 0.8821
#
# Epoch 00093: val_auc did not improve from 0.98387
# Epoch 94/100
# 557/557 [==============================] - 185s 331ms/step - loss: 0.5301 - acc: 0.9132 - auc: 0.9928 - precision: 0.9186 - recall: 0.9081 - val_loss: 0.5253 - val_acc: 0.8413 - val_auc: 0.9781 - val_precision: 0.8476 - val_recall: 0.8368
#
# Epoch 00094: val_auc did not improve from 0.98387
# Epoch 00094: early stopping

# %% [markdown]
# ### 3.2.4. Avaliando o treinamento do modelo

# %%
acc += history_fine.history['acc']
val_acc += history_fine.history['val_acc']

loss += history_fine.history['loss']
val_loss += history_fine.history['val_loss']

# %%
plt.figure(figsize=(8, 8))
plt.subplot(2, 1, 1)
plt.plot(acc, label='Acuracia de treinamento')
plt.plot(val_acc, label='Acuracia de validação')
plt.ylim([0, 1])
plt.plot([first_epoch-1,first_epoch-1],
          plt.ylim(), label='Começo do Fine Tuning')
plt.legend(loc='lower right')
plt.title('Acuracia do treinamento e validação')

plt.subplot(2, 1, 2)
plt.plot(loss, label='Perda do treinamento')
plt.plot(val_loss, label='Perda da validação')
plt.ylim([0, 8])
plt.plot([first_epoch-1,first_epoch-1],
         plt.ylim(), label='Começo do Fine Tuning')
plt.legend(loc='upper right')
plt.title('Perda do treinamento e validação')
plt.xlabel('epoca')
plt.show()

# %% [markdown]
# #### 3.2.4.1. Verificando CLR

# %%
clr.plot_lr((14, 3.5))

# %% [markdown]
# # 4. Avaliando o modelo

# %%
model.load_weights(save_dir + str(nomeDoModelo)+'_folder_'+ str(fold_var)+'.h5')
# model_all = tf.keras.models.load_model(save_dir + str(nomeDoModelo)+'_folder_'+ str(fold_var)+'.h5')

# %%
model.evaluate(val_ds)
# Out:
# 69/69 [==============================] - 7s 101ms/step - loss: 0.4194 - acc: 0.8558 - auc: 0.9839 - precision: 0.8656 - recall: 0.8468
# [0.4194164574146271,
#  0.8558477163314819,
#  0.9838712215423584,
#  0.8656163215637207,
#  0.8467814922332764]

# %% [markdown]
# ## 4.1. Realizando as previsões

# %%
# Obtendo a tabela verdade 
true_categories = tf.concat([y for x, y in val_ds], axis=0)
true_categories  = tf.argmax(true_categories , axis=1)

# %%
# Realizando as previsões
predictions = model.predict(val_ds, verbose=1)
y_pred = tf.argmax(predictions, axis=1)
# Out:
# 69/69 [==============================] - 7s 87ms/step

# %% [markdown]
# ## 4.3. Metricas de avaliação

# %% [markdown]
# ### 4.3.1. Quadro de metricas

# %%
cm_plot_labels = ['akiec', 'bcc', 'bkl', 'df', 'mel','nv', 'vasc']
print(classification_report(true_categories , y_pred, target_names=cm_plot_labels))
# Out:
#               precision    recall  f1-score   support
#
#        akiec       0.80      0.52      0.63        31
#          bcc       0.83      0.83      0.83        35
#          bkl       0.65      0.81      0.72        88
#           df       0.41      0.88      0.56         8
#          mel       0.29      0.80      0.43        46
#           nv       0.99      0.87      0.93       883
#         vasc       0.86      1.00      0.92        12
#
#     accuracy                           0.86      1103
#    macro avg       0.69      0.82      0.72      1103
# weighted avg       0.92      0.86      0.88      1103

# %% [markdown]
# ### 4.3.2. Matriz de confusão

# %%
cm = confusion_matrix(true_categories , y_pred)
fig, ax = plot_confusion_matrix(conf_mat=cm,
                                show_absolute=True,
                                show_normed=True, 
                                class_names=cm_plot_labels)

# %% [markdown]
# ### 4.3.3. Acurácia balanceada

# %%
bAcc= sklearn.metrics.balanced_accuracy_score(true_categories, y_pred)
print(f'Acurácia balanceada: {bAcc*100:.6f}%')
# Out:
# Acurácia balanceada: 81.502266%
