# %% [markdown]
# # 1. Comando Iniciais

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ## 1.1. Importando Bibliotecas

# %%
import numpy as np
import pandas as pd

import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
import plotly 
import plotly.express as px

import tensorflow as tf
from tensorflow.keras.layers import Dense, Dropout, Conv2D, Flatten, GlobalAveragePooling2D, Input
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.preprocessing import image_dataset_from_directory
from tensorflow.keras.models import Model
from tensorflow.keras.callbacks import ReduceLROnPlateau, ModelCheckpoint, EarlyStopping
from tensorflow.keras.metrics import CategoricalAccuracy, AUC, Precision, Recall
from tensorflow import keras

import sklearn
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import confusion_matrix, classification_report

import mlxtend
from mlxtend.plotting import plot_confusion_matrix

import itertools

import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# %%
  # !pip install mlxtend --upgrade --no-deps # Versão do Mlxtend: 0.19.0

# %%
# Utility Script - Criados dentro do Kaggle Code, devido ao fato que são modulo customizados 
# %cd /content/drive/MyDrive/TCC-Melo/Kaggle/
from lrfinder import *
from cyclicallr import *
# Out:
# /content/drive/MyDrive/TCC-Melo/Kaggle

# %% [markdown]
# ### 1.1.1. Demostrando versões das bibliotecas

# %%
print(f'Versão do Numpy: {np.__version__}')
print(f'Versão do Pandas: {pd.__version__}')
print(f'Versão do Matplotlib: {mpl.__version__}')
print(f'Versão do Season: {sns.__version__}')
print(f'Versão do Plotly: {plotly.__version__}')
print(f'Versão do TensorFlow: {tf.__version__}')
print(f'Versão do Keras: {keras.__version__}')
print(f'Versão do Sklearn: {sklearn.__version__}')
print(f'Versão do Mlxtend: {mlxtend.__version__}')
# Out:
# Versão do Numpy: 1.19.5
# Versão do Pandas: 1.1.5
# Versão do Matplotlib: 3.2.2
# Versão do Season: 0.11.2
# Versão do Plotly: 4.4.1
# Versão do TensorFlow: 2.6.0
# Versão do Keras: 2.6.0
# Versão do Sklearn: 0.22.2.post1
# Versão do Mlxtend: 0.19.0

# %% [markdown]
# ## 1.2. Verificando Accelerator

# %%
gpu_info = !nvidia-smi
gpu_info = '\n'.join(gpu_info)
if gpu_info.find('failed') >= 0:
  print('Not connected to a GPU')
else:
  print(gpu_info)
# Out:
# Fri Oct  1 11:07:03 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 470.63.01    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   37C    P0    27W / 250W |      0MiB / 16280MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
gpus = tf.config.list_physical_devices('GPU')
for gpu in gpus:
    print("Name:", gpu.name, "  Type:", gpu.device_type)
tf.test.is_gpu_available()
# Out:
# Name: /physical_device:GPU:0   Type: GPU
# WARNING:tensorflow:From <ipython-input-7-f99a3e65d632>:4: is_gpu_available (from tensorflow.python.framework.test_util) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.config.list_physical_devices('GPU')` instead.
# True

# %% [markdown]
# ## 1.3. Variaveis Globais

# %%
# Caminho para salvar os melhores modelos do callback checkpoint
save_dir = '/content/drive/MyDrive/TCC-Melo/Kaggle/modelos_checkPoint/'

# Caminho dos Folds
fold_var = 1 # Folder selecionado

train_path = f'/content/drive/MyDrive/TCC-Melo/Dados/Folds_Modified/fold_{fold_var}/train_dir'    # Imagens em JPG separadas em folders
valid_path = f'/content/drive/MyDrive/TCC-Melo/Dados/Folds_Modified/fold_{fold_var}/val_dir'    # Imagens em JPG separadas em folders

# Ordem das categorias
classes = ['AKIEC', 'BCC', 'BKL', 'DF', 'MEL', 'NV', 'VASC']
#         [0      , 1    , 2    , 3   , 4    , 5   , 6]

# Tamanho da batch
batch_size = 16

# Dimensão das imagens de entrada
image_size = (448, 448)

# Numero de epochs
## Primeiro Momento:
first_epoch = 30

## Segundo Momento:
second_epoch = first_epoch + 70

# Calculando os passos para o treinamento
train_steps = np.ceil(8912 / batch_size)
val_steps = np.ceil(1103 / batch_size)

# Carregando os pesos para as categorias para o treinamento 
weights_train_dict = {0: 15, 1: 10, 2: 5, 3: 42,
                      4: 20, 5: 1, 6: 35}

# %% [markdown]
# ## 1.4. Metricas de avaliação

# %%
metricasEscolhidas = [CategoricalAccuracy(name='acc'), 
                      AUC(name='auc'),
                      Precision(name='precision'), 
                      Recall(name='recall')]

# %% [markdown]
# ## 1.5. Carregando os dados

# %% [markdown]
#  ### 1.5.1. Treinamento

# %%
train_ds = image_dataset_from_directory(train_path,
                                        batch_size=batch_size,
                                        image_size = image_size,
                                        label_mode='categorical',
                                        shuffle=True,
                                        seed=42)
# Out:
# Found 8912 files belonging to 7 classes.

# %%
val_ds = image_dataset_from_directory(valid_path,
                                      batch_size=batch_size,
                                      image_size = image_size,
                                      label_mode='categorical',
                                      shuffle=False,
                                      seed=42)
# Out:
# Found 1103 files belonging to 7 classes.

# %% [markdown]
# #### 1.5.1.1. Alta velocidade de treinamento

# %%
for image_batch, labels_batch in train_ds:
  print(image_batch.shape)
  print(labels_batch.shape)
  break
# Out:
# (16, 448, 448, 3)
# (16, 7)

# %%
AUTOTUNE = tf.data.AUTOTUNE

#train_ds = train_ds.cache().prefetch(buffer_size=AUTOTUNE)
train_ds = train_ds.prefetch(buffer_size=AUTOTUNE)
#val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.prefetch(buffer_size=AUTOTUNE)

# %% [markdown]
# ## 1.6. Modelo Pré-treinado

# %%
num_model = 4

# %% [markdown]
# ### 1.6.1. Selecionando modelo

# %%
if num_model == 1:
    nomeDoModelo = 'DenseNet121'
    modelo = tf.keras.applications.DenseNet121(weights='imagenet', 
                                               include_top=False, 
                                               input_tensor=Input(shape=image_size+(3,)))
elif num_model == 2:
    nomeDoModelo = 'DenseNet169'
    modelo = tf.keras.applications.DenseNet169(weights='imagenet', 
                                               include_top=False, 
                                               input_tensor=Input(shape=image_size+(3,)))
elif num_model == 3:
    nomeDoModelo = 'DenseNet201'
    modelo = tf.keras.applications.DenseNet201(weights='imagenet', 
                                               include_top=False, 
                                               input_tensor=Input(shape=image_size+(3,)))
elif num_model == 4:
    nomeDoModelo = 'ResNet50V2'
    modelo = tf.keras.applications.ResNet50V2(weights='imagenet', 
                                               include_top=False, 
                                               input_tensor=Input(shape=image_size+(3,)))
elif num_model == 5:
    nomeDoModelo = 'ResNet101V2'
    modelo = tf.keras.applications.ResNet101V2(weights='imagenet', 
                                               include_top=False, 
                                               input_tensor=Input(shape=image_size+(3,)))
elif num_model == 6:
    nomeDoModelo = 'ResNet152V2'
    modelo = tf.keras.applications.ResNet152V2(weights='imagenet', 
                                               include_top=False, 
                                               input_tensor=Input(shape=image_size+(3,)))
elif num_model == 7:
    nomeDoModelo = 'Xception'
    modelo = tf.keras.applications.Xception(weights='imagenet', 
                                               include_top=False, 
                                               input_tensor=Input(shape=image_size+(3,)))
elif num_model == 8:
    nomeDoModelo = 'InceptionV3'
    modelo = tf.keras.applications.InceptionV3(weights='imagenet', 
                                               include_top=False, 
                                               input_tensor=Input(shape=image_size+(3,)))
elif num_model == 9:
    nomeDoModelo = 'InceptionResNetV2'
    modelo = tf.keras.applications.InceptionResNetV2(weights='imagenet', 
                                               include_top=False, 
                                               input_tensor=Input(shape=image_size+(3,)))
elif num_model == 10:
    nomeDoModelo = 'EfficientNetB0'
    modelo = tf.keras.applications.EfficientNetB0(weights='imagenet', 
                                               include_top=False, 
                                               input_tensor=Input(shape=image_size+(3,)))
elif num_model == 11:
    nomeDoModelo = 'EfficientNetB1'
    modelo = tf.keras.applications.EfficientNetB1(weights='imagenet', 
                                               include_top=False, 
                                               input_tensor=Input(shape=image_size+(3,)))
elif num_model == 12:
    nomeDoModelo = 'EfficientNetB2'
    modelo = tf.keras.applications.EfficientNetB2(weights='imagenet', 
                                               include_top=False, 
                                               input_tensor=Input(shape=image_size+(3,)))
elif num_model == 13:
    nomeDoModelo = 'EfficientNetB3'
    modelo = tf.keras.applications.EfficientNetB3(weights='imagenet', 
                                               include_top=False, 
                                               input_tensor=Input(shape=image_size+(3,)))
    
print(f'O modelo selecionado foi {nomeDoModelo}')
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50v2_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94674944/94668760 [==============================] - 3s 0us/step
# 94683136/94668760 [==============================] - 3s 0us/step
# O modelo selecionado foi ResNet50V2

# %% [markdown]
# # 2. Preprocessamento

# %% [markdown]
# ## 2.1. Camada de aumento de dados

# %%
camada_ad = tf.keras.Sequential([
  tf.keras.layers.experimental.preprocessing.RandomFlip('horizontal'),
  tf.keras.layers.experimental.preprocessing.RandomFlip('vertical'),
  tf.keras.layers.experimental.preprocessing.RandomRotation(0.3),
  tf.keras.layers.experimental.preprocessing.RandomContrast((0.8, 1.1)),
], name='data_augmentation')

# %% [markdown]
# ## 2.2. Camada de reescalonamento

# %%
if num_model in [1, 2, 3]:
    camada_reescal = tf.keras.applications.densenet.preprocess_input
elif num_model in [4, 5, 6]:
    camada_reescal = tf.keras.applications.resnet_v2.preprocess_input
elif num_model == 7:
    camada_reescal = tf.keras.applications.xception.preprocess_input
elif num_model == 8:
    camada_reescal = tf.keras.applications.inception_v3.preprocess_input
elif num_model == 9:
    camada_reescal = tf.keras.applications.inception_resnet_v2.preprocess_input
elif num_model in [10, 11, 12, 13]:
    camada_reescal = tf.keras.applications.efficientnet.preprocess_input
    
print(f'A camada selecionada foi {camada_reescal}')
# Out:
# A camada selecionada foi <function preprocess_input at 0x7f0128c450e0>

# %% [markdown]
# # 3. Classificação

# %% [markdown]
# ## 3.1. Criando o modelo: Primeiro Momento

# %%
modelBase = modelo

modelBase.trainable = False # Congelando os pesos do modelo base

inputs = tf.keras.Input(shape=image_size+(3,))
x = camada_ad(inputs)
x = camada_reescal(x)
x = modelBase(x, training=False) # Deixando o modelo em modo enferência por causa das camadas BatchNormalization
x = GlobalAveragePooling2D()(x)
x = Dropout(0.3)(x)
predictions = Dense(7, activation='softmax')(x)
model = tf.keras.Model(inputs, predictions, name=nomeDoModelo)

# %%
model.summary()
# Out:
# Model: "ResNet50V2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         [(None, 448, 448, 3)]     0
# _________________________________________________________________
# data_augmentation (Sequentia (None, 448, 448, 3)       0
# _________________________________________________________________
# tf.math.truediv (TFOpLambda) (None, 448, 448, 3)       0
# _________________________________________________________________
# tf.math.subtract (TFOpLambda (None, 448, 448, 3)       0
# _________________________________________________________________
# resnet50v2 (Functional)      (None, 14, 14, 2048)      23564800
# _________________________________________________________________
# global_average_pooling2d (Gl (None, 2048)              0
# _________________________________________________________________
# dropout (Dropout)            (None, 2048)              0
# _________________________________________________________________
# dense (Dense)                (None, 7)                 14343
# =================================================================
# Total params: 23,579,143
# Trainable params: 14,343
# Non-trainable params: 23,564,800
# _________________________________________________________________

# %% [markdown]
# ### 3.1.1. Buscando a taxa de aprendizado: LRFinder 1

# %%
optimizer = tf.keras.optimizers.Adam()
loss_fn = tf.keras.losses.CategoricalCrossentropy()

# %%
lr_find = LrFinder(model, optimizer, loss_fn)
lr_find.range_test(train_ds)
lr_find.plot_lrs(suggestion=True, show_grid=True)
# Out:
# Finding best initial lr over 100 steps
#   0%|          | 0/100 [00:00<?, ?it/s]
# LR Finder is complete, type {LrFinder}.plot_lrs() to see the graph.
# Min numerical gradient: 8.32E-04
# Min loss divided by 10: 1.58E-03

# %%
base_lr = 1e-03

# %% [markdown]
# ### 3.1.2. Treinando

# %%
model.compile(optimizer=Adam(learning_rate= base_lr), 
              loss=tf.keras.losses.CategoricalCrossentropy(), 
              metrics=metricasEscolhidas)

# %%
history = model.fit(train_ds,
                    class_weight = weights_train_dict,
                    steps_per_epoch = train_steps,
                    epochs=first_epoch,
                    validation_data=val_ds,
                    validation_steps = val_steps)
# Out:
# Epoch 1/30
# 557/557 [==============================] - 1057s 2s/step - loss: 8.1658 - acc: 0.3420 - auc: 0.7645 - precision: 0.3960 - recall: 0.1963 - val_loss: 1.0925 - val_acc: 0.5902 - val_auc: 0.9025 - val_precision: 0.7005 - val_recall: 0.3880
# Epoch 2/30
# 557/557 [==============================] - 66s 118ms/step - loss: 6.6945 - acc: 0.4201 - auc: 0.8256 - precision: 0.4696 - recall: 0.2856 - val_loss: 0.9045 - val_acc: 0.6772 - val_auc: 0.9326 - val_precision: 0.7665 - val_recall: 0.5358
# Epoch 3/30
# 557/557 [==============================] - 66s 118ms/step - loss: 6.3315 - acc: 0.4633 - auc: 0.8428 - precision: 0.5148 - recall: 0.3440 - val_loss: 1.3211 - val_acc: 0.4760 - val_auc: 0.8575 - val_precision: 0.5134 - val_recall: 0.3300
# Epoch 4/30
# 557/557 [==============================] - 66s 118ms/step - loss: 6.0351 - acc: 0.4647 - auc: 0.8449 - precision: 0.5170 - recall: 0.3624 - val_loss: 0.7511 - val_acc: 0.7461 - val_auc: 0.9533 - val_precision: 0.8124 - val_recall: 0.6437
# Epoch 5/30
# 557/557 [==============================] - 66s 118ms/step - loss: 5.7283 - acc: 0.4841 - auc: 0.8589 - precision: 0.5399 - recall: 0.3842 - val_loss: 0.9410 - val_acc: 0.6482 - val_auc: 0.9247 - val_precision: 0.6948 - val_recall: 0.5304
# Epoch 6/30
# 557/557 [==============================] - 66s 118ms/step - loss: 5.7089 - acc: 0.4937 - auc: 0.8624 - precision: 0.5469 - recall: 0.3982 - val_loss: 0.9136 - val_acc: 0.6818 - val_auc: 0.9290 - val_precision: 0.7269 - val_recall: 0.5839
# Epoch 7/30
# 557/557 [==============================] - 66s 118ms/step - loss: 5.5975 - acc: 0.4936 - auc: 0.8652 - precision: 0.5467 - recall: 0.4050 - val_loss: 1.1894 - val_acc: 0.5648 - val_auc: 0.8839 - val_precision: 0.6166 - val_recall: 0.4243
# Epoch 8/30
# 557/557 [==============================] - 70s 124ms/step - loss: 5.6277 - acc: 0.4884 - auc: 0.8614 - precision: 0.5363 - recall: 0.4031 - val_loss: 0.7802 - val_acc: 0.7298 - val_auc: 0.9488 - val_precision: 0.8086 - val_recall: 0.6319
# Epoch 9/30
# 557/557 [==============================] - 66s 118ms/step - loss: 5.5932 - acc: 0.4981 - auc: 0.8678 - precision: 0.5439 - recall: 0.4133 - val_loss: 0.9598 - val_acc: 0.6464 - val_auc: 0.9228 - val_precision: 0.7058 - val_recall: 0.5394
# Epoch 10/30
# 557/557 [==============================] - 66s 118ms/step - loss: 5.5673 - acc: 0.4971 - auc: 0.8672 - precision: 0.5477 - recall: 0.4107 - val_loss: 1.0929 - val_acc: 0.5730 - val_auc: 0.9012 - val_precision: 0.6056 - val_recall: 0.4678
# Epoch 11/30
# 557/557 [==============================] - 66s 118ms/step - loss: 5.4849 - acc: 0.5008 - auc: 0.8684 - precision: 0.5497 - recall: 0.4256 - val_loss: 1.1050 - val_acc: 0.5993 - val_auc: 0.9002 - val_precision: 0.6468 - val_recall: 0.4832
# Epoch 12/30
# 557/557 [==============================] - 66s 118ms/step - loss: 5.3895 - acc: 0.5187 - auc: 0.8755 - precision: 0.5653 - recall: 0.4399 - val_loss: 0.8472 - val_acc: 0.6990 - val_auc: 0.9393 - val_precision: 0.7450 - val_recall: 0.6120
# Epoch 13/30
# 557/557 [==============================] - 66s 118ms/step - loss: 5.5617 - acc: 0.4975 - auc: 0.8705 - precision: 0.5435 - recall: 0.4203 - val_loss: 1.0763 - val_acc: 0.5721 - val_auc: 0.9037 - val_precision: 0.6048 - val_recall: 0.4814
# Epoch 14/30
# 557/557 [==============================] - 66s 118ms/step - loss: 5.4703 - acc: 0.4999 - auc: 0.8697 - precision: 0.5504 - recall: 0.4236 - val_loss: 1.1328 - val_acc: 0.5712 - val_auc: 0.8945 - val_precision: 0.6464 - val_recall: 0.4723
# Epoch 15/30
# 557/557 [==============================] - 70s 124ms/step - loss: 5.3354 - acc: 0.5118 - auc: 0.8734 - precision: 0.5590 - recall: 0.4345 - val_loss: 0.7781 - val_acc: 0.7262 - val_auc: 0.9484 - val_precision: 0.7829 - val_recall: 0.6410
# Epoch 16/30
# 557/557 [==============================] - 66s 118ms/step - loss: 5.3659 - acc: 0.5150 - auc: 0.8742 - precision: 0.5608 - recall: 0.4415 - val_loss: 0.8997 - val_acc: 0.6700 - val_auc: 0.9320 - val_precision: 0.7463 - val_recall: 0.5866
# Epoch 17/30
# 557/557 [==============================] - 66s 118ms/step - loss: 5.4929 - acc: 0.5121 - auc: 0.8700 - precision: 0.5557 - recall: 0.4388 - val_loss: 0.9830 - val_acc: 0.6346 - val_auc: 0.9201 - val_precision: 0.7126 - val_recall: 0.5485
# Epoch 18/30
# 557/557 [==============================] - 66s 118ms/step - loss: 5.2505 - acc: 0.5242 - auc: 0.8787 - precision: 0.5707 - recall: 0.4504 - val_loss: 0.8209 - val_acc: 0.7099 - val_auc: 0.9430 - val_precision: 0.7650 - val_recall: 0.6346
# Epoch 19/30
# 557/557 [==============================] - 66s 118ms/step - loss: 5.3218 - acc: 0.5155 - auc: 0.8764 - precision: 0.5635 - recall: 0.4432 - val_loss: 0.9654 - val_acc: 0.6455 - val_auc: 0.9222 - val_precision: 0.6982 - val_recall: 0.5621
# Epoch 20/30
# 557/557 [==============================] - 66s 118ms/step - loss: 5.2702 - acc: 0.5212 - auc: 0.8782 - precision: 0.5672 - recall: 0.4484 - val_loss: 1.0991 - val_acc: 0.6038 - val_auc: 0.9033 - val_precision: 0.6479 - val_recall: 0.5122
# Epoch 21/30
# 557/557 [==============================] - 66s 118ms/step - loss: 5.3262 - acc: 0.5226 - auc: 0.8762 - precision: 0.5630 - recall: 0.4445 - val_loss: 0.9792 - val_acc: 0.6301 - val_auc: 0.9202 - val_precision: 0.6689 - val_recall: 0.5422
# Epoch 22/30
# 557/557 [==============================] - 66s 118ms/step - loss: 5.3732 - acc: 0.5200 - auc: 0.8789 - precision: 0.5594 - recall: 0.4492 - val_loss: 0.9288 - val_acc: 0.6609 - val_auc: 0.9276 - val_precision: 0.6942 - val_recall: 0.5784
# Epoch 23/30
# 557/557 [==============================] - 66s 118ms/step - loss: 5.3866 - acc: 0.5167 - auc: 0.8732 - precision: 0.5543 - recall: 0.4439 - val_loss: 0.7670 - val_acc: 0.7208 - val_auc: 0.9500 - val_precision: 0.7698 - val_recall: 0.6609
# Epoch 24/30
# 557/557 [==============================] - 66s 118ms/step - loss: 5.3166 - acc: 0.5321 - auc: 0.8827 - precision: 0.5774 - recall: 0.4643 - val_loss: 1.1452 - val_acc: 0.5766 - val_auc: 0.8949 - val_precision: 0.6247 - val_recall: 0.4769
# Epoch 25/30
# 557/557 [==============================] - 66s 118ms/step - loss: 5.1694 - acc: 0.5194 - auc: 0.8769 - precision: 0.5610 - recall: 0.4493 - val_loss: 0.8901 - val_acc: 0.6854 - val_auc: 0.9333 - val_precision: 0.7161 - val_recall: 0.6129
# Epoch 26/30
# 557/557 [==============================] - 66s 118ms/step - loss: 5.3260 - acc: 0.5239 - auc: 0.8779 - precision: 0.5637 - recall: 0.4567 - val_loss: 0.8551 - val_acc: 0.6890 - val_auc: 0.9382 - val_precision: 0.7337 - val_recall: 0.6120
# Epoch 27/30
# 557/557 [==============================] - 66s 118ms/step - loss: 5.2643 - acc: 0.5169 - auc: 0.8766 - precision: 0.5572 - recall: 0.4488 - val_loss: 0.8073 - val_acc: 0.7153 - val_auc: 0.9443 - val_precision: 0.7583 - val_recall: 0.6455
# Epoch 28/30
# 557/557 [==============================] - 66s 118ms/step - loss: 5.1127 - acc: 0.5209 - auc: 0.8817 - precision: 0.5665 - recall: 0.4556 - val_loss: 1.0941 - val_acc: 0.5956 - val_auc: 0.9046 - val_precision: 0.6475 - val_recall: 0.5195
# Epoch 29/30
# 557/557 [==============================] - 66s 118ms/step - loss: 5.2547 - acc: 0.5199 - auc: 0.8780 - precision: 0.5595 - recall: 0.4531 - val_loss: 0.8454 - val_acc: 0.6936 - val_auc: 0.9396 - val_precision: 0.7484 - val_recall: 0.6256
# Epoch 30/30
# 557/557 [==============================] - 66s 118ms/step - loss: 5.1859 - acc: 0.5237 - auc: 0.8786 - precision: 0.5685 - recall: 0.4584 - val_loss: 0.9671 - val_acc: 0.6482 - val_auc: 0.9224 - val_precision: 0.7164 - val_recall: 0.5657

# %% [markdown]
# ### 3.1.3. Avaliando o treinamento do modelo

# %%
acc = history.history['acc']
val_acc = history.history['val_acc']

loss = history.history['loss']
val_loss = history.history['val_loss']

plt.figure(figsize=(8, 8))
plt.subplot(2, 1, 1)
plt.plot(acc, label='Acuracia do treinamento')
plt.plot(val_acc, label='Acuracia da validação')
plt.legend(loc='lower right')
plt.ylabel('Acuracia')
plt.ylim([0,1])
plt.title('Acuracia do treinamento e validação')

plt.subplot(2, 1, 2)
plt.plot(loss, label='Perda do treinamento')
plt.plot(val_loss, label='Perda da validação')
plt.legend(loc='upper right')
plt.ylabel('Entropia Cruzada')
plt.ylim([0,8])
plt.title('Perda do treinamento e validação')
plt.xlabel('epoca')
plt.show()

# %% [markdown]
# ## 3.2. Criando o modelo: Segundo Momento

# %%
modelBase.trainable = True # Descongelando os pesos do modelo base para o treinamento

# %%
model.summary()
# Out:
# Model: "ResNet50V2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         [(None, 448, 448, 3)]     0
# _________________________________________________________________
# data_augmentation (Sequentia (None, 448, 448, 3)       0
# _________________________________________________________________
# tf.math.truediv (TFOpLambda) (None, 448, 448, 3)       0
# _________________________________________________________________
# tf.math.subtract (TFOpLambda (None, 448, 448, 3)       0
# _________________________________________________________________
# resnet50v2 (Functional)      (None, 14, 14, 2048)      23564800
# _________________________________________________________________
# global_average_pooling2d (Gl (None, 2048)              0
# _________________________________________________________________
# dropout (Dropout)            (None, 2048)              0
# _________________________________________________________________
# dense (Dense)                (None, 7)                 14343
# =================================================================
# Total params: 23,579,143
# Trainable params: 23,533,703
# Non-trainable params: 45,440
# _________________________________________________________________

# %% [markdown]
# ### 3.2.1. Buscando a taxa de aprendizado: LRFinder 2

# %%
optimizer = tf.keras.optimizers.Adam()
loss_fn = tf.keras.losses.CategoricalCrossentropy()

# %%
lr_find = LrFinder(model, optimizer, loss_fn)
lr_find.range_test(train_ds)
lr_find.plot_lrs(suggestion=True, show_grid=True)
# Out:
# Finding best initial lr over 100 steps
#   0%|          | 0/100 [00:00<?, ?it/s]
# LR Finder is complete, type {LrFinder}.plot_lrs() to see the graph.
# Min numerical gradient: 5.75E-06
# Min loss divided by 10: 9.12E-06

# %%
base_lr = 1e-6
max_lr = 1e-5

# %% [markdown]
# ### 3.2.2. Definindo os Callbacks

# %% [markdown]
# #### 3.2.2.1. CyclicalLR

# %%
step_size = train_steps
clr = CyclicalLR(max_lr=max_lr, 
                 base_lr=base_lr, 
                 step_size=step_size, 
                 cyclical_momentum=False)

# %% [markdown]
# #### 3.2.2.2. Checkpoint

# %%
# salva os melhores modelos para o callback
def get_model_name(k):
    return str(nomeDoModelo)+'_folder_'+ str(k)+'.h5'

# %%
checkpoint = ModelCheckpoint(save_dir+get_model_name(fold_var),
                                                  monitor='val_auc', verbose=1,
                                                  save_best_only=True, mode='max')

# %% [markdown]
# #### 3.2.2.3. Earlystopping

# %%
earlystopping = EarlyStopping(monitor='val_loss',
                              verbose=1, mode='min', 
                              restore_best_weights=False,
                              patience=15)

# %%
# Lista contendo todos os callbacks
callbacks_list = [checkpoint, earlystopping, clr]

# %% [markdown]
# ### 3.2.3. Treinando

# %%
model.compile(optimizer=Adam(learning_rate=base_lr), 
              loss=tf.keras.losses.CategoricalCrossentropy(), 
              metrics=metricasEscolhidas)

# %%
history_fine = model.fit(train_ds,
                    class_weight = weights_train_dict,
                    steps_per_epoch = train_steps,
                    epochs=second_epoch,
                    initial_epoch=history.epoch[-1],
                    validation_data=val_ds,
                    validation_steps = val_steps,
                    callbacks = callbacks_list)
# Out:
# Epoch 30/100
# 557/557 [==============================] - 189s 330ms/step - loss: 5.0009 - acc: 0.5380 - auc: 0.8884 - precision: 0.5859 - recall: 0.4612 - val_loss: 1.1258 - val_acc: 0.5394 - val_auc: 0.8927 - val_precision: 0.5666 - val_recall: 0.4125
#
# Epoch 00030: val_auc improved from -inf to 0.89267, saving model to /content/drive/MyDrive/TCC-Melo/Kaggle/modelos_checkPoint/ResNet50V2_folder_1.h5
# /usr/local/lib/python3.7/dist-packages/keras/utils/generic_utils.py:497: CustomMaskWarning:
#
# Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
# Epoch 31/100
# 557/557 [==============================] - 183s 327ms/step - loss: 4.4441 - acc: 0.5419 - auc: 0.8969 - precision: 0.5867 - recall: 0.4698 - val_loss: 0.8133 - val_acc: 0.7063 - val_auc: 0.9434 - val_precision: 0.7593 - val_recall: 0.6464
#
# Epoch 00031: val_auc improved from 0.89267 to 0.94344, saving model to /content/drive/MyDrive/TCC-Melo/Kaggle/modelos_checkPoint/ResNet50V2_folder_1.h5
# Epoch 32/100
# 557/557 [==============================] - 183s 327ms/step - loss: 3.9269 - acc: 0.5798 - auc: 0.9122 - precision: 0.6209 - recall: 0.5231 - val_loss: 0.7925 - val_acc: 0.7099 - val_auc: 0.9473 - val_precision: 0.7694 - val_recall: 0.6020
#
# Epoch 00032: val_auc improved from 0.94344 to 0.94731, saving model to /content/drive/MyDrive/TCC-Melo/Kaggle/modelos_checkPoint/ResNet50V2_folder_1.h5
# Epoch 33/100
# 557/557 [==============================] - 184s 327ms/step - loss: 3.7736 - acc: 0.5959 - auc: 0.9190 - precision: 0.6369 - recall: 0.5382 - val_loss: 0.6345 - val_acc: 0.7752 - val_auc: 0.9642 - val_precision: 0.8062 - val_recall: 0.7280
#
# Epoch 00033: val_auc improved from 0.94731 to 0.96420, saving model to /content/drive/MyDrive/TCC-Melo/Kaggle/modelos_checkPoint/ResNet50V2_folder_1.h5
# Epoch 34/100
# 557/557 [==============================] - 183s 328ms/step - loss: 3.4684 - acc: 0.6104 - auc: 0.9239 - precision: 0.6469 - recall: 0.5624 - val_loss: 0.8734 - val_acc: 0.6473 - val_auc: 0.9352 - val_precision: 0.6984 - val_recall: 0.5712
#
# Epoch 00034: val_auc did not improve from 0.96420
# Epoch 35/100
# 557/557 [==============================] - 182s 327ms/step - loss: 3.3118 - acc: 0.6262 - auc: 0.9305 - precision: 0.6584 - recall: 0.5791 - val_loss: 0.6282 - val_acc: 0.7670 - val_auc: 0.9659 - val_precision: 0.8083 - val_recall: 0.7262
#
# Epoch 00035: val_auc improved from 0.96420 to 0.96590, saving model to /content/drive/MyDrive/TCC-Melo/Kaggle/modelos_checkPoint/ResNet50V2_folder_1.h5
# Epoch 36/100
# 557/557 [==============================] - 184s 327ms/step - loss: 3.0547 - acc: 0.6441 - auc: 0.9359 - precision: 0.6793 - recall: 0.5993 - val_loss: 0.6932 - val_acc: 0.7507 - val_auc: 0.9589 - val_precision: 0.7900 - val_recall: 0.6854
#
# Epoch 00036: val_auc did not improve from 0.96590
# Epoch 37/100
# 557/557 [==============================] - 182s 327ms/step - loss: 2.9657 - acc: 0.6465 - auc: 0.9378 - precision: 0.6806 - recall: 0.6100 - val_loss: 0.5807 - val_acc: 0.7960 - val_auc: 0.9708 - val_precision: 0.8220 - val_recall: 0.7579
#
# Epoch 00037: val_auc improved from 0.96590 to 0.97084, saving model to /content/drive/MyDrive/TCC-Melo/Kaggle/modelos_checkPoint/ResNet50V2_folder_1.h5
# Epoch 38/100
# 557/557 [==============================] - 183s 327ms/step - loss: 2.8136 - acc: 0.6662 - auc: 0.9434 - precision: 0.6983 - recall: 0.6284 - val_loss: 0.6250 - val_acc: 0.7679 - val_auc: 0.9660 - val_precision: 0.8068 - val_recall: 0.7271
#
# Epoch 00038: val_auc did not improve from 0.97084
# Epoch 39/100
# 557/557 [==============================] - 182s 327ms/step - loss: 2.8958 - acc: 0.6566 - auc: 0.9415 - precision: 0.6882 - recall: 0.6192 - val_loss: 0.5877 - val_acc: 0.7733 - val_auc: 0.9702 - val_precision: 0.7988 - val_recall: 0.7525
#
# Epoch 00039: val_auc did not improve from 0.97084
# Epoch 40/100
# 557/557 [==============================] - 183s 327ms/step - loss: 2.5378 - acc: 0.6911 - auc: 0.9484 - precision: 0.7147 - recall: 0.6606 - val_loss: 0.6056 - val_acc: 0.7806 - val_auc: 0.9684 - val_precision: 0.8065 - val_recall: 0.7597
#
# Epoch 00040: val_auc did not improve from 0.97084
# Epoch 41/100
# 557/557 [==============================] - 182s 327ms/step - loss: 2.5250 - acc: 0.6923 - auc: 0.9507 - precision: 0.7164 - recall: 0.6636 - val_loss: 0.6041 - val_acc: 0.7761 - val_auc: 0.9695 - val_precision: 0.8029 - val_recall: 0.7607
#
# Epoch 00041: val_auc did not improve from 0.97084
# Epoch 42/100
# 557/557 [==============================] - 183s 327ms/step - loss: 2.3184 - acc: 0.7052 - auc: 0.9541 - precision: 0.7303 - recall: 0.6779 - val_loss: 0.5149 - val_acc: 0.8123 - val_auc: 0.9756 - val_precision: 0.8279 - val_recall: 0.7851
#
# Epoch 00042: val_auc improved from 0.97084 to 0.97561, saving model to /content/drive/MyDrive/TCC-Melo/Kaggle/modelos_checkPoint/ResNet50V2_folder_1.h5
# Epoch 43/100
# 557/557 [==============================] - 184s 327ms/step - loss: 2.2282 - acc: 0.7077 - auc: 0.9544 - precision: 0.7301 - recall: 0.6801 - val_loss: 0.5146 - val_acc: 0.8187 - val_auc: 0.9765 - val_precision: 0.8326 - val_recall: 0.8114
#
# Epoch 00043: val_auc improved from 0.97561 to 0.97647, saving model to /content/drive/MyDrive/TCC-Melo/Kaggle/modelos_checkPoint/ResNet50V2_folder_1.h5
# Epoch 44/100
# 557/557 [==============================] - 183s 327ms/step - loss: 2.2147 - acc: 0.7156 - auc: 0.9566 - precision: 0.7355 - recall: 0.6872 - val_loss: 0.5593 - val_acc: 0.8024 - val_auc: 0.9722 - val_precision: 0.8234 - val_recall: 0.7779
#
# Epoch 00044: val_auc did not improve from 0.97647
# Epoch 45/100
# 557/557 [==============================] - 183s 327ms/step - loss: 2.1041 - acc: 0.7195 - auc: 0.9585 - precision: 0.7406 - recall: 0.6970 - val_loss: 0.5455 - val_acc: 0.8096 - val_auc: 0.9724 - val_precision: 0.8254 - val_recall: 0.7969
#
# Epoch 00045: val_auc did not improve from 0.97647
# Epoch 46/100
# 557/557 [==============================] - 183s 328ms/step - loss: 1.9238 - acc: 0.7362 - auc: 0.9624 - precision: 0.7563 - recall: 0.7170 - val_loss: 0.7936 - val_acc: 0.7235 - val_auc: 0.9517 - val_precision: 0.7454 - val_recall: 0.7035
#
# Epoch 00046: val_auc did not improve from 0.97647
# Epoch 47/100
# 557/557 [==============================] - 183s 327ms/step - loss: 2.0193 - acc: 0.7258 - auc: 0.9609 - precision: 0.7496 - recall: 0.7051 - val_loss: 0.5908 - val_acc: 0.7915 - val_auc: 0.9705 - val_precision: 0.8091 - val_recall: 0.7761
#
# Epoch 00047: val_auc did not improve from 0.97647
# Epoch 48/100
# 557/557 [==============================] - 183s 327ms/step - loss: 1.8424 - acc: 0.7444 - auc: 0.9645 - precision: 0.7632 - recall: 0.7262 - val_loss: 0.4436 - val_acc: 0.8314 - val_auc: 0.9815 - val_precision: 0.8581 - val_recall: 0.8060
#
# Epoch 00048: val_auc improved from 0.97647 to 0.98153, saving model to /content/drive/MyDrive/TCC-Melo/Kaggle/modelos_checkPoint/ResNet50V2_folder_1.h5
# Epoch 49/100
# 557/557 [==============================] - 183s 327ms/step - loss: 2.0233 - acc: 0.7331 - auc: 0.9609 - precision: 0.7549 - recall: 0.7138 - val_loss: 0.5809 - val_acc: 0.7879 - val_auc: 0.9711 - val_precision: 0.8088 - val_recall: 0.7706
#
# Epoch 00049: val_auc did not improve from 0.98153
# Epoch 50/100
# 557/557 [==============================] - 183s 327ms/step - loss: 1.7142 - acc: 0.7602 - auc: 0.9676 - precision: 0.7787 - recall: 0.7458 - val_loss: 0.5719 - val_acc: 0.7824 - val_auc: 0.9712 - val_precision: 0.8069 - val_recall: 0.7461
#
# Epoch 00050: val_auc did not improve from 0.98153
# Epoch 51/100
# 557/557 [==============================] - 183s 328ms/step - loss: 1.8767 - acc: 0.7475 - auc: 0.9663 - precision: 0.7666 - recall: 0.7273 - val_loss: 0.5128 - val_acc: 0.8169 - val_auc: 0.9772 - val_precision: 0.8318 - val_recall: 0.7978
#
# Epoch 00051: val_auc did not improve from 0.98153
# Epoch 52/100
# 557/557 [==============================] - 182s 327ms/step - loss: 1.6488 - acc: 0.7689 - auc: 0.9704 - precision: 0.7890 - recall: 0.7511 - val_loss: 0.6408 - val_acc: 0.7679 - val_auc: 0.9669 - val_precision: 0.7878 - val_recall: 0.7507
#
# Epoch 00052: val_auc did not improve from 0.98153
# Epoch 53/100
# 557/557 [==============================] - 183s 327ms/step - loss: 1.4924 - acc: 0.7784 - auc: 0.9734 - precision: 0.7932 - recall: 0.7646 - val_loss: 0.5597 - val_acc: 0.8087 - val_auc: 0.9731 - val_precision: 0.8238 - val_recall: 0.7969
#
# Epoch 00053: val_auc did not improve from 0.98153
# Epoch 54/100
# 557/557 [==============================] - 183s 328ms/step - loss: 1.5213 - acc: 0.7833 - auc: 0.9729 - precision: 0.8017 - recall: 0.7678 - val_loss: 0.7604 - val_acc: 0.7280 - val_auc: 0.9552 - val_precision: 0.7467 - val_recall: 0.7135
#
# Epoch 00054: val_auc did not improve from 0.98153
# Epoch 55/100
# 557/557 [==============================] - 183s 328ms/step - loss: 1.5335 - acc: 0.7718 - auc: 0.9719 - precision: 0.7877 - recall: 0.7563 - val_loss: 0.5559 - val_acc: 0.8187 - val_auc: 0.9728 - val_precision: 0.8301 - val_recall: 0.8060
#
# Epoch 00055: val_auc did not improve from 0.98153
# Epoch 56/100
# 557/557 [==============================] - 183s 327ms/step - loss: 1.3665 - acc: 0.7915 - auc: 0.9755 - precision: 0.8049 - recall: 0.7781 - val_loss: 0.4653 - val_acc: 0.8441 - val_auc: 0.9792 - val_precision: 0.8574 - val_recall: 0.8341
#
# Epoch 00056: val_auc did not improve from 0.98153
# Epoch 57/100
# 557/557 [==============================] - 182s 327ms/step - loss: 1.6223 - acc: 0.7746 - auc: 0.9721 - precision: 0.7935 - recall: 0.7572 - val_loss: 0.4363 - val_acc: 0.8577 - val_auc: 0.9814 - val_precision: 0.8682 - val_recall: 0.8422
#
# Epoch 00057: val_auc did not improve from 0.98153
# Epoch 58/100
# 557/557 [==============================] - 183s 328ms/step - loss: 1.3259 - acc: 0.7986 - auc: 0.9771 - precision: 0.8132 - recall: 0.7869 - val_loss: 0.6222 - val_acc: 0.7815 - val_auc: 0.9682 - val_precision: 0.8052 - val_recall: 0.7643
#
# Epoch 00058: val_auc did not improve from 0.98153
# Epoch 59/100
# 557/557 [==============================] - 182s 327ms/step - loss: 1.4650 - acc: 0.7919 - auc: 0.9751 - precision: 0.8073 - recall: 0.7782 - val_loss: 0.4430 - val_acc: 0.8495 - val_auc: 0.9809 - val_precision: 0.8638 - val_recall: 0.8450
#
# Epoch 00059: val_auc did not improve from 0.98153
# Epoch 60/100
# 557/557 [==============================] - 183s 328ms/step - loss: 1.2596 - acc: 0.8092 - auc: 0.9787 - precision: 0.8215 - recall: 0.7978 - val_loss: 0.5254 - val_acc: 0.8132 - val_auc: 0.9748 - val_precision: 0.8349 - val_recall: 0.8069
#
# Epoch 00060: val_auc did not improve from 0.98153
# Epoch 61/100
# 557/557 [==============================] - 183s 327ms/step - loss: 1.3816 - acc: 0.7968 - auc: 0.9768 - precision: 0.8091 - recall: 0.7836 - val_loss: 0.5023 - val_acc: 0.8377 - val_auc: 0.9767 - val_precision: 0.8474 - val_recall: 0.8305
#
# Epoch 00061: val_auc did not improve from 0.98153
# Epoch 62/100
# 557/557 [==============================] - 183s 327ms/step - loss: 1.1875 - acc: 0.8173 - auc: 0.9793 - precision: 0.8286 - recall: 0.8076 - val_loss: 0.4137 - val_acc: 0.8540 - val_auc: 0.9835 - val_precision: 0.8728 - val_recall: 0.8459
#
# Epoch 00062: val_auc improved from 0.98153 to 0.98352, saving model to /content/drive/MyDrive/TCC-Melo/Kaggle/modelos_checkPoint/ResNet50V2_folder_1.h5
# Epoch 63/100
# 557/557 [==============================] - 183s 327ms/step - loss: 1.2069 - acc: 0.8153 - auc: 0.9799 - precision: 0.8260 - recall: 0.8072 - val_loss: 0.5189 - val_acc: 0.8332 - val_auc: 0.9761 - val_precision: 0.8433 - val_recall: 0.8296
#
# Epoch 00063: val_auc did not improve from 0.98352
# Epoch 64/100
# 557/557 [==============================] - 183s 327ms/step - loss: 1.1617 - acc: 0.8255 - auc: 0.9808 - precision: 0.8381 - recall: 0.8168 - val_loss: 0.5953 - val_acc: 0.7933 - val_auc: 0.9697 - val_precision: 0.8058 - val_recall: 0.7788
#
# Epoch 00064: val_auc did not improve from 0.98352
# Epoch 65/100
# 557/557 [==============================] - 183s 327ms/step - loss: 1.1874 - acc: 0.8101 - auc: 0.9799 - precision: 0.8225 - recall: 0.7999 - val_loss: 0.4632 - val_acc: 0.8604 - val_auc: 0.9794 - val_precision: 0.8675 - val_recall: 0.8549
#
# Epoch 00065: val_auc did not improve from 0.98352
# Epoch 66/100
# 557/557 [==============================] - 183s 328ms/step - loss: 0.9904 - acc: 0.8377 - auc: 0.9833 - precision: 0.8474 - recall: 0.8298 - val_loss: 0.6669 - val_acc: 0.7860 - val_auc: 0.9657 - val_precision: 0.7972 - val_recall: 0.7733
#
# Epoch 00066: val_auc did not improve from 0.98352
# Epoch 67/100
# 557/557 [==============================] - 183s 328ms/step - loss: 1.0763 - acc: 0.8326 - auc: 0.9827 - precision: 0.8441 - recall: 0.8235 - val_loss: 0.4466 - val_acc: 0.8640 - val_auc: 0.9792 - val_precision: 0.8689 - val_recall: 0.8531
#
# Epoch 00067: val_auc did not improve from 0.98352
# Epoch 68/100
# 557/557 [==============================] - 183s 327ms/step - loss: 1.0002 - acc: 0.8439 - auc: 0.9832 - precision: 0.8539 - recall: 0.8348 - val_loss: 0.6255 - val_acc: 0.7942 - val_auc: 0.9686 - val_precision: 0.8076 - val_recall: 0.7879
#
# Epoch 00068: val_auc did not improve from 0.98352
# Epoch 69/100
# 557/557 [==============================] - 183s 328ms/step - loss: 1.0426 - acc: 0.8362 - auc: 0.9838 - precision: 0.8468 - recall: 0.8281 - val_loss: 0.4892 - val_acc: 0.8495 - val_auc: 0.9770 - val_precision: 0.8532 - val_recall: 0.8432
#
# Epoch 00069: val_auc did not improve from 0.98352
# Epoch 70/100
# 557/557 [==============================] - 183s 328ms/step - loss: 1.0369 - acc: 0.8426 - auc: 0.9833 - precision: 0.8529 - recall: 0.8338 - val_loss: 0.4920 - val_acc: 0.8368 - val_auc: 0.9775 - val_precision: 0.8489 - val_recall: 0.8305
#
# Epoch 00070: val_auc did not improve from 0.98352
# Epoch 71/100
# 557/557 [==============================] - 183s 328ms/step - loss: 1.0176 - acc: 0.8443 - auc: 0.9844 - precision: 0.8557 - recall: 0.8345 - val_loss: 0.4807 - val_acc: 0.8504 - val_auc: 0.9792 - val_precision: 0.8578 - val_recall: 0.8422
#
# Epoch 00071: val_auc did not improve from 0.98352
# Epoch 72/100
# 557/557 [==============================] - 183s 328ms/step - loss: 0.8943 - acc: 0.8565 - auc: 0.9863 - precision: 0.8670 - recall: 0.8487 - val_loss: 0.4646 - val_acc: 0.8613 - val_auc: 0.9769 - val_precision: 0.8744 - val_recall: 0.8522
#
# Epoch 00072: val_auc did not improve from 0.98352
# Epoch 73/100
# 557/557 [==============================] - 183s 328ms/step - loss: 1.0823 - acc: 0.8357 - auc: 0.9833 - precision: 0.8474 - recall: 0.8282 - val_loss: 0.5003 - val_acc: 0.8441 - val_auc: 0.9780 - val_precision: 0.8519 - val_recall: 0.8395
#
# Epoch 00073: val_auc did not improve from 0.98352
# Epoch 74/100
# 557/557 [==============================] - 183s 328ms/step - loss: 0.8820 - acc: 0.8609 - auc: 0.9868 - precision: 0.8713 - recall: 0.8526 - val_loss: 0.9843 - val_acc: 0.6763 - val_auc: 0.9363 - val_precision: 0.6964 - val_recall: 0.6591
#
# Epoch 00074: val_auc did not improve from 0.98352
# Epoch 75/100
# 557/557 [==============================] - 183s 328ms/step - loss: 0.9183 - acc: 0.8565 - auc: 0.9863 - precision: 0.8686 - recall: 0.8481 - val_loss: 0.5093 - val_acc: 0.8477 - val_auc: 0.9765 - val_precision: 0.8582 - val_recall: 0.8450
#
# Epoch 00075: val_auc did not improve from 0.98352
# Epoch 76/100
# 557/557 [==============================] - 183s 328ms/step - loss: 0.7942 - acc: 0.8777 - auc: 0.9885 - precision: 0.8869 - recall: 0.8717 - val_loss: 0.5351 - val_acc: 0.8459 - val_auc: 0.9744 - val_precision: 0.8615 - val_recall: 0.8404
#
# Epoch 00076: val_auc did not improve from 0.98352
# Epoch 77/100
# 557/557 [==============================] - 183s 328ms/step - loss: 0.9149 - acc: 0.8578 - auc: 0.9864 - precision: 0.8678 - recall: 0.8498 - val_loss: 0.4850 - val_acc: 0.8558 - val_auc: 0.9782 - val_precision: 0.8667 - val_recall: 0.8486
#
# Epoch 00077: val_auc did not improve from 0.98352
# Epoch 00077: early stopping

# %% [markdown]
# ### 3.2.4. Avaliando o treinamento do modelo

# %%
acc += history_fine.history['acc']
val_acc += history_fine.history['val_acc']

loss += history_fine.history['loss']
val_loss += history_fine.history['val_loss']

# %%
plt.figure(figsize=(8, 8))
plt.subplot(2, 1, 1)
plt.plot(acc, label='Acuracia de treinamento')
plt.plot(val_acc, label='Acuracia de validação')
plt.ylim([0, 1])
plt.plot([first_epoch-1,first_epoch-1],
          plt.ylim(), label='Começo do Fine Tuning')
plt.legend(loc='lower right')
plt.title('Acuracia do treinamento e validação')

plt.subplot(2, 1, 2)
plt.plot(loss, label='Perda do treinamento')
plt.plot(val_loss, label='Perda da validação')
plt.ylim([0, 8])
plt.plot([first_epoch-1,first_epoch-1],
         plt.ylim(), label='Começo do Fine Tuning')
plt.legend(loc='upper right')
plt.title('Perda do treinamento e validação')
plt.xlabel('epoca')
plt.show()

# %% [markdown]
# #### 3.2.4.1. Verificando CLR

# %%
clr.plot_lr((14, 3.5))

# %% [markdown]
# # 4. Avaliando o modelo

# %%
model.load_weights(save_dir + str(nomeDoModelo)+'_folder_'+ str(fold_var)+'.h5')
# model_all = tf.keras.models.load_model(save_dir + str(nomeDoModelo)+'_folder_'+ str(fold_var)+'.h5')

# %%
model.evaluate(val_ds)
# Out:
# 69/69 [==============================] - 7s 98ms/step - loss: 0.4137 - acc: 0.8540 - auc: 0.9835 - precision: 0.8728 - recall: 0.8459
# [0.413669228553772,
#  0.854034423828125,
#  0.9835184216499329,
#  0.8727782964706421,
#  0.8458749055862427]

# %% [markdown]
# ## 4.1. Realizando as previsões

# %%
# Obtendo a tabela verdade 
true_categories = tf.concat([y for x, y in val_ds], axis=0)
true_categories  = tf.argmax(true_categories , axis=1)

# %%
# Realizando as previsões
predictions = model.predict(val_ds, verbose=1)
y_pred = tf.argmax(predictions, axis=1)
# Out:
# 69/69 [==============================] - 7s 89ms/step

# %% [markdown]
# ## 4.3. Metricas de avaliação

# %% [markdown]
# ### 4.3.1. Quadro de metricas

# %%
cm_plot_labels = ['akiec', 'bcc', 'bkl', 'df', 'mel','nv', 'vasc']
print(classification_report(true_categories , y_pred, target_names=cm_plot_labels))
# Out:
#               precision    recall  f1-score   support
#
#        akiec       0.59      0.57      0.58        30
#          bcc       0.64      0.77      0.70        35
#          bkl       0.56      0.82      0.66        88
#           df       0.78      0.88      0.82         8
#          mel       0.31      0.63      0.41        46
#           nv       0.99      0.88      0.93       883
#         vasc       0.86      0.92      0.89        13
#
#     accuracy                           0.85      1103
#    macro avg       0.67      0.78      0.71      1103
# weighted avg       0.90      0.85      0.87      1103

# %% [markdown]
# ### 4.3.2. Matriz de confusão

# %%
cm = confusion_matrix(true_categories , y_pred)
fig, ax = plot_confusion_matrix(conf_mat=cm,
                                show_absolute=True,
                                show_normed=True, 
                                class_names=cm_plot_labels)

# %% [markdown]
# ### 4.3.3. Acurácia balanceada

# %%
bAcc= sklearn.metrics.balanced_accuracy_score(true_categories, y_pred)
print(f'Acurácia balanceada: {bAcc*100:.6f}%')
# Out:
# Acurácia balanceada: 78.083942%
