# %% [markdown]
# # 1. Comando Iniciais

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## 1.1. Importando Bibliotecas

# %%
# !pip install mlxtend --upgrade --no-deps # Versão do Mlxtend: 0.19.0
# Out:
# Requirement already satisfied: mlxtend in /usr/local/lib/python3.7/dist-packages (0.14.0)
# Collecting mlxtend
#   Downloading mlxtend-0.19.0-py2.py3-none-any.whl (1.3 MB)
#      |████████████████████████████████| 1.3 MB 8.8 MB/s
# Installing collected packages: mlxtend
#   Attempting uninstall: mlxtend
#     Found existing installation: mlxtend 0.14.0
#     Uninstalling mlxtend-0.14.0:
#       Successfully uninstalled mlxtend-0.14.0
# Successfully installed mlxtend-0.19.0

# %%
import numpy as np
import pandas as pd

import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
import plotly 
import plotly.express as px

import tensorflow as tf
from tensorflow.keras.layers import Dense, Dropout, Conv2D, Flatten, GlobalAveragePooling2D, Input
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.preprocessing import image_dataset_from_directory
from tensorflow.keras.models import Model
from tensorflow.keras.callbacks import ReduceLROnPlateau, ModelCheckpoint, EarlyStopping
from tensorflow.keras.metrics import CategoricalAccuracy, AUC, Precision, Recall
from tensorflow import keras

import sklearn
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import confusion_matrix, classification_report

import mlxtend
from mlxtend.plotting import plot_confusion_matrix

import itertools

import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# %%
# Utility Script - Criados dentro do Kaggle Code, devido ao fato que são modulo customizados 
# %cd /content/drive/MyDrive/TCC-Melo/Kaggle/
from lrfinder import *
from cyclicallr import *
# Out:
# /content/drive/MyDrive/TCC-Melo/Kaggle

# %% [markdown]
# ### 1.1.1. Demostrando versões das bibliotecas

# %%
print(f'Versão do Numpy: {np.__version__}')
print(f'Versão do Pandas: {pd.__version__}')
print(f'Versão do Matplotlib: {mpl.__version__}')
print(f'Versão do Season: {sns.__version__}')
print(f'Versão do Plotly: {plotly.__version__}')
print(f'Versão do TensorFlow: {tf.__version__}')
print(f'Versão do Keras: {keras.__version__}')
print(f'Versão do Sklearn: {sklearn.__version__}')
print(f'Versão do Mlxtend: {mlxtend.__version__}')
# Out:
# Versão do Numpy: 1.19.5
# Versão do Pandas: 1.1.5
# Versão do Matplotlib: 3.2.2
# Versão do Season: 0.11.2
# Versão do Plotly: 4.4.1
# Versão do TensorFlow: 2.6.0
# Versão do Keras: 2.6.0
# Versão do Sklearn: 0.22.2.post1
# Versão do Mlxtend: 0.19.0

# %% [markdown]
# ## 1.2. Verificando Accelerator

# %%
gpu_info = !nvidia-smi
gpu_info = '\n'.join(gpu_info)
if gpu_info.find('failed') >= 0:
  print('Not connected to a GPU')
else:
  print(gpu_info)
# Out:
# Sun Oct  3 16:35:05 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 470.74       Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   40C    P0    27W / 250W |      0MiB / 16280MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
gpus = tf.config.list_physical_devices('GPU')
for gpu in gpus:
    print("Name:", gpu.name, "  Type:", gpu.device_type)
tf.test.is_gpu_available()
# Out:
# Name: /physical_device:GPU:0   Type: GPU
# WARNING:tensorflow:From <ipython-input-7-f99a3e65d632>:4: is_gpu_available (from tensorflow.python.framework.test_util) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.config.list_physical_devices('GPU')` instead.
# True

# %% [markdown]
# ## 1.3. Variaveis Globais

# %%
# Caminho para salvar os melhores modelos do callback checkpoint
save_dir = '/content/drive/MyDrive/TCC-Melo/Kaggle/modelos_checkPoint/'

# Caminho dos Folds
fold_var = 5 # Folder selecionado

train_path = f'/content/drive/MyDrive/TCC-Melo/Dados/Folds_Modified/fold_{fold_var}/train_dir'    # Imagens em JPG separadas em folders
valid_path = f'/content/drive/MyDrive/TCC-Melo/Dados/Folds_Modified/fold_{fold_var}/val_dir'    # Imagens em JPG separadas em folders

# Ordem das categorias
classes = ['AKIEC', 'BCC', 'BKL', 'DF', 'MEL', 'NV', 'VASC']
#         [0      , 1    , 2    , 3   , 4    , 5   , 6]

# Tamanho da batch
batch_size = 16

# Dimensão das imagens de entrada
image_size = (448, 448)

# Numero de epochs
## Primeiro Momento:
first_epoch = 30

## Segundo Momento:
second_epoch = first_epoch + 70

# Calculando os passos para o treinamento
if fold_var != 5:
  train_steps = np.ceil(8912 / batch_size)
  val_steps = np.ceil(1103 / batch_size)
  print('Opção 1')
else:
  train_steps = np.ceil(8913 / batch_size)
  val_steps = np.ceil(1102 / batch_size)
  print('Opção 2')


# Carregando os pesos para as categorias para o treinamento 
weights_train_dict = {0: 15, 1: 10, 2: 5, 3: 42,
                      4: 20, 5: 1, 6: 35}
# Out:
# Opção 2

# %% [markdown]
# ## 1.4. Metricas de avaliação

# %%
metricasEscolhidas = [CategoricalAccuracy(name='acc'), 
                      AUC(name='auc'),
                      Precision(name='precision'), 
                      Recall(name='recall')]

# %% [markdown]
# ## 1.5. Carregando os dados

# %% [markdown]
#  ### 1.5.1. Treinamento

# %%
train_ds = image_dataset_from_directory(train_path,
                                        batch_size=batch_size,
                                        image_size = image_size,
                                        label_mode='categorical',
                                        shuffle=True,
                                        seed=42)
# Out:
# Found 8913 files belonging to 7 classes.

# %%
val_ds = image_dataset_from_directory(valid_path,
                                      batch_size=batch_size,
                                      image_size = image_size,
                                      label_mode='categorical',
                                      shuffle=False,
                                      seed=42)
# Out:
# Found 1102 files belonging to 7 classes.

# %% [markdown]
# #### 1.5.1.1. Alta velocidade de treinamento

# %%
for image_batch, labels_batch in train_ds:
  print(image_batch.shape)
  print(labels_batch.shape)
  break
# Out:
# (16, 448, 448, 3)
# (16, 7)

# %%
AUTOTUNE = tf.data.AUTOTUNE

#train_ds = train_ds.cache().prefetch(buffer_size=AUTOTUNE)
train_ds = train_ds.prefetch(buffer_size=AUTOTUNE)
#val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.prefetch(buffer_size=AUTOTUNE)

# %% [markdown]
# ## 1.6. Modelo Pré-treinado

# %%
num_model = 4

# %% [markdown]
# ### 1.6.1. Selecionando modelo

# %%
if num_model == 1:
    nomeDoModelo = 'DenseNet121'
    modelo = tf.keras.applications.DenseNet121(weights='imagenet', 
                                               include_top=False, 
                                               input_tensor=Input(shape=image_size+(3,)))
elif num_model == 2:
    nomeDoModelo = 'DenseNet169'
    modelo = tf.keras.applications.DenseNet169(weights='imagenet', 
                                               include_top=False, 
                                               input_tensor=Input(shape=image_size+(3,)))
elif num_model == 3:
    nomeDoModelo = 'DenseNet201'
    modelo = tf.keras.applications.DenseNet201(weights='imagenet', 
                                               include_top=False, 
                                               input_tensor=Input(shape=image_size+(3,)))
elif num_model == 4:
    nomeDoModelo = 'ResNet50V2'
    modelo = tf.keras.applications.ResNet50V2(weights='imagenet', 
                                               include_top=False, 
                                               input_tensor=Input(shape=image_size+(3,)))
elif num_model == 5:
    nomeDoModelo = 'ResNet101V2'
    modelo = tf.keras.applications.ResNet101V2(weights='imagenet', 
                                               include_top=False, 
                                               input_tensor=Input(shape=image_size+(3,)))
elif num_model == 6:
    nomeDoModelo = 'ResNet152V2'
    modelo = tf.keras.applications.ResNet152V2(weights='imagenet', 
                                               include_top=False, 
                                               input_tensor=Input(shape=image_size+(3,)))
elif num_model == 7:
    nomeDoModelo = 'Xception'
    modelo = tf.keras.applications.Xception(weights='imagenet', 
                                               include_top=False, 
                                               input_tensor=Input(shape=image_size+(3,)))
elif num_model == 8:
    nomeDoModelo = 'InceptionV3'
    modelo = tf.keras.applications.InceptionV3(weights='imagenet', 
                                               include_top=False, 
                                               input_tensor=Input(shape=image_size+(3,)))
elif num_model == 9:
    nomeDoModelo = 'InceptionResNetV2'
    modelo = tf.keras.applications.InceptionResNetV2(weights='imagenet', 
                                               include_top=False, 
                                               input_tensor=Input(shape=image_size+(3,)))
elif num_model == 10:
    nomeDoModelo = 'EfficientNetB0'
    modelo = tf.keras.applications.EfficientNetB0(weights='imagenet', 
                                               include_top=False, 
                                               input_tensor=Input(shape=image_size+(3,)))
elif num_model == 11:
    nomeDoModelo = 'EfficientNetB1'
    modelo = tf.keras.applications.EfficientNetB1(weights='imagenet', 
                                               include_top=False, 
                                               input_tensor=Input(shape=image_size+(3,)))
elif num_model == 12:
    nomeDoModelo = 'EfficientNetB2'
    modelo = tf.keras.applications.EfficientNetB2(weights='imagenet', 
                                               include_top=False, 
                                               input_tensor=Input(shape=image_size+(3,)))
elif num_model == 13:
    nomeDoModelo = 'EfficientNetB3'
    modelo = tf.keras.applications.EfficientNetB3(weights='imagenet', 
                                               include_top=False, 
                                               input_tensor=Input(shape=image_size+(3,)))
    
print(f'O modelo selecionado foi {nomeDoModelo}')
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50v2_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94674944/94668760 [==============================] - 1s 0us/step
# 94683136/94668760 [==============================] - 1s 0us/step
# O modelo selecionado foi ResNet50V2

# %% [markdown]
# # 2. Preprocessamento

# %% [markdown]
# ## 2.1. Camada de aumento de dados

# %%
camada_ad = tf.keras.Sequential([
  tf.keras.layers.experimental.preprocessing.RandomFlip('horizontal'),
  tf.keras.layers.experimental.preprocessing.RandomFlip('vertical'),
  tf.keras.layers.experimental.preprocessing.RandomRotation(0.3),
  tf.keras.layers.experimental.preprocessing.RandomContrast((0.8, 1.1)),
], name='data_augmentation')

# %% [markdown]
# ## 2.2. Camada de reescalonamento

# %%
if num_model in [1, 2, 3]:
    camada_reescal = tf.keras.applications.densenet.preprocess_input
elif num_model in [4, 5, 6]:
    camada_reescal = tf.keras.applications.resnet_v2.preprocess_input
elif num_model == 7:
    camada_reescal = tf.keras.applications.xception.preprocess_input
elif num_model == 8:
    camada_reescal = tf.keras.applications.inception_v3.preprocess_input
elif num_model == 9:
    camada_reescal = tf.keras.applications.inception_resnet_v2.preprocess_input
elif num_model in [10, 11, 12, 13]:
    camada_reescal = tf.keras.applications.efficientnet.preprocess_input
    
print(f'A camada selecionada foi {camada_reescal}')
# Out:
# A camada selecionada foi <function preprocess_input at 0x7fb234b72320>

# %% [markdown]
# # 3. Classificação

# %% [markdown]
# ## 3.1. Criando o modelo: Primeiro Momento

# %%
modelBase = modelo

modelBase.trainable = False # Congelando os pesos do modelo base

inputs = tf.keras.Input(shape=image_size+(3,))
x = camada_ad(inputs)
x = camada_reescal(x)
x = modelBase(x, training=False) # Deixando o modelo em modo enferência por causa das camadas BatchNormalization
x = GlobalAveragePooling2D()(x)
x = Dropout(0.3)(x)
predictions = Dense(7, activation='softmax')(x)
model = tf.keras.Model(inputs, predictions, name=nomeDoModelo)

# %%
model.summary()
# Out:
# Model: "ResNet50V2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         [(None, 448, 448, 3)]     0
# _________________________________________________________________
# data_augmentation (Sequentia (None, 448, 448, 3)       0
# _________________________________________________________________
# tf.math.truediv (TFOpLambda) (None, 448, 448, 3)       0
# _________________________________________________________________
# tf.math.subtract (TFOpLambda (None, 448, 448, 3)       0
# _________________________________________________________________
# resnet50v2 (Functional)      (None, 14, 14, 2048)      23564800
# _________________________________________________________________
# global_average_pooling2d (Gl (None, 2048)              0
# _________________________________________________________________
# dropout (Dropout)            (None, 2048)              0
# _________________________________________________________________
# dense (Dense)                (None, 7)                 14343
# =================================================================
# Total params: 23,579,143
# Trainable params: 14,343
# Non-trainable params: 23,564,800
# _________________________________________________________________

# %% [markdown]
# ### 3.1.1. Buscando a taxa de aprendizado: LRFinder 1

# %%
optimizer = tf.keras.optimizers.Adam()
loss_fn = tf.keras.losses.CategoricalCrossentropy()

# %%
lr_find = LrFinder(model, optimizer, loss_fn)
lr_find.range_test(train_ds)
lr_find.plot_lrs(suggestion=True, show_grid=True)
# Out:
# Finding best initial lr over 100 steps
#   0%|          | 0/100 [00:00<?, ?it/s]
# LR Finder is complete, type {LrFinder}.plot_lrs() to see the graph.
# Min numerical gradient: 1.00E-03
# Min loss divided by 10: 2.29E-03

# %%
base_lr = 1e-03

# %% [markdown]
# ### 3.1.2. Treinando

# %%
model.compile(optimizer=Adam(learning_rate= base_lr), 
              loss=tf.keras.losses.CategoricalCrossentropy(), 
              metrics=metricasEscolhidas)

# %%
history = model.fit(train_ds,
                    class_weight = weights_train_dict,
                    steps_per_epoch = train_steps,
                    epochs=first_epoch,
                    validation_data=val_ds,
                    validation_steps = val_steps)
# Out:
# Epoch 1/30
# 558/558 [==============================] - 647s 1s/step - loss: 8.2490 - acc: 0.3392 - auc: 0.7618 - precision: 0.3823 - recall: 0.1885 - val_loss: 1.1040 - val_acc: 0.5771 - val_auc: 0.8980 - val_precision: 0.6819 - val_recall: 0.4065
# Epoch 2/30
# 558/558 [==============================] - 67s 119ms/step - loss: 6.5542 - acc: 0.4396 - auc: 0.8271 - precision: 0.4978 - recall: 0.3084 - val_loss: 1.2841 - val_acc: 0.4819 - val_auc: 0.8656 - val_precision: 0.5351 - val_recall: 0.3666
# Epoch 3/30
# 558/558 [==============================] - 67s 119ms/step - loss: 6.3434 - acc: 0.4410 - auc: 0.8341 - precision: 0.4883 - recall: 0.3266 - val_loss: 1.0544 - val_acc: 0.5935 - val_auc: 0.9070 - val_precision: 0.6423 - val_recall: 0.4791
# Epoch 4/30
# 558/558 [==============================] - 67s 119ms/step - loss: 5.9873 - acc: 0.4749 - auc: 0.8526 - precision: 0.5321 - recall: 0.3656 - val_loss: 1.1464 - val_acc: 0.5481 - val_auc: 0.8914 - val_precision: 0.6040 - val_recall: 0.4347
# Epoch 5/30
# 558/558 [==============================] - 67s 119ms/step - loss: 5.8345 - acc: 0.4850 - auc: 0.8583 - precision: 0.5429 - recall: 0.3858 - val_loss: 1.3518 - val_acc: 0.4719 - val_auc: 0.8564 - val_precision: 0.5184 - val_recall: 0.3702
# Epoch 6/30
# 558/558 [==============================] - 67s 119ms/step - loss: 5.7418 - acc: 0.4856 - auc: 0.8623 - precision: 0.5427 - recall: 0.3909 - val_loss: 1.3853 - val_acc: 0.4437 - val_auc: 0.8543 - val_precision: 0.4656 - val_recall: 0.3557
# Epoch 7/30
# 558/558 [==============================] - 67s 119ms/step - loss: 5.8094 - acc: 0.4815 - auc: 0.8586 - precision: 0.5342 - recall: 0.3910 - val_loss: 1.0535 - val_acc: 0.5944 - val_auc: 0.9093 - val_precision: 0.6517 - val_recall: 0.5145
# Epoch 8/30
# 558/558 [==============================] - 67s 119ms/step - loss: 5.6683 - acc: 0.5012 - auc: 0.8658 - precision: 0.5547 - recall: 0.4130 - val_loss: 1.0689 - val_acc: 0.5762 - val_auc: 0.9064 - val_precision: 0.6266 - val_recall: 0.5009
# Epoch 9/30
# 558/558 [==============================] - 67s 119ms/step - loss: 5.6331 - acc: 0.5048 - auc: 0.8711 - precision: 0.5542 - recall: 0.4174 - val_loss: 1.2372 - val_acc: 0.5145 - val_auc: 0.8789 - val_precision: 0.5664 - val_recall: 0.4220
# Epoch 10/30
# 558/558 [==============================] - 67s 119ms/step - loss: 5.4061 - acc: 0.5174 - auc: 0.8743 - precision: 0.5609 - recall: 0.4317 - val_loss: 1.4763 - val_acc: 0.3920 - val_auc: 0.8467 - val_precision: 0.4076 - val_recall: 0.3303
# Epoch 11/30
# 558/558 [==============================] - 67s 119ms/step - loss: 5.3641 - acc: 0.5054 - auc: 0.8708 - precision: 0.5471 - recall: 0.4219 - val_loss: 0.8234 - val_acc: 0.7005 - val_auc: 0.9430 - val_precision: 0.7657 - val_recall: 0.6289
# Epoch 12/30
# 558/558 [==============================] - 67s 119ms/step - loss: 5.4444 - acc: 0.5041 - auc: 0.8690 - precision: 0.5478 - recall: 0.4252 - val_loss: 0.9625 - val_acc: 0.6416 - val_auc: 0.9241 - val_precision: 0.6893 - val_recall: 0.5717
# Epoch 13/30
# 558/558 [==============================] - 67s 119ms/step - loss: 5.4077 - acc: 0.5192 - auc: 0.8763 - precision: 0.5634 - recall: 0.4431 - val_loss: 1.3672 - val_acc: 0.4474 - val_auc: 0.8626 - val_precision: 0.4690 - val_recall: 0.3702
# Epoch 14/30
# 558/558 [==============================] - 67s 119ms/step - loss: 5.4686 - acc: 0.4955 - auc: 0.8642 - precision: 0.5371 - recall: 0.4169 - val_loss: 1.1385 - val_acc: 0.5535 - val_auc: 0.8979 - val_precision: 0.5932 - val_recall: 0.4936
# Epoch 15/30
# 558/558 [==============================] - 67s 119ms/step - loss: 5.4083 - acc: 0.5057 - auc: 0.8701 - precision: 0.5510 - recall: 0.4335 - val_loss: 0.8997 - val_acc: 0.6770 - val_auc: 0.9323 - val_precision: 0.7263 - val_recall: 0.5898
# Epoch 16/30
# 558/558 [==============================] - 67s 119ms/step - loss: 5.2827 - acc: 0.5089 - auc: 0.8731 - precision: 0.5522 - recall: 0.4362 - val_loss: 0.9414 - val_acc: 0.6497 - val_auc: 0.9261 - val_precision: 0.6926 - val_recall: 0.5808
# Epoch 17/30
# 558/558 [==============================] - 67s 120ms/step - loss: 5.4568 - acc: 0.5196 - auc: 0.8777 - precision: 0.5657 - recall: 0.4495 - val_loss: 0.9344 - val_acc: 0.6452 - val_auc: 0.9277 - val_precision: 0.6922 - val_recall: 0.5898
# Epoch 18/30
# 558/558 [==============================] - 67s 119ms/step - loss: 5.1967 - acc: 0.5106 - auc: 0.8745 - precision: 0.5563 - recall: 0.4410 - val_loss: 0.8401 - val_acc: 0.6833 - val_auc: 0.9404 - val_precision: 0.7459 - val_recall: 0.6180
# Epoch 19/30
# 558/558 [==============================] - 67s 120ms/step - loss: 5.3970 - acc: 0.5122 - auc: 0.8744 - precision: 0.5563 - recall: 0.4410 - val_loss: 1.1476 - val_acc: 0.5517 - val_auc: 0.8996 - val_precision: 0.5761 - val_recall: 0.4946
# Epoch 20/30
# 558/558 [==============================] - 67s 120ms/step - loss: 5.3048 - acc: 0.5205 - auc: 0.8778 - precision: 0.5622 - recall: 0.4521 - val_loss: 0.9790 - val_acc: 0.6407 - val_auc: 0.9202 - val_precision: 0.6905 - val_recall: 0.5426
# Epoch 21/30
# 558/558 [==============================] - 67s 119ms/step - loss: 5.3309 - acc: 0.5211 - auc: 0.8793 - precision: 0.5599 - recall: 0.4468 - val_loss: 1.0590 - val_acc: 0.5926 - val_auc: 0.9115 - val_precision: 0.6259 - val_recall: 0.5390
# Epoch 22/30
# 558/558 [==============================] - 67s 120ms/step - loss: 5.2510 - acc: 0.5118 - auc: 0.8762 - precision: 0.5554 - recall: 0.4434 - val_loss: 0.8311 - val_acc: 0.7069 - val_auc: 0.9415 - val_precision: 0.7573 - val_recall: 0.6316
# Epoch 23/30
# 558/558 [==============================] - 67s 119ms/step - loss: 5.1696 - acc: 0.5272 - auc: 0.8795 - precision: 0.5642 - recall: 0.4548 - val_loss: 1.0366 - val_acc: 0.5953 - val_auc: 0.9141 - val_precision: 0.6172 - val_recall: 0.5354
# Epoch 24/30
# 558/558 [==============================] - 67s 119ms/step - loss: 5.3192 - acc: 0.5198 - auc: 0.8790 - precision: 0.5610 - recall: 0.4559 - val_loss: 1.0995 - val_acc: 0.5690 - val_auc: 0.9053 - val_precision: 0.5936 - val_recall: 0.5181
# Epoch 25/30
# 558/558 [==============================] - 67s 119ms/step - loss: 5.2365 - acc: 0.5182 - auc: 0.8796 - precision: 0.5601 - recall: 0.4493 - val_loss: 1.0536 - val_acc: 0.6034 - val_auc: 0.9116 - val_precision: 0.6429 - val_recall: 0.5390
# Epoch 26/30
# 558/558 [==============================] - 67s 119ms/step - loss: 5.3034 - acc: 0.5142 - auc: 0.8777 - precision: 0.5583 - recall: 0.4477 - val_loss: 1.0333 - val_acc: 0.6125 - val_auc: 0.9144 - val_precision: 0.6480 - val_recall: 0.5463
# Epoch 27/30
# 558/558 [==============================] - 67s 119ms/step - loss: 5.1394 - acc: 0.5247 - auc: 0.8801 - precision: 0.5692 - recall: 0.4585 - val_loss: 1.0747 - val_acc: 0.5989 - val_auc: 0.9086 - val_precision: 0.6463 - val_recall: 0.5290
# Epoch 28/30
# 558/558 [==============================] - 67s 119ms/step - loss: 5.2148 - acc: 0.5171 - auc: 0.8795 - precision: 0.5597 - recall: 0.4551 - val_loss: 0.8855 - val_acc: 0.6751 - val_auc: 0.9349 - val_precision: 0.7131 - val_recall: 0.6225
# Epoch 29/30
# 558/558 [==============================] - 67s 119ms/step - loss: 5.3463 - acc: 0.5223 - auc: 0.8812 - precision: 0.5624 - recall: 0.4579 - val_loss: 0.8900 - val_acc: 0.6597 - val_auc: 0.9340 - val_precision: 0.7120 - val_recall: 0.6080
# Epoch 30/30
# 558/558 [==============================] - 67s 119ms/step - loss: 5.3002 - acc: 0.5278 - auc: 0.8823 - precision: 0.5693 - recall: 0.4606 - val_loss: 0.9310 - val_acc: 0.6552 - val_auc: 0.9287 - val_precision: 0.6914 - val_recall: 0.5998

# %% [markdown]
# ### 3.1.3. Avaliando o treinamento do modelo

# %%
acc = history.history['acc']
val_acc = history.history['val_acc']

loss = history.history['loss']
val_loss = history.history['val_loss']

plt.figure(figsize=(8, 8))
plt.subplot(2, 1, 1)
plt.plot(acc, label='Acuracia do treinamento')
plt.plot(val_acc, label='Acuracia da validação')
plt.legend(loc='lower right')
plt.ylabel('Acuracia')
plt.ylim([0,1])
plt.title('Acuracia do treinamento e validação')

plt.subplot(2, 1, 2)
plt.plot(loss, label='Perda do treinamento')
plt.plot(val_loss, label='Perda da validação')
plt.legend(loc='upper right')
plt.ylabel('Entropia Cruzada')
plt.ylim([0,8])
plt.title('Perda do treinamento e validação')
plt.xlabel('epoca')
plt.show()

# %% [markdown]
# ## 3.2. Criando o modelo: Segundo Momento

# %%
modelBase.trainable = True # Descongelando os pesos do modelo base para o treinamento

# %%
model.summary()
# Out:
# Model: "ResNet50V2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         [(None, 448, 448, 3)]     0
# _________________________________________________________________
# data_augmentation (Sequentia (None, 448, 448, 3)       0
# _________________________________________________________________
# tf.math.truediv (TFOpLambda) (None, 448, 448, 3)       0
# _________________________________________________________________
# tf.math.subtract (TFOpLambda (None, 448, 448, 3)       0
# _________________________________________________________________
# resnet50v2 (Functional)      (None, 14, 14, 2048)      23564800
# _________________________________________________________________
# global_average_pooling2d (Gl (None, 2048)              0
# _________________________________________________________________
# dropout (Dropout)            (None, 2048)              0
# _________________________________________________________________
# dense (Dense)                (None, 7)                 14343
# =================================================================
# Total params: 23,579,143
# Trainable params: 23,533,703
# Non-trainable params: 45,440
# _________________________________________________________________

# %% [markdown]
# ### 3.2.1. Buscando a taxa de aprendizado: LRFinder 2

# %%
optimizer = tf.keras.optimizers.Adam()
loss_fn = tf.keras.losses.CategoricalCrossentropy()

# %%
lr_find = LrFinder(model, optimizer, loss_fn)
lr_find.range_test(train_ds)
lr_find.plot_lrs(suggestion=True, show_grid=True)
# Out:
# Finding best initial lr over 100 steps
#   0%|          | 0/100 [00:00<?, ?it/s]
# LR Finder is complete, type {LrFinder}.plot_lrs() to see the graph.
# Min numerical gradient: 1.32E-06
# Min loss divided by 10: 1.10E-05

# %%
base_lr = 1e-6
max_lr = 1e-5

# %% [markdown]
# ### 3.2.2. Definindo os Callbacks

# %% [markdown]
# #### 3.2.2.1. CyclicalLR

# %%
step_size = train_steps
clr = CyclicalLR(max_lr=max_lr, 
                 base_lr=base_lr, 
                 step_size=step_size, 
                 cyclical_momentum=False)

# %% [markdown]
# #### 3.2.2.2. Checkpoint

# %%
# salva os melhores modelos para o callback
def get_model_name(k):
    return str(nomeDoModelo)+'_folder_'+ str(k)+'.h5'

# %%
checkpoint = ModelCheckpoint(save_dir+get_model_name(fold_var),
                                                  monitor='val_auc', verbose=1,
                                                  save_best_only=True, mode='max')

# %% [markdown]
# #### 3.2.2.3. Earlystopping

# %%
earlystopping = EarlyStopping(monitor='val_loss',
                              verbose=1, mode='min', 
                              restore_best_weights=False,
                              patience=15)

# %%
# Lista contendo todos os callbacks
callbacks_list = [checkpoint, earlystopping, clr]

# %% [markdown]
# ### 3.2.3. Treinando

# %%
model.compile(optimizer=Adam(learning_rate=base_lr), 
              loss=tf.keras.losses.CategoricalCrossentropy(), 
              metrics=metricasEscolhidas)

# %%
history_fine = model.fit(train_ds,
                    class_weight = weights_train_dict,
                    steps_per_epoch = train_steps,
                    epochs=second_epoch,
                    initial_epoch=history.epoch[-1],
                    validation_data=val_ds,
                    validation_steps = val_steps,
                    callbacks = callbacks_list)
# Out:
# Epoch 30/100
# 558/558 [==============================] - 192s 332ms/step - loss: 4.9458 - acc: 0.5404 - auc: 0.8919 - precision: 0.5887 - recall: 0.4671 - val_loss: 1.0431 - val_acc: 0.5744 - val_auc: 0.9114 - val_precision: 0.6090 - val_recall: 0.5172
#
# Epoch 00030: val_auc improved from -inf to 0.91135, saving model to /content/drive/MyDrive/TCC-Melo/Kaggle/modelos_checkPoint/ResNet50V2_folder_5.h5
# /usr/local/lib/python3.7/dist-packages/keras/utils/generic_utils.py:497: CustomMaskWarning:
#
# Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
# Epoch 31/100
# 558/558 [==============================] - 184s 329ms/step - loss: 4.3682 - acc: 0.5536 - auc: 0.9037 - precision: 0.5980 - recall: 0.4860 - val_loss: 0.7219 - val_acc: 0.7187 - val_auc: 0.9555 - val_precision: 0.7460 - val_recall: 0.6688
#
# Epoch 00031: val_auc improved from 0.91135 to 0.95554, saving model to /content/drive/MyDrive/TCC-Melo/Kaggle/modelos_checkPoint/ResNet50V2_folder_5.h5
# Epoch 32/100
# 558/558 [==============================] - 184s 329ms/step - loss: 3.9579 - acc: 0.5897 - auc: 0.9161 - precision: 0.6362 - recall: 0.5346 - val_loss: 0.8421 - val_acc: 0.6461 - val_auc: 0.9385 - val_precision: 0.6845 - val_recall: 0.5926
#
# Epoch 00032: val_auc did not improve from 0.95554
# Epoch 33/100
# 558/558 [==============================] - 184s 330ms/step - loss: 3.8101 - acc: 0.5951 - auc: 0.9176 - precision: 0.6361 - recall: 0.5426 - val_loss: 0.6467 - val_acc: 0.7632 - val_auc: 0.9635 - val_precision: 0.7980 - val_recall: 0.7387
#
# Epoch 00033: val_auc improved from 0.95554 to 0.96353, saving model to /content/drive/MyDrive/TCC-Melo/Kaggle/modelos_checkPoint/ResNet50V2_folder_5.h5
# Epoch 34/100
# 558/558 [==============================] - 184s 329ms/step - loss: 3.4333 - acc: 0.6219 - auc: 0.9283 - precision: 0.6588 - recall: 0.5733 - val_loss: 0.8476 - val_acc: 0.6633 - val_auc: 0.9386 - val_precision: 0.6894 - val_recall: 0.6044
#
# Epoch 00034: val_auc did not improve from 0.96353
# Epoch 35/100
# 558/558 [==============================] - 184s 330ms/step - loss: 3.4090 - acc: 0.6142 - auc: 0.9276 - precision: 0.6503 - recall: 0.5688 - val_loss: 0.6534 - val_acc: 0.7514 - val_auc: 0.9635 - val_precision: 0.7854 - val_recall: 0.7341
#
# Epoch 00035: val_auc did not improve from 0.96353
# Epoch 36/100
# 558/558 [==============================] - 184s 330ms/step - loss: 3.1398 - acc: 0.6438 - auc: 0.9363 - precision: 0.6769 - recall: 0.5990 - val_loss: 0.8109 - val_acc: 0.6633 - val_auc: 0.9437 - val_precision: 0.7115 - val_recall: 0.6198
#
# Epoch 00036: val_auc did not improve from 0.96353
# Epoch 37/100
# 558/558 [==============================] - 184s 329ms/step - loss: 3.2189 - acc: 0.6361 - auc: 0.9341 - precision: 0.6721 - recall: 0.5906 - val_loss: 0.5885 - val_acc: 0.7931 - val_auc: 0.9705 - val_precision: 0.8196 - val_recall: 0.7668
#
# Epoch 00037: val_auc improved from 0.96353 to 0.97046, saving model to /content/drive/MyDrive/TCC-Melo/Kaggle/modelos_checkPoint/ResNet50V2_folder_5.h5
# Epoch 38/100
# 558/558 [==============================] - 185s 330ms/step - loss: 2.8304 - acc: 0.6694 - auc: 0.9431 - precision: 0.6995 - recall: 0.6315 - val_loss: 0.5873 - val_acc: 0.7840 - val_auc: 0.9692 - val_precision: 0.8206 - val_recall: 0.7514
#
# Epoch 00038: val_auc did not improve from 0.97046
# Epoch 39/100
# 558/558 [==============================] - 184s 330ms/step - loss: 2.8079 - acc: 0.6676 - auc: 0.9436 - precision: 0.6987 - recall: 0.6328 - val_loss: 0.5524 - val_acc: 0.7976 - val_auc: 0.9728 - val_precision: 0.8270 - val_recall: 0.7722
#
# Epoch 00039: val_auc improved from 0.97046 to 0.97281, saving model to /content/drive/MyDrive/TCC-Melo/Kaggle/modelos_checkPoint/ResNet50V2_folder_5.h5
# Epoch 40/100
# 558/558 [==============================] - 185s 330ms/step - loss: 2.7006 - acc: 0.6801 - auc: 0.9461 - precision: 0.7077 - recall: 0.6431 - val_loss: 0.6399 - val_acc: 0.7604 - val_auc: 0.9637 - val_precision: 0.7858 - val_recall: 0.7123
#
# Epoch 00040: val_auc did not improve from 0.97281
# Epoch 41/100
# 558/558 [==============================] - 184s 329ms/step - loss: 2.4672 - acc: 0.6860 - auc: 0.9496 - precision: 0.7124 - recall: 0.6566 - val_loss: 0.5158 - val_acc: 0.8122 - val_auc: 0.9769 - val_precision: 0.8329 - val_recall: 0.7958
#
# Epoch 00041: val_auc improved from 0.97281 to 0.97694, saving model to /content/drive/MyDrive/TCC-Melo/Kaggle/modelos_checkPoint/ResNet50V2_folder_5.h5
# Epoch 42/100
# 558/558 [==============================] - 185s 330ms/step - loss: 2.3182 - acc: 0.7076 - auc: 0.9536 - precision: 0.7321 - recall: 0.6787 - val_loss: 0.5988 - val_acc: 0.7895 - val_auc: 0.9685 - val_precision: 0.8136 - val_recall: 0.7686
#
# Epoch 00042: val_auc did not improve from 0.97694
# Epoch 43/100
# 558/558 [==============================] - 185s 330ms/step - loss: 2.2738 - acc: 0.7062 - auc: 0.9548 - precision: 0.7312 - recall: 0.6805 - val_loss: 0.4995 - val_acc: 0.8258 - val_auc: 0.9779 - val_precision: 0.8473 - val_recall: 0.8158
#
# Epoch 00043: val_auc improved from 0.97694 to 0.97790, saving model to /content/drive/MyDrive/TCC-Melo/Kaggle/modelos_checkPoint/ResNet50V2_folder_5.h5
# Epoch 44/100
# 558/558 [==============================] - 184s 329ms/step - loss: 2.1177 - acc: 0.7237 - auc: 0.9598 - precision: 0.7481 - recall: 0.7009 - val_loss: 0.6057 - val_acc: 0.7849 - val_auc: 0.9680 - val_precision: 0.8207 - val_recall: 0.7559
#
# Epoch 00044: val_auc did not improve from 0.97790
# Epoch 45/100
# 558/558 [==============================] - 184s 329ms/step - loss: 2.0940 - acc: 0.7306 - auc: 0.9594 - precision: 0.7519 - recall: 0.7054 - val_loss: 0.4729 - val_acc: 0.8312 - val_auc: 0.9790 - val_precision: 0.8479 - val_recall: 0.8194
#
# Epoch 00045: val_auc improved from 0.97790 to 0.97899, saving model to /content/drive/MyDrive/TCC-Melo/Kaggle/modelos_checkPoint/ResNet50V2_folder_5.h5
# Epoch 46/100
# 558/558 [==============================] - 185s 329ms/step - loss: 1.9950 - acc: 0.7407 - auc: 0.9633 - precision: 0.7628 - recall: 0.7207 - val_loss: 0.4912 - val_acc: 0.8149 - val_auc: 0.9787 - val_precision: 0.8372 - val_recall: 0.7931
#
# Epoch 00046: val_auc did not improve from 0.97899
# Epoch 47/100
# 558/558 [==============================] - 184s 329ms/step - loss: 2.0885 - acc: 0.7189 - auc: 0.9594 - precision: 0.7423 - recall: 0.6991 - val_loss: 0.4838 - val_acc: 0.8294 - val_auc: 0.9783 - val_precision: 0.8460 - val_recall: 0.8176
#
# Epoch 00047: val_auc did not improve from 0.97899
# Epoch 48/100
# 558/558 [==============================] - 184s 330ms/step - loss: 1.8355 - acc: 0.7573 - auc: 0.9671 - precision: 0.7767 - recall: 0.7399 - val_loss: 0.8483 - val_acc: 0.6688 - val_auc: 0.9410 - val_precision: 0.6894 - val_recall: 0.6425
#
# Epoch 00048: val_auc did not improve from 0.97899
# Epoch 49/100
# 558/558 [==============================] - 184s 329ms/step - loss: 1.8283 - acc: 0.7526 - auc: 0.9654 - precision: 0.7717 - recall: 0.7317 - val_loss: 0.5405 - val_acc: 0.8194 - val_auc: 0.9742 - val_precision: 0.8347 - val_recall: 0.8067
#
# Epoch 00049: val_auc did not improve from 0.97899
# Epoch 50/100
# 558/558 [==============================] - 184s 329ms/step - loss: 1.7582 - acc: 0.7590 - auc: 0.9689 - precision: 0.7768 - recall: 0.7423 - val_loss: 0.7565 - val_acc: 0.7060 - val_auc: 0.9522 - val_precision: 0.7380 - val_recall: 0.6670
#
# Epoch 00050: val_auc did not improve from 0.97899
# Epoch 51/100
# 558/558 [==============================] - 184s 329ms/step - loss: 1.8251 - acc: 0.7523 - auc: 0.9679 - precision: 0.7697 - recall: 0.7334 - val_loss: 0.5204 - val_acc: 0.8212 - val_auc: 0.9763 - val_precision: 0.8371 - val_recall: 0.8158
#
# Epoch 00051: val_auc did not improve from 0.97899
# Epoch 52/100
# 558/558 [==============================] - 184s 329ms/step - loss: 1.5319 - acc: 0.7762 - auc: 0.9716 - precision: 0.7924 - recall: 0.7598 - val_loss: 0.6117 - val_acc: 0.7868 - val_auc: 0.9681 - val_precision: 0.7994 - val_recall: 0.7704
#
# Epoch 00052: val_auc did not improve from 0.97899
# Epoch 53/100
# 558/558 [==============================] - 184s 329ms/step - loss: 1.6004 - acc: 0.7802 - auc: 0.9720 - precision: 0.7960 - recall: 0.7637 - val_loss: 0.4884 - val_acc: 0.8403 - val_auc: 0.9798 - val_precision: 0.8570 - val_recall: 0.8267
#
# Epoch 00053: val_auc improved from 0.97899 to 0.97977, saving model to /content/drive/MyDrive/TCC-Melo/Kaggle/modelos_checkPoint/ResNet50V2_folder_5.h5
# Epoch 54/100
# 558/558 [==============================] - 184s 329ms/step - loss: 1.4775 - acc: 0.7941 - auc: 0.9752 - precision: 0.8079 - recall: 0.7793 - val_loss: 0.5897 - val_acc: 0.7995 - val_auc: 0.9700 - val_precision: 0.8221 - val_recall: 0.7759
#
# Epoch 00054: val_auc did not improve from 0.97977
# Epoch 55/100
# 558/558 [==============================] - 184s 330ms/step - loss: 1.6302 - acc: 0.7744 - auc: 0.9706 - precision: 0.7915 - recall: 0.7568 - val_loss: 0.4650 - val_acc: 0.8430 - val_auc: 0.9787 - val_precision: 0.8548 - val_recall: 0.8385
#
# Epoch 00055: val_auc did not improve from 0.97977
# Epoch 56/100
# 558/558 [==============================] - 184s 330ms/step - loss: 1.3900 - acc: 0.8057 - auc: 0.9767 - precision: 0.8174 - recall: 0.7897 - val_loss: 0.5219 - val_acc: 0.8212 - val_auc: 0.9751 - val_precision: 0.8384 - val_recall: 0.8049
#
# Epoch 00056: val_auc did not improve from 0.97977
# Epoch 57/100
# 558/558 [==============================] - 184s 329ms/step - loss: 1.4292 - acc: 0.7875 - auc: 0.9759 - precision: 0.8027 - recall: 0.7763 - val_loss: 0.4824 - val_acc: 0.8330 - val_auc: 0.9790 - val_precision: 0.8463 - val_recall: 0.8294
#
# Epoch 00057: val_auc did not improve from 0.97977
# Epoch 58/100
# 558/558 [==============================] - 184s 330ms/step - loss: 1.2969 - acc: 0.8039 - auc: 0.9774 - precision: 0.8138 - recall: 0.7931 - val_loss: 0.4819 - val_acc: 0.8394 - val_auc: 0.9789 - val_precision: 0.8567 - val_recall: 0.8249
#
# Epoch 00058: val_auc did not improve from 0.97977
# Epoch 59/100
# 558/558 [==============================] - 184s 330ms/step - loss: 1.4158 - acc: 0.8042 - auc: 0.9771 - precision: 0.8182 - recall: 0.7920 - val_loss: 0.4153 - val_acc: 0.8648 - val_auc: 0.9820 - val_precision: 0.8813 - val_recall: 0.8557
#
# Epoch 00059: val_auc improved from 0.97977 to 0.98202, saving model to /content/drive/MyDrive/TCC-Melo/Kaggle/modelos_checkPoint/ResNet50V2_folder_5.h5
# Epoch 60/100
# 558/558 [==============================] - 185s 330ms/step - loss: 1.2312 - acc: 0.8094 - auc: 0.9790 - precision: 0.8211 - recall: 0.7980 - val_loss: 0.6481 - val_acc: 0.7958 - val_auc: 0.9662 - val_precision: 0.8033 - val_recall: 0.7858
#
# Epoch 00060: val_auc did not improve from 0.98202
# Epoch 61/100
# 558/558 [==============================] - 184s 330ms/step - loss: 1.2851 - acc: 0.8118 - auc: 0.9796 - precision: 0.8248 - recall: 0.7993 - val_loss: 0.4605 - val_acc: 0.8466 - val_auc: 0.9801 - val_precision: 0.8569 - val_recall: 0.8367
#
# Epoch 00061: val_auc did not improve from 0.98202
# Epoch 62/100
# 558/558 [==============================] - 184s 330ms/step - loss: 1.1449 - acc: 0.8259 - auc: 0.9809 - precision: 0.8381 - recall: 0.8144 - val_loss: 0.6757 - val_acc: 0.7759 - val_auc: 0.9643 - val_precision: 0.7941 - val_recall: 0.7632
#
# Epoch 00062: val_auc did not improve from 0.98202
# Epoch 63/100
# 558/558 [==============================] - 184s 330ms/step - loss: 1.1800 - acc: 0.8286 - auc: 0.9821 - precision: 0.8416 - recall: 0.8176 - val_loss: 0.4675 - val_acc: 0.8575 - val_auc: 0.9788 - val_precision: 0.8721 - val_recall: 0.8539
#
# Epoch 00063: val_auc did not improve from 0.98202
# Epoch 64/100
# 558/558 [==============================] - 184s 329ms/step - loss: 1.0777 - acc: 0.8338 - auc: 0.9815 - precision: 0.8451 - recall: 0.8241 - val_loss: 0.4402 - val_acc: 0.8485 - val_auc: 0.9825 - val_precision: 0.8626 - val_recall: 0.8376
#
# Epoch 00064: val_auc improved from 0.98202 to 0.98246, saving model to /content/drive/MyDrive/TCC-Melo/Kaggle/modelos_checkPoint/ResNet50V2_folder_5.h5
# Epoch 65/100
# 558/558 [==============================] - 184s 330ms/step - loss: 1.1422 - acc: 0.8250 - auc: 0.9815 - precision: 0.8354 - recall: 0.8140 - val_loss: 0.5186 - val_acc: 0.8267 - val_auc: 0.9760 - val_precision: 0.8436 - val_recall: 0.8176
#
# Epoch 00065: val_auc did not improve from 0.98246
# Epoch 66/100
# 558/558 [==============================] - 185s 330ms/step - loss: 1.0361 - acc: 0.8369 - auc: 0.9840 - precision: 0.8468 - recall: 0.8281 - val_loss: 0.4872 - val_acc: 0.8466 - val_auc: 0.9777 - val_precision: 0.8621 - val_recall: 0.8285
#
# Epoch 00066: val_auc did not improve from 0.98246
# Epoch 67/100
# 558/558 [==============================] - 184s 330ms/step - loss: 1.2344 - acc: 0.8156 - auc: 0.9790 - precision: 0.8299 - recall: 0.8019 - val_loss: 0.4315 - val_acc: 0.8539 - val_auc: 0.9813 - val_precision: 0.8666 - val_recall: 0.8430
#
# Epoch 00067: val_auc did not improve from 0.98246
# Epoch 68/100
# 558/558 [==============================] - 184s 329ms/step - loss: 1.0777 - acc: 0.8430 - auc: 0.9835 - precision: 0.8531 - recall: 0.8328 - val_loss: 0.8552 - val_acc: 0.7441 - val_auc: 0.9486 - val_precision: 0.7514 - val_recall: 0.7269
#
# Epoch 00068: val_auc did not improve from 0.98246
# Epoch 69/100
# 558/558 [==============================] - 184s 330ms/step - loss: 1.0449 - acc: 0.8384 - auc: 0.9841 - precision: 0.8497 - recall: 0.8278 - val_loss: 0.4728 - val_acc: 0.8593 - val_auc: 0.9787 - val_precision: 0.8675 - val_recall: 0.8494
#
# Epoch 00069: val_auc did not improve from 0.98246
# Epoch 70/100
# 558/558 [==============================] - 184s 330ms/step - loss: 0.9866 - acc: 0.8513 - auc: 0.9856 - precision: 0.8625 - recall: 0.8416 - val_loss: 0.6276 - val_acc: 0.8067 - val_auc: 0.9688 - val_precision: 0.8219 - val_recall: 0.7958
#
# Epoch 00070: val_auc did not improve from 0.98246
# Epoch 71/100
# 558/558 [==============================] - 184s 329ms/step - loss: 1.1217 - acc: 0.8322 - auc: 0.9828 - precision: 0.8431 - recall: 0.8230 - val_loss: 0.4445 - val_acc: 0.8566 - val_auc: 0.9798 - val_precision: 0.8656 - val_recall: 0.8475
#
# Epoch 00071: val_auc did not improve from 0.98246
# Epoch 72/100
# 558/558 [==============================] - 184s 330ms/step - loss: 0.7984 - acc: 0.8640 - auc: 0.9871 - precision: 0.8729 - recall: 0.8561 - val_loss: 0.4901 - val_acc: 0.8521 - val_auc: 0.9769 - val_precision: 0.8642 - val_recall: 0.8430
#
# Epoch 00072: val_auc did not improve from 0.98246
# Epoch 73/100
# 558/558 [==============================] - 184s 329ms/step - loss: 1.0688 - acc: 0.8437 - auc: 0.9844 - precision: 0.8543 - recall: 0.8345 - val_loss: 0.4791 - val_acc: 0.8575 - val_auc: 0.9769 - val_precision: 0.8657 - val_recall: 0.8485
#
# Epoch 00073: val_auc did not improve from 0.98246
# Epoch 74/100
# 558/558 [==============================] - 184s 329ms/step - loss: 0.8937 - acc: 0.8628 - auc: 0.9871 - precision: 0.8729 - recall: 0.8563 - val_loss: 0.5375 - val_acc: 0.8212 - val_auc: 0.9749 - val_precision: 0.8361 - val_recall: 0.8103
#
# Epoch 00074: val_auc did not improve from 0.98246
# Epoch 00074: early stopping

# %% [markdown]
# ### 3.2.4. Avaliando o treinamento do modelo

# %%
acc += history_fine.history['acc']
val_acc += history_fine.history['val_acc']

loss += history_fine.history['loss']
val_loss += history_fine.history['val_loss']

# %%
plt.figure(figsize=(8, 8))
plt.subplot(2, 1, 1)
plt.plot(acc, label='Acuracia de treinamento')
plt.plot(val_acc, label='Acuracia de validação')
plt.ylim([0, 1])
plt.plot([first_epoch-1,first_epoch-1],
          plt.ylim(), label='Começo do Fine Tuning')
plt.legend(loc='lower right')
plt.title('Acuracia do treinamento e validação')

plt.subplot(2, 1, 2)
plt.plot(loss, label='Perda do treinamento')
plt.plot(val_loss, label='Perda da validação')
plt.ylim([0, 8])
plt.plot([first_epoch-1,first_epoch-1],
         plt.ylim(), label='Começo do Fine Tuning')
plt.legend(loc='upper right')
plt.title('Perda do treinamento e validação')
plt.xlabel('epoca')
plt.show()

# %% [markdown]
# #### 3.2.4.1. Verificando CLR

# %%
clr.plot_lr((14, 3.5))

# %% [markdown]
# # 4. Avaliando o modelo

# %%
model.load_weights(save_dir + str(nomeDoModelo)+'_folder_'+ str(fold_var)+'.h5')
# model_all = tf.keras.models.load_model(save_dir + str(nomeDoModelo)+'_folder_'+ str(fold_var)+'.h5')

# %%
model.evaluate(val_ds)
# Out:
# 69/69 [==============================] - 7s 98ms/step - loss: 0.4402 - acc: 0.8485 - auc: 0.9825 - precision: 0.8626 - recall: 0.8376
# [0.4401548206806183,
#  0.8484573364257812,
#  0.9824582934379578,
#  0.8626168370246887,
#  0.8375680446624756]

# %% [markdown]
# ## 4.1. Realizando as previsões

# %%
# Obtendo a tabela verdade 
true_categories = tf.concat([y for x, y in val_ds], axis=0)
true_categories  = tf.argmax(true_categories , axis=1)

# %%
# Realizando as previsões
predictions = model.predict(val_ds, verbose=1)
y_pred = tf.argmax(predictions, axis=1)
# Out:
# 69/69 [==============================] - 7s 86ms/step

# %% [markdown]
# ## 4.3. Metricas de avaliação

# %% [markdown]
# ### 4.3.1. Quadro de metricas

# %%
cm_plot_labels = ['akiec', 'bcc', 'bkl', 'df', 'mel','nv', 'vasc']
print(classification_report(true_categories , y_pred, target_names=cm_plot_labels))
# Out:
#               precision    recall  f1-score   support
#
#        akiec       0.65      0.43      0.52        30
#          bcc       0.91      0.60      0.72        35
#          bkl       0.71      0.55      0.62        88
#           df       0.28      1.00      0.44         7
#          mel       0.26      0.70      0.37        46
#           nv       0.97      0.91      0.94       883
#         vasc       0.92      0.92      0.92        13
#
#     accuracy                           0.85      1102
#    macro avg       0.67      0.73      0.65      1102
# weighted avg       0.90      0.85      0.87      1102

# %% [markdown]
# ### 4.3.2. Matriz de confusão

# %%
cm = confusion_matrix(true_categories , y_pred)
fig, ax = plot_confusion_matrix(conf_mat=cm,
                                show_absolute=True,
                                show_normed=True, 
                                class_names=cm_plot_labels)

# %% [markdown]
# ### 4.3.3. Acurácia balanceada

# %%
bAcc= sklearn.metrics.balanced_accuracy_score(true_categories, y_pred)
print(f'Acurácia balanceada: {bAcc*100:.6f}%')
# Out:
# Acurácia balanceada: 72.939775%
