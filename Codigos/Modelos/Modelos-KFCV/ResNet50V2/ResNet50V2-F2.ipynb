# %% [markdown]
# # 1. Comando Iniciais

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ## 1.1. Importando Bibliotecas

# %%
# !pip install mlxtend --upgrade --no-deps # Versão do Mlxtend: 0.19.0
# Out:
# Requirement already satisfied: mlxtend in /usr/local/lib/python3.7/dist-packages (0.19.0)

# %%
import numpy as np
import pandas as pd

import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
import plotly 
import plotly.express as px

import tensorflow as tf
from tensorflow.keras.layers import Dense, Dropout, Conv2D, Flatten, GlobalAveragePooling2D, Input
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.preprocessing import image_dataset_from_directory
from tensorflow.keras.models import Model
from tensorflow.keras.callbacks import ReduceLROnPlateau, ModelCheckpoint, EarlyStopping
from tensorflow.keras.metrics import CategoricalAccuracy, AUC, Precision, Recall
from tensorflow import keras

import sklearn
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import confusion_matrix, classification_report

import mlxtend
from mlxtend.plotting import plot_confusion_matrix

import itertools

import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# %%
# Utility Script - Criados dentro do Kaggle Code, devido ao fato que são modulo customizados 
# %cd /content/drive/MyDrive/TCC-Melo/Kaggle/
from lrfinder import *
from cyclicallr import *
# Out:
# /content/drive/MyDrive/TCC-Melo/Kaggle

# %% [markdown]
# ### 1.1.1. Demostrando versões das bibliotecas

# %%
print(f'Versão do Numpy: {np.__version__}')
print(f'Versão do Pandas: {pd.__version__}')
print(f'Versão do Matplotlib: {mpl.__version__}')
print(f'Versão do Season: {sns.__version__}')
print(f'Versão do Plotly: {plotly.__version__}')
print(f'Versão do TensorFlow: {tf.__version__}')
print(f'Versão do Keras: {keras.__version__}')
print(f'Versão do Sklearn: {sklearn.__version__}')
print(f'Versão do Mlxtend: {mlxtend.__version__}')
# Out:
# Versão do Numpy: 1.19.5
# Versão do Pandas: 1.1.5
# Versão do Matplotlib: 3.2.2
# Versão do Season: 0.11.2
# Versão do Plotly: 4.4.1
# Versão do TensorFlow: 2.6.0
# Versão do Keras: 2.6.0
# Versão do Sklearn: 0.22.2.post1
# Versão do Mlxtend: 0.19.0

# %% [markdown]
# ## 1.2. Verificando Accelerator

# %%
gpu_info = !nvidia-smi
gpu_info = '\n'.join(gpu_info)
if gpu_info.find('failed') >= 0:
  print('Not connected to a GPU')
else:
  print(gpu_info)
# Out:
# Fri Oct  1 19:32:16 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 470.74       Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   51C    P0    33W / 250W |      0MiB / 16280MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
gpus = tf.config.list_physical_devices('GPU')
for gpu in gpus:
    print("Name:", gpu.name, "  Type:", gpu.device_type)
tf.test.is_gpu_available()
# Out:
# Name: /physical_device:GPU:0   Type: GPU
# WARNING:tensorflow:From <ipython-input-7-f99a3e65d632>:4: is_gpu_available (from tensorflow.python.framework.test_util) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.config.list_physical_devices('GPU')` instead.
# True

# %% [markdown]
# ## 1.3. Variaveis Globais

# %%
# Caminho para salvar os melhores modelos do callback checkpoint
save_dir = '/content/drive/MyDrive/TCC-Melo/Kaggle/modelos_checkPoint/'

# Caminho dos Folds
fold_var = 2 # Folder selecionado

train_path = f'/content/drive/MyDrive/TCC-Melo/Dados/Folds_Modified/fold_{fold_var}/train_dir'    # Imagens em JPG separadas em folders
valid_path = f'/content/drive/MyDrive/TCC-Melo/Dados/Folds_Modified/fold_{fold_var}/val_dir'    # Imagens em JPG separadas em folders

# Ordem das categorias
classes = ['AKIEC', 'BCC', 'BKL', 'DF', 'MEL', 'NV', 'VASC']
#         [0      , 1    , 2    , 3   , 4    , 5   , 6]

# Tamanho da batch
batch_size = 16

# Dimensão das imagens de entrada
image_size = (448, 448)

# Numero de epochs
## Primeiro Momento:
first_epoch = 30

## Segundo Momento:
second_epoch = first_epoch + 70

# Calculando os passos para o treinamento
train_steps = np.ceil(8912 / batch_size)
val_steps = np.ceil(1103 / batch_size)

# Carregando os pesos para as categorias para o treinamento 
weights_train_dict = {0: 15, 1: 10, 2: 5, 3: 42,
                      4: 20, 5: 1, 6: 35}

# %% [markdown]
# ## 1.4. Metricas de avaliação

# %%
metricasEscolhidas = [CategoricalAccuracy(name='acc'), 
                      AUC(name='auc'),
                      Precision(name='precision'), 
                      Recall(name='recall')]

# %% [markdown]
# ## 1.5. Carregando os dados

# %% [markdown]
#  ### 1.5.1. Treinamento

# %%
train_ds = image_dataset_from_directory(train_path,
                                        batch_size=batch_size,
                                        image_size = image_size,
                                        label_mode='categorical',
                                        shuffle=True,
                                        seed=42)
# Out:
# Found 8912 files belonging to 7 classes.

# %%
val_ds = image_dataset_from_directory(valid_path,
                                      batch_size=batch_size,
                                      image_size = image_size,
                                      label_mode='categorical',
                                      shuffle=False,
                                      seed=42)
# Out:
# Found 1103 files belonging to 7 classes.

# %% [markdown]
# #### 1.5.1.1. Alta velocidade de treinamento

# %%
for image_batch, labels_batch in train_ds:
  print(image_batch.shape)
  print(labels_batch.shape)
  break
# Out:
# (16, 448, 448, 3)
# (16, 7)

# %%
AUTOTUNE = tf.data.AUTOTUNE

#train_ds = train_ds.cache().prefetch(buffer_size=AUTOTUNE)
train_ds = train_ds.prefetch(buffer_size=AUTOTUNE)
#val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.prefetch(buffer_size=AUTOTUNE)

# %% [markdown]
# ## 1.6. Modelo Pré-treinado

# %%
num_model = 4

# %% [markdown]
# ### 1.6.1. Selecionando modelo

# %%
if num_model == 1:
    nomeDoModelo = 'DenseNet121'
    modelo = tf.keras.applications.DenseNet121(weights='imagenet', 
                                               include_top=False, 
                                               input_tensor=Input(shape=image_size+(3,)))
elif num_model == 2:
    nomeDoModelo = 'DenseNet169'
    modelo = tf.keras.applications.DenseNet169(weights='imagenet', 
                                               include_top=False, 
                                               input_tensor=Input(shape=image_size+(3,)))
elif num_model == 3:
    nomeDoModelo = 'DenseNet201'
    modelo = tf.keras.applications.DenseNet201(weights='imagenet', 
                                               include_top=False, 
                                               input_tensor=Input(shape=image_size+(3,)))
elif num_model == 4:
    nomeDoModelo = 'ResNet50V2'
    modelo = tf.keras.applications.ResNet50V2(weights='imagenet', 
                                               include_top=False, 
                                               input_tensor=Input(shape=image_size+(3,)))
elif num_model == 5:
    nomeDoModelo = 'ResNet101V2'
    modelo = tf.keras.applications.ResNet101V2(weights='imagenet', 
                                               include_top=False, 
                                               input_tensor=Input(shape=image_size+(3,)))
elif num_model == 6:
    nomeDoModelo = 'ResNet152V2'
    modelo = tf.keras.applications.ResNet152V2(weights='imagenet', 
                                               include_top=False, 
                                               input_tensor=Input(shape=image_size+(3,)))
elif num_model == 7:
    nomeDoModelo = 'Xception'
    modelo = tf.keras.applications.Xception(weights='imagenet', 
                                               include_top=False, 
                                               input_tensor=Input(shape=image_size+(3,)))
elif num_model == 8:
    nomeDoModelo = 'InceptionV3'
    modelo = tf.keras.applications.InceptionV3(weights='imagenet', 
                                               include_top=False, 
                                               input_tensor=Input(shape=image_size+(3,)))
elif num_model == 9:
    nomeDoModelo = 'InceptionResNetV2'
    modelo = tf.keras.applications.InceptionResNetV2(weights='imagenet', 
                                               include_top=False, 
                                               input_tensor=Input(shape=image_size+(3,)))
elif num_model == 10:
    nomeDoModelo = 'EfficientNetB0'
    modelo = tf.keras.applications.EfficientNetB0(weights='imagenet', 
                                               include_top=False, 
                                               input_tensor=Input(shape=image_size+(3,)))
elif num_model == 11:
    nomeDoModelo = 'EfficientNetB1'
    modelo = tf.keras.applications.EfficientNetB1(weights='imagenet', 
                                               include_top=False, 
                                               input_tensor=Input(shape=image_size+(3,)))
elif num_model == 12:
    nomeDoModelo = 'EfficientNetB2'
    modelo = tf.keras.applications.EfficientNetB2(weights='imagenet', 
                                               include_top=False, 
                                               input_tensor=Input(shape=image_size+(3,)))
elif num_model == 13:
    nomeDoModelo = 'EfficientNetB3'
    modelo = tf.keras.applications.EfficientNetB3(weights='imagenet', 
                                               include_top=False, 
                                               input_tensor=Input(shape=image_size+(3,)))
    
print(f'O modelo selecionado foi {nomeDoModelo}')
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50v2_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94674944/94668760 [==============================] - 1s 0us/step
# 94683136/94668760 [==============================] - 1s 0us/step
# O modelo selecionado foi ResNet50V2

# %% [markdown]
# # 2. Preprocessamento

# %% [markdown]
# ## 2.1. Camada de aumento de dados

# %%
camada_ad = tf.keras.Sequential([
  tf.keras.layers.experimental.preprocessing.RandomFlip('horizontal'),
  tf.keras.layers.experimental.preprocessing.RandomFlip('vertical'),
  tf.keras.layers.experimental.preprocessing.RandomRotation(0.3),
  tf.keras.layers.experimental.preprocessing.RandomContrast((0.8, 1.1)),
], name='data_augmentation')

# %% [markdown]
# ## 2.2. Camada de reescalonamento

# %%
if num_model in [1, 2, 3]:
    camada_reescal = tf.keras.applications.densenet.preprocess_input
elif num_model in [4, 5, 6]:
    camada_reescal = tf.keras.applications.resnet_v2.preprocess_input
elif num_model == 7:
    camada_reescal = tf.keras.applications.xception.preprocess_input
elif num_model == 8:
    camada_reescal = tf.keras.applications.inception_v3.preprocess_input
elif num_model == 9:
    camada_reescal = tf.keras.applications.inception_resnet_v2.preprocess_input
elif num_model in [10, 11, 12, 13]:
    camada_reescal = tf.keras.applications.efficientnet.preprocess_input
    
print(f'A camada selecionada foi {camada_reescal}')
# Out:
# A camada selecionada foi <function preprocess_input at 0x7f92af30c320>

# %% [markdown]
# # 3. Classificação

# %% [markdown]
# ## 3.1. Criando o modelo: Primeiro Momento

# %%
modelBase = modelo

modelBase.trainable = False # Congelando os pesos do modelo base

inputs = tf.keras.Input(shape=image_size+(3,))
x = camada_ad(inputs)
x = camada_reescal(x)
x = modelBase(x, training=False) # Deixando o modelo em modo enferência por causa das camadas BatchNormalization
x = GlobalAveragePooling2D()(x)
x = Dropout(0.3)(x)
predictions = Dense(7, activation='softmax')(x)
model = tf.keras.Model(inputs, predictions, name=nomeDoModelo)

# %%
model.summary()
# Out:
# Model: "ResNet50V2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         [(None, 448, 448, 3)]     0
# _________________________________________________________________
# data_augmentation (Sequentia (None, 448, 448, 3)       0
# _________________________________________________________________
# tf.math.truediv (TFOpLambda) (None, 448, 448, 3)       0
# _________________________________________________________________
# tf.math.subtract (TFOpLambda (None, 448, 448, 3)       0
# _________________________________________________________________
# resnet50v2 (Functional)      (None, 14, 14, 2048)      23564800
# _________________________________________________________________
# global_average_pooling2d (Gl (None, 2048)              0
# _________________________________________________________________
# dropout (Dropout)            (None, 2048)              0
# _________________________________________________________________
# dense (Dense)                (None, 7)                 14343
# =================================================================
# Total params: 23,579,143
# Trainable params: 14,343
# Non-trainable params: 23,564,800
# _________________________________________________________________

# %% [markdown]
# ### 3.1.1. Buscando a taxa de aprendizado: LRFinder 1

# %%
optimizer = tf.keras.optimizers.Adam()
loss_fn = tf.keras.losses.CategoricalCrossentropy()

# %%
lr_find = LrFinder(model, optimizer, loss_fn)
lr_find.range_test(train_ds)
lr_find.plot_lrs(suggestion=True, show_grid=True)
# Out:
# Finding best initial lr over 100 steps
#   0%|          | 0/100 [00:00<?, ?it/s]
# LR Finder is complete, type {LrFinder}.plot_lrs() to see the graph.
# Min numerical gradient: 1.00E-03
# Min loss divided by 10: 6.92E-03

# %%
base_lr = 1e-03

# %% [markdown]
# ### 3.1.2. Treinando

# %%
model.compile(optimizer=Adam(learning_rate= base_lr), 
              loss=tf.keras.losses.CategoricalCrossentropy(), 
              metrics=metricasEscolhidas)

# %%
history = model.fit(train_ds,
                    class_weight = weights_train_dict,
                    steps_per_epoch = train_steps,
                    epochs=first_epoch,
                    validation_data=val_ds,
                    validation_steps = val_steps)
# Out:
# Epoch 1/30
# 557/557 [==============================] - 659s 1s/step - loss: 8.0445 - acc: 0.3381 - auc: 0.7620 - precision: 0.3946 - recall: 0.1925 - val_loss: 1.0337 - val_acc: 0.6310 - val_auc: 0.9117 - val_precision: 0.7282 - val_recall: 0.4687
# Epoch 2/30
# 557/557 [==============================] - 67s 119ms/step - loss: 6.4818 - acc: 0.4332 - auc: 0.8277 - precision: 0.4943 - recall: 0.3039 - val_loss: 1.1303 - val_acc: 0.5802 - val_auc: 0.8927 - val_precision: 0.6548 - val_recall: 0.4352
# Epoch 3/30
# 557/557 [==============================] - 66s 118ms/step - loss: 6.1269 - acc: 0.4543 - auc: 0.8413 - precision: 0.5138 - recall: 0.3326 - val_loss: 0.8701 - val_acc: 0.6745 - val_auc: 0.9372 - val_precision: 0.7598 - val_recall: 0.5648
# Epoch 4/30
# 557/557 [==============================] - 66s 118ms/step - loss: 5.9761 - acc: 0.4505 - auc: 0.8440 - precision: 0.5012 - recall: 0.3397 - val_loss: 0.9664 - val_acc: 0.6555 - val_auc: 0.9220 - val_precision: 0.7365 - val_recall: 0.5068
# Epoch 5/30
# 557/557 [==============================] - 66s 118ms/step - loss: 5.7962 - acc: 0.4786 - auc: 0.8574 - precision: 0.5342 - recall: 0.3772 - val_loss: 0.8688 - val_acc: 0.6782 - val_auc: 0.9364 - val_precision: 0.7391 - val_recall: 0.5830
# Epoch 6/30
# 557/557 [==============================] - 66s 118ms/step - loss: 5.7908 - acc: 0.4837 - auc: 0.8590 - precision: 0.5358 - recall: 0.3871 - val_loss: 1.2014 - val_acc: 0.5431 - val_auc: 0.8817 - val_precision: 0.5990 - val_recall: 0.4252
# Epoch 7/30
# 557/557 [==============================] - 66s 118ms/step - loss: 5.6754 - acc: 0.4813 - auc: 0.8634 - precision: 0.5377 - recall: 0.3926 - val_loss: 0.9215 - val_acc: 0.6410 - val_auc: 0.9296 - val_precision: 0.7096 - val_recall: 0.5694
# Epoch 8/30
# 557/557 [==============================] - 66s 119ms/step - loss: 5.6621 - acc: 0.4758 - auc: 0.8586 - precision: 0.5222 - recall: 0.3880 - val_loss: 0.9281 - val_acc: 0.6582 - val_auc: 0.9275 - val_precision: 0.7161 - val_recall: 0.5648
# Epoch 9/30
# 557/557 [==============================] - 66s 118ms/step - loss: 5.5478 - acc: 0.4908 - auc: 0.8670 - precision: 0.5432 - recall: 0.4053 - val_loss: 1.0312 - val_acc: 0.5993 - val_auc: 0.9115 - val_precision: 0.6582 - val_recall: 0.5150
# Epoch 10/30
# 557/557 [==============================] - 66s 118ms/step - loss: 5.5488 - acc: 0.5045 - auc: 0.8704 - precision: 0.5541 - recall: 0.4194 - val_loss: 1.0679 - val_acc: 0.5802 - val_auc: 0.9056 - val_precision: 0.6518 - val_recall: 0.5023
# Epoch 11/30
# 557/557 [==============================] - 67s 119ms/step - loss: 5.5448 - acc: 0.4901 - auc: 0.8652 - precision: 0.5361 - recall: 0.4078 - val_loss: 1.0016 - val_acc: 0.6156 - val_auc: 0.9161 - val_precision: 0.6777 - val_recall: 0.5204
# Epoch 12/30
# 557/557 [==============================] - 66s 119ms/step - loss: 5.5343 - acc: 0.5044 - auc: 0.8721 - precision: 0.5520 - recall: 0.4239 - val_loss: 0.7995 - val_acc: 0.7135 - val_auc: 0.9457 - val_precision: 0.7713 - val_recall: 0.6392
# Epoch 13/30
# 557/557 [==============================] - 66s 118ms/step - loss: 5.3512 - acc: 0.5075 - auc: 0.8726 - precision: 0.5573 - recall: 0.4271 - val_loss: 1.0614 - val_acc: 0.5966 - val_auc: 0.9106 - val_precision: 0.6321 - val_recall: 0.5313
# Epoch 14/30
# 557/557 [==============================] - 66s 118ms/step - loss: 5.3328 - acc: 0.5145 - auc: 0.8742 - precision: 0.5590 - recall: 0.4369 - val_loss: 1.1714 - val_acc: 0.5576 - val_auc: 0.8892 - val_precision: 0.6310 - val_recall: 0.4542
# Epoch 15/30
# 557/557 [==============================] - 66s 118ms/step - loss: 5.3046 - acc: 0.5117 - auc: 0.8747 - precision: 0.5545 - recall: 0.4336 - val_loss: 0.7644 - val_acc: 0.7307 - val_auc: 0.9505 - val_precision: 0.8023 - val_recall: 0.6437
# Epoch 16/30
# 557/557 [==============================] - 66s 118ms/step - loss: 5.1573 - acc: 0.5119 - auc: 0.8759 - precision: 0.5592 - recall: 0.4377 - val_loss: 0.8515 - val_acc: 0.6772 - val_auc: 0.9384 - val_precision: 0.7396 - val_recall: 0.5947
# Epoch 17/30
# 557/557 [==============================] - 66s 119ms/step - loss: 5.3254 - acc: 0.5127 - auc: 0.8762 - precision: 0.5548 - recall: 0.4372 - val_loss: 0.8433 - val_acc: 0.6899 - val_auc: 0.9396 - val_precision: 0.7605 - val_recall: 0.6102
# Epoch 18/30
# 557/557 [==============================] - 66s 118ms/step - loss: 5.1591 - acc: 0.5164 - auc: 0.8755 - precision: 0.5605 - recall: 0.4379 - val_loss: 1.0215 - val_acc: 0.6201 - val_auc: 0.9139 - val_precision: 0.6866 - val_recall: 0.5422
# Epoch 19/30
# 557/557 [==============================] - 66s 119ms/step - loss: 5.2531 - acc: 0.5052 - auc: 0.8765 - precision: 0.5488 - recall: 0.4312 - val_loss: 1.0481 - val_acc: 0.6056 - val_auc: 0.9092 - val_precision: 0.6759 - val_recall: 0.5104
# Epoch 20/30
# 557/557 [==============================] - 66s 118ms/step - loss: 5.2297 - acc: 0.5166 - auc: 0.8781 - precision: 0.5543 - recall: 0.4434 - val_loss: 0.8800 - val_acc: 0.6664 - val_auc: 0.9357 - val_precision: 0.7152 - val_recall: 0.6011
# Epoch 21/30
# 557/557 [==============================] - 66s 118ms/step - loss: 5.4379 - acc: 0.5024 - auc: 0.8733 - precision: 0.5440 - recall: 0.4349 - val_loss: 1.0029 - val_acc: 0.6174 - val_auc: 0.9181 - val_precision: 0.6726 - val_recall: 0.5440
# Epoch 22/30
# 557/557 [==============================] - 67s 119ms/step - loss: 5.2878 - acc: 0.5221 - auc: 0.8800 - precision: 0.5641 - recall: 0.4493 - val_loss: 0.7513 - val_acc: 0.7325 - val_auc: 0.9523 - val_precision: 0.8016 - val_recall: 0.6482
# Epoch 23/30
# 557/557 [==============================] - 66s 118ms/step - loss: 5.2263 - acc: 0.5178 - auc: 0.8801 - precision: 0.5587 - recall: 0.4491 - val_loss: 1.0464 - val_acc: 0.6038 - val_auc: 0.9119 - val_precision: 0.6475 - val_recall: 0.5313
# Epoch 24/30
# 557/557 [==============================] - 66s 119ms/step - loss: 5.2534 - acc: 0.5325 - auc: 0.8830 - precision: 0.5751 - recall: 0.4606 - val_loss: 1.0122 - val_acc: 0.6011 - val_auc: 0.9173 - val_precision: 0.6526 - val_recall: 0.5449
# Epoch 25/30
# 557/557 [==============================] - 66s 118ms/step - loss: 5.2602 - acc: 0.5175 - auc: 0.8775 - precision: 0.5610 - recall: 0.4493 - val_loss: 1.2216 - val_acc: 0.5349 - val_auc: 0.8849 - val_precision: 0.5849 - val_recall: 0.4651
# Epoch 26/30
# 557/557 [==============================] - 66s 118ms/step - loss: 5.2288 - acc: 0.5196 - auc: 0.8785 - precision: 0.5613 - recall: 0.4523 - val_loss: 0.9971 - val_acc: 0.6274 - val_auc: 0.9182 - val_precision: 0.6818 - val_recall: 0.5458
# Epoch 27/30
# 557/557 [==============================] - 66s 118ms/step - loss: 5.2530 - acc: 0.5039 - auc: 0.8747 - precision: 0.5455 - recall: 0.4373 - val_loss: 0.9838 - val_acc: 0.6337 - val_auc: 0.9204 - val_precision: 0.6808 - val_recall: 0.5530
# Epoch 28/30
# 557/557 [==============================] - 66s 118ms/step - loss: 5.2731 - acc: 0.5187 - auc: 0.8810 - precision: 0.5632 - recall: 0.4546 - val_loss: 0.9241 - val_acc: 0.6555 - val_auc: 0.9291 - val_precision: 0.7112 - val_recall: 0.5938
# Epoch 29/30
# 557/557 [==============================] - 66s 118ms/step - loss: 5.2340 - acc: 0.5246 - auc: 0.8809 - precision: 0.5659 - recall: 0.4578 - val_loss: 0.9671 - val_acc: 0.6510 - val_auc: 0.9241 - val_precision: 0.6983 - val_recall: 0.5730
# Epoch 30/30
# 557/557 [==============================] - 66s 118ms/step - loss: 5.2142 - acc: 0.5232 - auc: 0.8791 - precision: 0.5625 - recall: 0.4565 - val_loss: 1.0561 - val_acc: 0.6092 - val_auc: 0.9124 - val_precision: 0.6446 - val_recall: 0.5476

# %% [markdown]
# ### 3.1.3. Avaliando o treinamento do modelo

# %%
acc = history.history['acc']
val_acc = history.history['val_acc']

loss = history.history['loss']
val_loss = history.history['val_loss']

plt.figure(figsize=(8, 8))
plt.subplot(2, 1, 1)
plt.plot(acc, label='Acuracia do treinamento')
plt.plot(val_acc, label='Acuracia da validação')
plt.legend(loc='lower right')
plt.ylabel('Acuracia')
plt.ylim([0,1])
plt.title('Acuracia do treinamento e validação')

plt.subplot(2, 1, 2)
plt.plot(loss, label='Perda do treinamento')
plt.plot(val_loss, label='Perda da validação')
plt.legend(loc='upper right')
plt.ylabel('Entropia Cruzada')
plt.ylim([0,8])
plt.title('Perda do treinamento e validação')
plt.xlabel('epoca')
plt.show()

# %% [markdown]
# ## 3.2. Criando o modelo: Segundo Momento

# %%
modelBase.trainable = True # Descongelando os pesos do modelo base para o treinamento

# %%
model.summary()
# Out:
# Model: "ResNet50V2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         [(None, 448, 448, 3)]     0
# _________________________________________________________________
# data_augmentation (Sequentia (None, 448, 448, 3)       0
# _________________________________________________________________
# tf.math.truediv (TFOpLambda) (None, 448, 448, 3)       0
# _________________________________________________________________
# tf.math.subtract (TFOpLambda (None, 448, 448, 3)       0
# _________________________________________________________________
# resnet50v2 (Functional)      (None, 14, 14, 2048)      23564800
# _________________________________________________________________
# global_average_pooling2d (Gl (None, 2048)              0
# _________________________________________________________________
# dropout (Dropout)            (None, 2048)              0
# _________________________________________________________________
# dense (Dense)                (None, 7)                 14343
# =================================================================
# Total params: 23,579,143
# Trainable params: 23,533,703
# Non-trainable params: 45,440
# _________________________________________________________________

# %% [markdown]
# ### 3.2.1. Buscando a taxa de aprendizado: LRFinder 2

# %%
optimizer = tf.keras.optimizers.Adam()
loss_fn = tf.keras.losses.CategoricalCrossentropy()

# %%
lr_find = LrFinder(model, optimizer, loss_fn)
lr_find.range_test(train_ds)
lr_find.plot_lrs(suggestion=True, show_grid=True)
# Out:
# Finding best initial lr over 100 steps
#   0%|          | 0/100 [00:00<?, ?it/s]
# LR Finder is complete, type {LrFinder}.plot_lrs() to see the graph.
# Min numerical gradient: 7.59E-07
# Min loss divided by 10: 1.20E-06

# %%
base_lr = 1e-6
max_lr = 1e-5

# %% [markdown]
# ### 3.2.2. Definindo os Callbacks

# %% [markdown]
# #### 3.2.2.1. CyclicalLR

# %%
step_size = train_steps
clr = CyclicalLR(max_lr=max_lr, 
                 base_lr=base_lr, 
                 step_size=step_size, 
                 cyclical_momentum=False)

# %% [markdown]
# #### 3.2.2.2. Checkpoint

# %%
# salva os melhores modelos para o callback
def get_model_name(k):
    return str(nomeDoModelo)+'_folder_'+ str(k)+'.h5'

# %%
checkpoint = ModelCheckpoint(save_dir+get_model_name(fold_var),
                                                  monitor='val_auc', verbose=1,
                                                  save_best_only=True, mode='max')

# %% [markdown]
# #### 3.2.2.3. Earlystopping

# %%
earlystopping = EarlyStopping(monitor='val_loss',
                              verbose=1, mode='min', 
                              restore_best_weights=False,
                              patience=15)

# %%
# Lista contendo todos os callbacks
callbacks_list = [checkpoint, earlystopping, clr]

# %% [markdown]
# ### 3.2.3. Treinando

# %%
model.compile(optimizer=Adam(learning_rate=base_lr), 
              loss=tf.keras.losses.CategoricalCrossentropy(), 
              metrics=metricasEscolhidas)

# %%
history_fine = model.fit(train_ds,
                    class_weight = weights_train_dict,
                    steps_per_epoch = train_steps,
                    epochs=second_epoch,
                    initial_epoch=history.epoch[-1],
                    validation_data=val_ds,
                    validation_steps = val_steps,
                    callbacks = callbacks_list)
# Out:
# Epoch 30/100
# 557/557 [==============================] - 191s 332ms/step - loss: 5.1377 - acc: 0.5328 - auc: 0.8865 - precision: 0.5761 - recall: 0.4551 - val_loss: 0.9685 - val_acc: 0.6228 - val_auc: 0.9208 - val_precision: 0.6594 - val_recall: 0.5476
#
# Epoch 00030: val_auc improved from -inf to 0.92084, saving model to /content/drive/MyDrive/TCC-Melo/Kaggle/modelos_checkPoint/ResNet50V2_folder_2.h5
# /usr/local/lib/python3.7/dist-packages/keras/utils/generic_utils.py:497: CustomMaskWarning:
#
# Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
# Epoch 31/100
# 557/557 [==============================] - 183s 328ms/step - loss: 4.2588 - acc: 0.5514 - auc: 0.9033 - precision: 0.5963 - recall: 0.4833 - val_loss: 0.7102 - val_acc: 0.7471 - val_auc: 0.9570 - val_precision: 0.7951 - val_recall: 0.7072
#
# Epoch 00031: val_auc improved from 0.92084 to 0.95702, saving model to /content/drive/MyDrive/TCC-Melo/Kaggle/modelos_checkPoint/ResNet50V2_folder_2.h5
# Epoch 32/100
# 557/557 [==============================] - 183s 329ms/step - loss: 3.9056 - acc: 0.5776 - auc: 0.9116 - precision: 0.6143 - recall: 0.5186 - val_loss: 0.8488 - val_acc: 0.6854 - val_auc: 0.9391 - val_precision: 0.7397 - val_recall: 0.6364
#
# Epoch 00032: val_auc did not improve from 0.95702
# Epoch 33/100
# 557/557 [==============================] - 183s 328ms/step - loss: 3.8420 - acc: 0.5818 - auc: 0.9156 - precision: 0.6245 - recall: 0.5292 - val_loss: 0.6957 - val_acc: 0.7425 - val_auc: 0.9587 - val_precision: 0.7807 - val_recall: 0.7262
#
# Epoch 00033: val_auc improved from 0.95702 to 0.95873, saving model to /content/drive/MyDrive/TCC-Melo/Kaggle/modelos_checkPoint/ResNet50V2_folder_2.h5
# Epoch 34/100
# 557/557 [==============================] - 183s 328ms/step - loss: 3.3722 - acc: 0.6157 - auc: 0.9260 - precision: 0.6447 - recall: 0.5670 - val_loss: 0.7034 - val_acc: 0.7416 - val_auc: 0.9575 - val_precision: 0.7638 - val_recall: 0.7035
#
# Epoch 00034: val_auc did not improve from 0.95873
# Epoch 35/100
# 557/557 [==============================] - 183s 328ms/step - loss: 3.2617 - acc: 0.6151 - auc: 0.9293 - precision: 0.6499 - recall: 0.5709 - val_loss: 0.6199 - val_acc: 0.7743 - val_auc: 0.9661 - val_precision: 0.7998 - val_recall: 0.7534
#
# Epoch 00035: val_auc improved from 0.95873 to 0.96609, saving model to /content/drive/MyDrive/TCC-Melo/Kaggle/modelos_checkPoint/ResNet50V2_folder_2.h5
# Epoch 36/100
# 557/557 [==============================] - 184s 328ms/step - loss: 3.0106 - acc: 0.6437 - auc: 0.9370 - precision: 0.6801 - recall: 0.6068 - val_loss: 0.6665 - val_acc: 0.7607 - val_auc: 0.9612 - val_precision: 0.8018 - val_recall: 0.7335
#
# Epoch 00036: val_auc did not improve from 0.96609
# Epoch 37/100
# 557/557 [==============================] - 183s 328ms/step - loss: 2.9892 - acc: 0.6463 - auc: 0.9373 - precision: 0.6809 - recall: 0.6083 - val_loss: 0.6515 - val_acc: 0.7588 - val_auc: 0.9644 - val_precision: 0.7817 - val_recall: 0.7371
#
# Epoch 00037: val_auc did not improve from 0.96609
# Epoch 38/100
# 557/557 [==============================] - 183s 328ms/step - loss: 2.7241 - acc: 0.6703 - auc: 0.9451 - precision: 0.7021 - recall: 0.6375 - val_loss: 0.5081 - val_acc: 0.8214 - val_auc: 0.9766 - val_precision: 0.8473 - val_recall: 0.7996
#
# Epoch 00038: val_auc improved from 0.96609 to 0.97655, saving model to /content/drive/MyDrive/TCC-Melo/Kaggle/modelos_checkPoint/ResNet50V2_folder_2.h5
# Epoch 39/100
# 557/557 [==============================] - 184s 329ms/step - loss: 2.7463 - acc: 0.6588 - auc: 0.9418 - precision: 0.6884 - recall: 0.6250 - val_loss: 0.6127 - val_acc: 0.7806 - val_auc: 0.9683 - val_precision: 0.8085 - val_recall: 0.7579
#
# Epoch 00039: val_auc did not improve from 0.97655
# Epoch 40/100
# 557/557 [==============================] - 183s 328ms/step - loss: 2.5756 - acc: 0.6875 - auc: 0.9484 - precision: 0.7114 - recall: 0.6548 - val_loss: 0.6927 - val_acc: 0.7380 - val_auc: 0.9601 - val_precision: 0.7555 - val_recall: 0.7226
#
# Epoch 00040: val_auc did not improve from 0.97655
# Epoch 41/100
# 557/557 [==============================] - 183s 328ms/step - loss: 2.5000 - acc: 0.6881 - auc: 0.9501 - precision: 0.7162 - recall: 0.6523 - val_loss: 0.6305 - val_acc: 0.7860 - val_auc: 0.9674 - val_precision: 0.8061 - val_recall: 0.7616
#
# Epoch 00041: val_auc did not improve from 0.97655
# Epoch 42/100
# 557/557 [==============================] - 183s 328ms/step - loss: 2.3631 - acc: 0.7057 - auc: 0.9546 - precision: 0.7308 - recall: 0.6794 - val_loss: 0.7796 - val_acc: 0.7335 - val_auc: 0.9520 - val_precision: 0.7556 - val_recall: 0.7008
#
# Epoch 00042: val_auc did not improve from 0.97655
# Epoch 43/100
# 557/557 [==============================] - 183s 329ms/step - loss: 2.2324 - acc: 0.7151 - auc: 0.9566 - precision: 0.7395 - recall: 0.6864 - val_loss: 0.6530 - val_acc: 0.7779 - val_auc: 0.9665 - val_precision: 0.8006 - val_recall: 0.7679
#
# Epoch 00043: val_auc did not improve from 0.97655
# Epoch 44/100
# 557/557 [==============================] - 183s 329ms/step - loss: 2.1451 - acc: 0.7234 - auc: 0.9597 - precision: 0.7472 - recall: 0.6976 - val_loss: 0.5709 - val_acc: 0.7978 - val_auc: 0.9713 - val_precision: 0.8257 - val_recall: 0.7815
#
# Epoch 00044: val_auc did not improve from 0.97655
# Epoch 45/100
# 557/557 [==============================] - 183s 329ms/step - loss: 2.1313 - acc: 0.7098 - auc: 0.9583 - precision: 0.7337 - recall: 0.6859 - val_loss: 0.5459 - val_acc: 0.8033 - val_auc: 0.9755 - val_precision: 0.8202 - val_recall: 0.7897
#
# Epoch 00045: val_auc did not improve from 0.97655
# Epoch 46/100
# 557/557 [==============================] - 184s 330ms/step - loss: 1.9078 - acc: 0.7404 - auc: 0.9632 - precision: 0.7610 - recall: 0.7198 - val_loss: 0.6950 - val_acc: 0.7461 - val_auc: 0.9611 - val_precision: 0.7732 - val_recall: 0.7262
#
# Epoch 00046: val_auc did not improve from 0.97655
# Epoch 47/100
# 557/557 [==============================] - 184s 330ms/step - loss: 2.0920 - acc: 0.7249 - auc: 0.9606 - precision: 0.7483 - recall: 0.7028 - val_loss: 0.6174 - val_acc: 0.7797 - val_auc: 0.9691 - val_precision: 0.7996 - val_recall: 0.7634
#
# Epoch 00047: val_auc did not improve from 0.97655
# Epoch 48/100
# 557/557 [==============================] - 185s 331ms/step - loss: 1.8231 - acc: 0.7513 - auc: 0.9668 - precision: 0.7690 - recall: 0.7337 - val_loss: 0.5230 - val_acc: 0.8087 - val_auc: 0.9769 - val_precision: 0.8266 - val_recall: 0.7951
#
# Epoch 00048: val_auc improved from 0.97655 to 0.97688, saving model to /content/drive/MyDrive/TCC-Melo/Kaggle/modelos_checkPoint/ResNet50V2_folder_2.h5
# Epoch 49/100
# 557/557 [==============================] - 185s 331ms/step - loss: 1.7575 - acc: 0.7506 - auc: 0.9668 - precision: 0.7677 - recall: 0.7335 - val_loss: 0.5088 - val_acc: 0.8150 - val_auc: 0.9782 - val_precision: 0.8318 - val_recall: 0.8024
#
# Epoch 00049: val_auc improved from 0.97688 to 0.97821, saving model to /content/drive/MyDrive/TCC-Melo/Kaggle/modelos_checkPoint/ResNet50V2_folder_2.h5
# Epoch 50/100
# 557/557 [==============================] - 184s 330ms/step - loss: 1.8357 - acc: 0.7502 - auc: 0.9662 - precision: 0.7677 - recall: 0.7308 - val_loss: 0.4671 - val_acc: 0.8277 - val_auc: 0.9799 - val_precision: 0.8559 - val_recall: 0.8078
#
# Epoch 00050: val_auc improved from 0.97821 to 0.97993, saving model to /content/drive/MyDrive/TCC-Melo/Kaggle/modelos_checkPoint/ResNet50V2_folder_2.h5
# Epoch 51/100
# 557/557 [==============================] - 184s 329ms/step - loss: 1.7279 - acc: 0.7507 - auc: 0.9673 - precision: 0.7700 - recall: 0.7309 - val_loss: 0.5817 - val_acc: 0.8033 - val_auc: 0.9737 - val_precision: 0.8210 - val_recall: 0.7942
#
# Epoch 00051: val_auc did not improve from 0.97993
# Epoch 52/100
# 557/557 [==============================] - 184s 331ms/step - loss: 1.5781 - acc: 0.7763 - auc: 0.9722 - precision: 0.7899 - recall: 0.7612 - val_loss: 0.7209 - val_acc: 0.7362 - val_auc: 0.9593 - val_precision: 0.7675 - val_recall: 0.7244
#
# Epoch 00052: val_auc did not improve from 0.97993
# Epoch 53/100
# 557/557 [==============================] - 185s 331ms/step - loss: 1.5638 - acc: 0.7713 - auc: 0.9710 - precision: 0.7849 - recall: 0.7537 - val_loss: 0.4837 - val_acc: 0.8286 - val_auc: 0.9811 - val_precision: 0.8413 - val_recall: 0.8169
#
# Epoch 00053: val_auc improved from 0.97993 to 0.98112, saving model to /content/drive/MyDrive/TCC-Melo/Kaggle/modelos_checkPoint/ResNet50V2_folder_2.h5
# Epoch 54/100
# 557/557 [==============================] - 186s 331ms/step - loss: 1.4988 - acc: 0.7859 - auc: 0.9738 - precision: 0.8011 - recall: 0.7711 - val_loss: 0.5892 - val_acc: 0.8033 - val_auc: 0.9719 - val_precision: 0.8119 - val_recall: 0.7942
#
# Epoch 00054: val_auc did not improve from 0.98112
# Epoch 55/100
# 557/557 [==============================] - 185s 331ms/step - loss: 1.6106 - acc: 0.7715 - auc: 0.9717 - precision: 0.7882 - recall: 0.7561 - val_loss: 0.4523 - val_acc: 0.8368 - val_auc: 0.9823 - val_precision: 0.8521 - val_recall: 0.8305
#
# Epoch 00055: val_auc improved from 0.98112 to 0.98234, saving model to /content/drive/MyDrive/TCC-Melo/Kaggle/modelos_checkPoint/ResNet50V2_folder_2.h5
# Epoch 56/100
# 557/557 [==============================] - 184s 330ms/step - loss: 1.3992 - acc: 0.7933 - auc: 0.9744 - precision: 0.8094 - recall: 0.7800 - val_loss: 0.4969 - val_acc: 0.8178 - val_auc: 0.9778 - val_precision: 0.8302 - val_recall: 0.8114
#
# Epoch 00056: val_auc did not improve from 0.98234
# Epoch 57/100
# 557/557 [==============================] - 184s 330ms/step - loss: 1.4729 - acc: 0.7903 - auc: 0.9751 - precision: 0.8051 - recall: 0.7737 - val_loss: 0.5770 - val_acc: 0.7960 - val_auc: 0.9754 - val_precision: 0.8043 - val_recall: 0.7860
#
# Epoch 00057: val_auc did not improve from 0.98234
# Epoch 58/100
# 557/557 [==============================] - 184s 330ms/step - loss: 1.3066 - acc: 0.8048 - auc: 0.9779 - precision: 0.8185 - recall: 0.7925 - val_loss: 0.3879 - val_acc: 0.8604 - val_auc: 0.9859 - val_precision: 0.8771 - val_recall: 0.8350
#
# Epoch 00058: val_auc improved from 0.98234 to 0.98585, saving model to /content/drive/MyDrive/TCC-Melo/Kaggle/modelos_checkPoint/ResNet50V2_folder_2.h5
# Epoch 59/100
# 557/557 [==============================] - 186s 331ms/step - loss: 1.5561 - acc: 0.7851 - auc: 0.9733 - precision: 0.7997 - recall: 0.7684 - val_loss: 0.5291 - val_acc: 0.8241 - val_auc: 0.9772 - val_precision: 0.8427 - val_recall: 0.8160
#
# Epoch 00059: val_auc did not improve from 0.98585
# Epoch 60/100
# 557/557 [==============================] - 185s 331ms/step - loss: 1.1919 - acc: 0.8182 - auc: 0.9797 - precision: 0.8317 - recall: 0.8054 - val_loss: 0.5197 - val_acc: 0.8078 - val_auc: 0.9758 - val_precision: 0.8225 - val_recall: 0.7897
#
# Epoch 00060: val_auc did not improve from 0.98585
# Epoch 61/100
# 557/557 [==============================] - 184s 330ms/step - loss: 1.3192 - acc: 0.8014 - auc: 0.9761 - precision: 0.8153 - recall: 0.7857 - val_loss: 0.5508 - val_acc: 0.8187 - val_auc: 0.9762 - val_precision: 0.8292 - val_recall: 0.8096
#
# Epoch 00061: val_auc did not improve from 0.98585
# Epoch 62/100
# 557/557 [==============================] - 184s 329ms/step - loss: 1.2391 - acc: 0.8147 - auc: 0.9796 - precision: 0.8264 - recall: 0.8033 - val_loss: 0.6321 - val_acc: 0.7597 - val_auc: 0.9660 - val_precision: 0.7797 - val_recall: 0.7443
#
# Epoch 00062: val_auc did not improve from 0.98585
# Epoch 63/100
# 557/557 [==============================] - 183s 329ms/step - loss: 1.3710 - acc: 0.7987 - auc: 0.9768 - precision: 0.8129 - recall: 0.7833 - val_loss: 0.5731 - val_acc: 0.8024 - val_auc: 0.9751 - val_precision: 0.8173 - val_recall: 0.7987
#
# Epoch 00063: val_auc did not improve from 0.98585
# Epoch 64/100
# 557/557 [==============================] - 183s 329ms/step - loss: 1.0578 - acc: 0.8360 - auc: 0.9820 - precision: 0.8482 - recall: 0.8271 - val_loss: 0.5690 - val_acc: 0.7978 - val_auc: 0.9733 - val_precision: 0.8132 - val_recall: 0.7815
#
# Epoch 00064: val_auc did not improve from 0.98585
# Epoch 65/100
# 557/557 [==============================] - 183s 329ms/step - loss: 1.0992 - acc: 0.8290 - auc: 0.9807 - precision: 0.8411 - recall: 0.8205 - val_loss: 0.4961 - val_acc: 0.8459 - val_auc: 0.9797 - val_precision: 0.8566 - val_recall: 0.8395
#
# Epoch 00065: val_auc did not improve from 0.98585
# Epoch 66/100
# 557/557 [==============================] - 183s 328ms/step - loss: 1.0976 - acc: 0.8301 - auc: 0.9813 - precision: 0.8425 - recall: 0.8198 - val_loss: 0.5597 - val_acc: 0.8060 - val_auc: 0.9744 - val_precision: 0.8172 - val_recall: 0.7942
#
# Epoch 00066: val_auc did not improve from 0.98585
# Epoch 67/100
# 557/557 [==============================] - 183s 328ms/step - loss: 1.2181 - acc: 0.8297 - auc: 0.9815 - precision: 0.8423 - recall: 0.8177 - val_loss: 0.5317 - val_acc: 0.8196 - val_auc: 0.9783 - val_precision: 0.8357 - val_recall: 0.8114
#
# Epoch 00067: val_auc did not improve from 0.98585
# Epoch 68/100
# 557/557 [==============================] - 183s 328ms/step - loss: 1.0076 - acc: 0.8436 - auc: 0.9845 - precision: 0.8538 - recall: 0.8344 - val_loss: 0.6031 - val_acc: 0.8078 - val_auc: 0.9707 - val_precision: 0.8184 - val_recall: 0.7969
#
# Epoch 00068: val_auc did not improve from 0.98585
# Epoch 69/100
# 557/557 [==============================] - 183s 329ms/step - loss: 1.1038 - acc: 0.8330 - auc: 0.9823 - precision: 0.8451 - recall: 0.8229 - val_loss: 0.5245 - val_acc: 0.8268 - val_auc: 0.9767 - val_precision: 0.8338 - val_recall: 0.8141
#
# Epoch 00069: val_auc did not improve from 0.98585
# Epoch 70/100
# 557/557 [==============================] - 183s 329ms/step - loss: 0.9519 - acc: 0.8514 - auc: 0.9853 - precision: 0.8585 - recall: 0.8416 - val_loss: 0.6051 - val_acc: 0.8087 - val_auc: 0.9728 - val_precision: 0.8156 - val_recall: 0.7978
#
# Epoch 00070: val_auc did not improve from 0.98585
# Epoch 71/100
# 557/557 [==============================] - 183s 328ms/step - loss: 1.0197 - acc: 0.8416 - auc: 0.9831 - precision: 0.8518 - recall: 0.8334 - val_loss: 0.5509 - val_acc: 0.8196 - val_auc: 0.9765 - val_precision: 0.8278 - val_recall: 0.8105
#
# Epoch 00071: val_auc did not improve from 0.98585
# Epoch 72/100
# 557/557 [==============================] - 184s 330ms/step - loss: 0.8965 - acc: 0.8651 - auc: 0.9873 - precision: 0.8752 - recall: 0.8567 - val_loss: 0.6569 - val_acc: 0.7987 - val_auc: 0.9697 - val_precision: 0.8042 - val_recall: 0.7897
#
# Epoch 00072: val_auc did not improve from 0.98585
# Epoch 73/100
# 557/557 [==============================] - 185s 331ms/step - loss: 0.9319 - acc: 0.8494 - auc: 0.9853 - precision: 0.8587 - recall: 0.8412 - val_loss: 0.4840 - val_acc: 0.8495 - val_auc: 0.9815 - val_precision: 0.8567 - val_recall: 0.8404
#
# Epoch 00073: val_auc did not improve from 0.98585
# Epoch 00073: early stopping

# %% [markdown]
# ### 3.2.4. Avaliando o treinamento do modelo

# %%
acc += history_fine.history['acc']
val_acc += history_fine.history['val_acc']

loss += history_fine.history['loss']
val_loss += history_fine.history['val_loss']

# %%
plt.figure(figsize=(8, 8))
plt.subplot(2, 1, 1)
plt.plot(acc, label='Acuracia de treinamento')
plt.plot(val_acc, label='Acuracia de validação')
plt.ylim([0, 1])
plt.plot([first_epoch-1,first_epoch-1],
          plt.ylim(), label='Começo do Fine Tuning')
plt.legend(loc='lower right')
plt.title('Acuracia do treinamento e validação')

plt.subplot(2, 1, 2)
plt.plot(loss, label='Perda do treinamento')
plt.plot(val_loss, label='Perda da validação')
plt.ylim([0, 8])
plt.plot([first_epoch-1,first_epoch-1],
         plt.ylim(), label='Começo do Fine Tuning')
plt.legend(loc='upper right')
plt.title('Perda do treinamento e validação')
plt.xlabel('epoca')
plt.show()

# %% [markdown]
# #### 3.2.4.1. Verificando CLR

# %%
clr.plot_lr((14, 3.5))

# %% [markdown]
# # 4. Avaliando o modelo

# %%
model.load_weights(save_dir + str(nomeDoModelo)+'_folder_'+ str(fold_var)+'.h5')
# model_all = tf.keras.models.load_model(save_dir + str(nomeDoModelo)+'_folder_'+ str(fold_var)+'.h5')

# %%
model.evaluate(val_ds)
# Out:
# 69/69 [==============================] - 7s 100ms/step - loss: 0.3879 - acc: 0.8604 - auc: 0.9859 - precision: 0.8771 - recall: 0.8350
# [0.38792118430137634,
#  0.8603807687759399,
#  0.9858525395393372,
#  0.8771428465843201,
#  0.834995448589325]

# %% [markdown]
# ## 4.1. Realizando as previsões

# %%
# Obtendo a tabela verdade 
true_categories = tf.concat([y for x, y in val_ds], axis=0)
true_categories  = tf.argmax(true_categories , axis=1)

# %%
# Realizando as previsões
predictions = model.predict(val_ds, verbose=1)
y_pred = tf.argmax(predictions, axis=1)
# Out:
# 69/69 [==============================] - 7s 86ms/step

# %% [markdown]
# ## 4.3. Metricas de avaliação

# %% [markdown]
# ### 4.3.1. Quadro de metricas

# %%
cm_plot_labels = ['akiec', 'bcc', 'bkl', 'df', 'mel','nv', 'vasc']
print(classification_report(true_categories , y_pred, target_names=cm_plot_labels))
# Out:
#               precision    recall  f1-score   support
#
#        akiec       0.68      0.50      0.58        30
#          bcc       0.61      0.77      0.68        35
#          bkl       0.59      0.72      0.65        88
#           df       0.33      0.75      0.46         8
#          mel       0.35      0.70      0.47        46
#           nv       0.98      0.90      0.94       883
#         vasc       1.00      0.77      0.87        13
#
#     accuracy                           0.86      1103
#    macro avg       0.65      0.73      0.66      1103
# weighted avg       0.90      0.86      0.87      1103

# %% [markdown]
# ### 4.3.2. Matriz de confusão

# %%
cm = confusion_matrix(true_categories , y_pred)
fig, ax = plot_confusion_matrix(conf_mat=cm,
                                show_absolute=True,
                                show_normed=True, 
                                class_names=cm_plot_labels)

# %% [markdown]
# ### 4.3.3. Acurácia balanceada

# %%
bAcc= sklearn.metrics.balanced_accuracy_score(true_categories, y_pred)
print(f'Acurácia balanceada: {bAcc*100:.6f}%')
# Out:
# Acurácia balanceada: 72.909898%
